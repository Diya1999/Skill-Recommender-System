# %%
import pandas as pd
import numpy as np

# %%
resume16= pd.read_csv (r'C:\Users\diyas\Downloads\2016CSEResumeTemp - Sheet1.csv')

# %%
resume16.rename(columns = {'SRN':'USN'}, inplace = True)

# %%
resume16.columns
# Out:
# Index(['USN', 'Name', 'Branch', '10th percentage', '12th percentage', 'CGPA',
#        'Number of projects', 'Projects details', 'Github link',
#        'LinkedIn link', 'General skills', 'Publications',
#        'Number of Internships', 'Internship details', 'External certificates',
#        'Programming Language Skills', 'Software Tool Skills', 'Minor name',
#        'Placement details', 'Scholarships', 'Awards',
#        'Events and Competitions participated', 'Workshops', 'Volunteering',
#        'Languages known', 'Co-curricular activities', 'Other Details'],
#       dtype='object')

# %%
academic_placement_16= pd.read_csv (r'C:\Users\diyas\Downloads\Placement+Academics1516_UpdatedTier.csv')

# %%
usn_list = resume16.USN.unique()
print(usn_list.size)
# Out:
# 57

# %%
academic_placement_16_res = academic_placement_16.loc[academic_placement_16['USN'].isin(usn_list)]

# %%
academic_placement_16_res.shape
# Out:
# (46, 15)

# %%
academic_placement_16.shape
# Out:
# (1055, 15)

# %%
academic_placement_16_res['Number of Offers'].value_counts()
# Out:
# 2.0    24
# 1.0    19
# 3.0     3
# Name: Number of Offers, dtype: int64

# %%
combined_master2016=pd.merge(academic_placement_16_res,resume16, on='USN')

# %%
combined_master2016
# Out:
#     StudentId           USN                             Name_x      Mobile  \
# 0        4271  01FB15ECS019                AISHWARYA MANJUNATH  9342400999
# 1       13453  01FB16ECS002               A OM SAI VIVEK REDDY  9491136166
# 2       13453  01FB16ECS002               A OM SAI VIVEK REDDY  9491136166
# 3       13457  01FB16ECS006                     AAYUSHI SANGHI  9845200117
# 4       13463  01FB16ECS012                      ABHINAV HEGDE  9482013192
# 5       13466  01FB16ECS015                  ABHISHEK MASHETTY  9243434390
# 6       13467  01FB16ECS016                 ABHISHEK NARAYANAN  9830310102
# 7       13467  01FB16ECS016                 ABHISHEK NARAYANAN  9830310102
# 8       13468  01FB16ECS017                    ABHISHEK PRASAD  9631077891
# 9       13469  01FB16ECS018                ABHISHEK SASEENDRAN  9481779462
# 10      13473  01FB16ECS023                      ADARSH MISHRA  8762548365
# 11      13481  01FB16ECS031                         ADITYA RAJ  8873296575
# 12      13485  01FB16ECS035                      AISHWARYA P S  9916696406
# 13      13485  01FB16ECS035                      Aishwarya P S         NaN
# 14      13486  01FB16ECS036                    Aiswarya Sriram         NaN
# 15      13486  01FB16ECS036                    AISWARYA SRIRAM  9845306899
# 16      13487  01FB16ECS037                     AJAY KUMAR K T  7349609600
# 17      13488  01FB16ECS038                         AKASH BHAT  9880209074
# 18      13494  01FB16ECS044       AKONDI VYASASAI ASHISH KUMAR  7349079716
# 19      13500  01FB16ECS050                         ALAN JACOB  9483953110
# 20      13502  01FB16ECS052                        AMAN BHAT T  9845263732
# 21      13502  01FB16ECS052                        AMAN BHAT T  9845263732
# 22      13506  01FB16ECS056                  ANEESH PADUR BHAT  9986229733
# 23      13506  01FB16ECS056                  Aneesh Padur Bhat         NaN
# 24      13519  01FB16ECS069               APRAMEYA M BHARADWAJ  9632228480
# 25      13522  01FB16ECS072                        ARNAV DUBEY  9206767375
# 26      13522  01FB16ECS072                        ARNAV DUBEY  9206767375
# 27      13523  01FB16ECS073  ARPIT SING PRATAP SING NARGUNDKAR  8296802783
# 28      13523  01FB16ECS073  ARPIT SING PRATAP SING NARGUNDKAR  8296802783
# 29      13524  01FB16ECS074                  ARVIND SRINIVASAN  7760856595
# 30      13526  01FB16ECS076                       ASHISH SINGH  8971516239
# 31      13535  01FB16ECS085                           B RUTVIK  8277427140
# 32      13539  01FB16ECS089                    Bhavani Shankar         NaN
# 33      13539  01FB16ECS089                    BHAVANI SHANKAR  7026580562
# 34      13544  01FB16ECS094            CHANDAN GAJANANA BHATTA  9449857469
# 35      13557  01FB16ECS107                     DEEPALI PRABHU  9901423265
# 36      13557  01FB16ECS107                     Deepali Prabhu         NaN
# 37      13560  01FB16ECS110                   DEVASHISH NARULA  9873761900
# 38      13574  01FB16ECS124            Gundam Satyabhama Reddy         NaN
# 39      13574  01FB16ECS124            GUNDAM SATYABHAMA REDDY  8105539466
# 40      13639  01FB16ECS189                      Malaika Vijay         NaN
# 41      13639  01FB16ECS189                      MALAIKA VIJAY  9148244771
# 42      13898  01FB16ECS449                           VISHAL S  9481662205
# 43      14174  01FB16ECS483                 RACHANA AITHAL K R  8550834324
# 44      14174  01FB16ECS483                 Rachana Aithal K R         NaN
# 45      14174  01FB16ECS483                 RACHANA AITHAL K R  8550834324
#
#                                Email  CGPA_x  \
# 0           aishwarya.9711@gmail.com    9.68
# 1              aomsaivivek@gmail.com    8.83
# 2              aomsaivivek@gmail.com    8.83
# 3              aayu.sanghi@gmail.com    9.27
# 4            hegdeabhinav7@gmail.com    8.95
# 5      abhishekmashetty117@gmail.com    8.78
# 6           abhishek.1010n@gmail.com    9.89
# 7           abhishek.1010n@gmail.com    9.89
# 8   abhishekcoolest.prasad@gmail.com    9.39
# 9            abhishek.pesu@gmail.com    9.04
# 10         adarshmishra288@gmail.com    8.57
# 11      adityasingh.591997@gmail.com    7.71
# 12          aishwarya.ps31@gmail.com    9.90
# 13                               NaN    9.90
# 14                               NaN    8.68
# 15           aiswarya.spaa@gmail.com    8.68
# 16      786ajaygopikrishna@gmail.com    7.30
# 17             akash11dude@gmail.com    9.22
# 18            csashish1998@gmail.com    7.71
# 19             alan1998jac@gmail.com    8.64
# 20              aman04jdsj@gmail.com    9.17
# 21              aman04jdsj@gmail.com    9.17
# 22          aneesh.bhat123@gmail.com    8.98
# 23                               NaN    8.98
# 24      aprameya.bharadwaj@gmail.com    9.52
# 25           Arnavdubey002@gmail.com    8.27
# 26           Arnavdubey002@gmail.com    8.27
# 27               APTNRG007@gmail.com    8.73
# 28               APTNRG007@gmail.com    8.73
# 29          arvind.srini.8@gmail.com    9.72
# 30       ashish.singh.6223@gmail.com    9.10
# 31               rutvikbrk@gmail.com    7.15
# 32                               NaN    7.63
# 33       bhavanishankar606@gmail.com    7.63
# 34        chandangbhatta10@gmail.com    7.31
# 35              deepali846@gmail.com    9.51
# 36                               NaN    9.51
# 37              devanarula@gmail.com    7.91
# 38                               NaN    9.56
# 39         satyabhamareddy@gmail.com    9.56
# 40                               NaN    9.91
# 41           malaika.vijay@gmail.com    9.91
# 42               vishalmkb@gmail.com    8.91
# 43         rachanaaithal88@gmail.com    9.57
# 44                               NaN    9.57
# 45         rachanaaithal88@gmail.com    9.57
#
#                                               Courses  EarnedCredits  \
# 0   {'Core Courses': [{"{'Code': 'UE15CS101', 'Nam...          176.0
# 1   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 2   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 3   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 4   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          178.0
# 5   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 6   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 7   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 8   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          178.0
# 9   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          178.0
# 10  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          178.0
# 11  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 12  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 13  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 14  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 15  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 16  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 17  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 18  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 19  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 20  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 21  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 22  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 23  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 24  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 25  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 26  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 27  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 28  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 29  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 30  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 31  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          152.0
# 32  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 33  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 34  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          172.0
# 35  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 36  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 37  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 38  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 39  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 40  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 41  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 42  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 43  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 44  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
# 45  {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...          176.0
#
#     TotalCredits  Number of Offers  ...  \
# 0          176.0               1.0  ...
# 1          176.0               2.0  ...
# 2          176.0               2.0  ...
# 3          176.0               1.0  ...
# 4          178.0               1.0  ...
# 5          176.0               1.0  ...
# 6          176.0               2.0  ...
# 7          176.0               2.0  ...
# 8          178.0               1.0  ...
# 9          178.0               1.0  ...
# 10         178.0               1.0  ...
# 11         176.0               1.0  ...
# 12         176.0               2.0  ...
# 13         176.0               2.0  ...
# 14         176.0               2.0  ...
# 15         176.0               2.0  ...
# 16         176.0               1.0  ...
# 17         176.0               1.0  ...
# 18         176.0               1.0  ...
# 19         176.0               1.0  ...
# 20         176.0               2.0  ...
# 21         176.0               2.0  ...
# 22         176.0               2.0  ...
# 23         176.0               2.0  ...
# 24         176.0               1.0  ...
# 25         176.0               2.0  ...
# 26         176.0               2.0  ...
# 27         176.0               2.0  ...
# 28         176.0               2.0  ...
# 29         176.0               1.0  ...
# 30         176.0               1.0  ...
# 31         152.0               1.0  ...
# 32         176.0               2.0  ...
# 33         176.0               2.0  ...
# 34         176.0               1.0  ...
# 35         176.0               2.0  ...
# 36         176.0               2.0  ...
# 37         176.0               1.0  ...
# 38         176.0               2.0  ...
# 39         176.0               2.0  ...
# 40         176.0               2.0  ...
# 41         176.0               2.0  ...
# 42         176.0               1.0  ...
# 43         176.0               3.0  ...
# 44         176.0               3.0  ...
# 45         176.0               3.0  ...
#
#                                    Minor name  Placement details  \
# 0   Electronics and Communication Engineering                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
# 5                                         NaN                NaN
# 6                                         NaN                NaN
# 7                                         NaN                NaN
# 8                                         NaN                NaN
# 9                                         NaN                NaN
# 10                                        NaN                NaN
# 11                                        NaN                NaN
# 12                                        NaN                NaN
# 13                                        NaN                NaN
# 14                                        NaN                NaN
# 15                                        NaN                NaN
# 16                                        NaN                NaN
# 17                                        NaN                NaN
# 18                                        NaN                NaN
# 19                                        NaN                NaN
# 20                                        NaN                NaN
# 21                                        NaN                NaN
# 22                                        NaN                NaN
# 23                                        NaN                NaN
# 24                                        NaN             Placed
# 25                                        NaN                NaN
# 26                                        NaN                NaN
# 27                                        NaN                NaN
# 28                                        NaN                NaN
# 29                                        NaN                NaN
# 30                                        NaN                NaN
# 31                                        NaN                NaN
# 32                                        NaN                NaN
# 33                                        NaN                NaN
# 34                                        NaN                NaN
# 35                                        NaN                NaN
# 36                                        NaN                NaN
# 37                                 Minor name  Placement details
# 38                                        NaN             Placed
# 39                                        NaN             Placed
# 40                                        NaN             Placed
# 41                                        NaN             Placed
# 42                                        NaN                NaN
# 43  Electronics and Communication Engineering             Placed
# 44  Electronics and Communication Engineering             Placed
# 45  Electronics and Communication Engineering             Placed
#
#                                          Scholarships  \
# 0                                                 NaN
# 1   Recipient of CNR Rao Scholarship in the 5th se...
# 2   Recipient of CNR Rao Scholarship in the 5th se...
# 3                                                 NaN
# 4   Prof MRD Scholarship for Academic Excellence, ...
# 5                                                 NaN
# 6   Received the Prof MRD Merit Scholarship for be...
# 7   Received the Prof MRD Merit Scholarship for be...
# 8   Recipient of “CNR RAO Merit Scholarship” ##Bag...
# 9   Recipient of Prof CNR RAO Merit Scholarship(20...
# 10                                                NaN
# 11                                                NaN
# 12  University merit-based scholarship holder and ...
# 13  University merit-based scholarship holder and ...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Received Prof. C N Rao Merit Scholarship durin...
# 20                 Prof. C.N.R. Rao Merit Scholarship
# 21                 Prof. C.N.R. Rao Merit Scholarship
# 22                 Prof. C.N.R. Rao Merit Scholarship
# 23                 Prof. C.N.R. Rao Merit Scholarship
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  CNR Rao Merit Scholarship winner for academic ...
# 30                   MRD Scholarship semester 1 and 5
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  Recipient of scholarship from Foundation For E...
# 35                                                NaN
# 36                                                NaN
# 37                                       Scholarships
# 38  Prof. C.N.R Rao Merit Scholarships for excelle...
# 39  Prof. C.N.R Rao Merit Scholarships for excelle...
# 40  CNR Rao Merit Scholarship PESU (Awarded to the...
# 41  CNR Rao Merit Scholarship PESU (Awarded to the...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                                Awards  \
# 0                                                 NaN
# 1   Recipient of 6 Distinction Awards in all semes...
# 2   Recipient of 6 Distinction Awards in all semes...
# 3                                                 NaN
# 4   1st Place at Alcoding Summer Challenge (out of...
# 5                                                 NaN
# 6   Felicitated with Distinction Award for academi...
# 7   Felicitated with Distinction Award for academi...
# 8   Bagged 13th rank in “Hour Storm #1” organized ...
# 9   Awarded First Class with Distinction across al...
# 10  Bet to Code - Secured Third Position in the co...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  Institution of Engineering and Technology (IET...
# 30                                                NaN
# 31  Won Second Prize in all India hackathon held i...
# 32                                                NaN
# 33                                                NaN
# 34  Awarded by Rotary Club Moodbidri for being one...
# 35                                                NaN
# 36                                                NaN
# 37                                             Awards
# 38                                                NaN
# 39                                                NaN
# 40  Most Innovative Solution, Intel ADAS (Advanced...
# 41  Most Innovative Solution, Intel ADAS (Advanced...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                  Events and Competitions participated  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Participated in the #Code Hackathon hosted by ...
# 7   Participated in the #Code Hackathon hosted by ...
# 8   Qualified Codechef Smackdown 2017 and 2019 Qua...
# 9   National Rank 500 in the NSTSE Exam (2015)\r\n...
# 10                                                NaN
# 11  Cleared the exam and interview of Indian Naval...
# 12  Secured 37th rank in Codiva on Hackerrank and ...
# 13  Secured 37th rank in Codiva on Hackerrank and ...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Organizer for The Amateur SCientist 2017, Core...
# 19                                                NaN
# 20  1st Place at the National Level Abacus Competi...
# 21  1st Place at the National Level Abacus Competi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  Secured 13th rank in PES Al-Coding club contes...
# 26  Secured 13th rank in PES Al-Coding club contes...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30             Participated in Data Science Hackathon
# 31  Participated in hackathon at PES University Ba...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37               Events and Competitions participated
# 38                                                NaN
# 39                                                NaN
# 40  { e-yantra Robotics Competition 2017-18 : Impl...
# 41  { e-yantra Robotics Competition 2017-18 : Impl...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                             Workshops  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Attended workshop on machine learning, image p...
# 7   Attended workshop on machine learning, image p...
# 8                                                 NaN
# 9                                                 NaN
# 10                                             L1 CIE
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Participated in Ethical Hacking Workshop in PE...
# 32  Case Study on VM ware — Knowledge Management S...
# 33  Case Study on VM ware — Knowledge Management S...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                          Workshops
# 38  Ethical Hacking Workshop conducted by ROBOTech...
# 39  Ethical Hacking Workshop conducted by ROBOTech...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                          Volunteering  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16     Organised and volunteered Events of Samarpana.
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Organised THE AMATEUR SCIENTIST fest in PES UN...
# 32  Volunteered at IoT India Congress 2016 organiz...
# 33  Volunteered at IoT India Congress 2016 organiz...
# 34  Active member of Samarpana Club in PES Univers...
# 35  Member of Aeolus Club PESU.## Core team member...
# 36  Member of Aeolus Club PESU.## Core team member...
# 37                                       Volunteering
# 38  Samarasa-Ninaada, a Cultural Annual Program##A...
# 39  Samarasa-Ninaada, a Cultural Annual Program##A...
# 40                                                NaN
# 41                                                NaN
# 42  Prakalpa: Helped in technical work and built a...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                             Languages known  \
# 0                 Kannada##Hindi##English\n
# 1                  English##Telugu##Hindi\n
# 2                  English##Telugu##Hindi\n
# 3                                       NaN
# 4                                       NaN
# 5          Kannada##Hindi##English##Marathi
# 6            Tamil##English##Hindi##Bengali
# 7            Tamil##English##Hindi##Bengali
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# 31          English##Hindi##Telugu##Kannada
# 32                  English##Kannada##Hindi
# 33                  English##Kannada##Hindi
# 34                  English##Kannada##Hindi
# 35                                      NaN
# 36                                      NaN
# 37                          Languages known
# 38          English##Telugu##Kannada##Hindi
# 39          English##Telugu##Kannada##Hindi
# 40                                      NaN
# 41                                      NaN
# 42                                      NaN
# 43  English##Hindi##Kannada##Telugu ##Tamil
# 44  English##Hindi##Kannada##Telugu ##Tamil
# 45  English##Hindi##Kannada##Telugu ##Tamil
#
#                              Co-curricular activities  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                              Wildlife#Space#Cricket
# 6   Enthusiastic about travelling, photography, re...
# 7   Enthusiastic about travelling, photography, re...
# 8                                                 NaN
# 9                                                 NaN
# 10  An active member of the Center For Innovation ...
# 11                    Football Player in College Team
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  President of Mathematics Association 2015-16, ...
# 30  Was in top 10 in the debate competition held a...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                           Co-curricular activities
# 38  An active member of CSR Club (Collegiate Socia...
# 39  An active member of CSR Club (Collegiate Socia...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                         Other Details
# 0   Literature##Sports, Outdoors and Fishing##Educ...
# 1   Team member for organizing Atma Trisha in2017,...
# 2   Team member for organizing Atma Trisha in2017,...
# 3                                                 NaN
# 4   Youtube-channel : Algo Made Easy (https://www....
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Executive Member (Core Team contest organizer)...
# 9   Software development enthusiast.\r\nAvid learn...
# 10  Codechef - Highest Rating of 1603 (handle : ad...
# 11  Got 99.41 percentile in e-litmus Aptitude Test...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Ranked 390 in Karnataka Common Entrance Test (...
# 20  Hindustani Tabla Examination - Junior Level Ka...
# 21  Hindustani Tabla Examination - Junior Level Ka...
# 22  Volleyball captain in school and college##Coor...
# 23  Volleyball captain in school and college##Coor...
# 24                                                NaN
# 25  Stood 3rd in university for ACM-ICPC qualifier...
# 26  Stood 3rd in university for ACM-ICPC qualifier...
# 27                                                NaN
# 28                                                NaN
# 29  Teaching Assistant for Advanced Algorithms, 20...
# 30              Secured 837 rank out of 15k+ students
# 31                                                NaN
# 32  Head Of March-Past of Bangalore division in KV...
# 33  Head Of March-Past of Bangalore division in KV...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                      Other Details
# 38  Hackathon organizer. Organized two 24-hour CS ...
# 39  Hackathon organizer. Organized two 24-hour CS ...
# 40  Machine Learning ##Natural Language Processing...
# 41  Machine Learning ##Natural Language Processing...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
# [46 rows x 41 columns]

# %%
combined_master2016.columns
# Out:
# Index(['StudentId', 'USN', 'Name_x', 'Mobile', 'Email', 'CGPA_x', 'Courses',
#        'EarnedCredits', 'TotalCredits', 'Number of Offers', 'CompanyName',
#        'TierLevel', 'EmploymentType', 'CTC', 'Stipend(K)', 'Name_y', 'Branch',
#        '10th percentage', '12th percentage', 'CGPA_y', 'Number of projects',
#        'Projects details', 'Github link', 'LinkedIn link', 'General skills',
#        'Publications', 'Number of Internships', 'Internship details',
#        'External certificates', 'Programming Language Skills',
#        'Software Tool Skills', 'Minor name', 'Placement details',
#        'Scholarships', 'Awards', 'Events and Competitions participated',
#        'Workshops', 'Volunteering', 'Languages known',
#        'Co-curricular activities', 'Other Details'],
#       dtype='object')

# %%
master_2017= pd.read_csv (r'C:\Users\diyas\Documents\Recommendation_system\MasterDataset2017.csv')

# %%
master_2017.columns
# Out:
# Index(['USN', 'Courses', 'Name', 'Branch', '10thPercentage', '12thPercentage',
#        'CGPA', 'NoofProjects', 'ProjectDetail', 'GitHubLink', 'LinkedInLink',
#        'GeneralSkills', 'PublicationDetails', 'NoofInternships',
#        'InternshipDetail', 'ExternalCertificates', 'ProgLanguages',
#        'SoftwareTools', 'MinorAttended', 'Placed', 'Scholarships', 'Awards',
#        'EventsParticipated', 'WorkshopAndSeminorAttended', 'VolunteeringWork',
#        'Languages', 'CoCurricularActivities', 'OtherDetails', ' CompanyName',
#        ' CTC', ' EmploymentType', ' TierLevel'],
#       dtype='object')

# %%
combined_master2016_1=combined_master2016.drop(['StudentId','Name_y','CGPA_y','Mobile','Email','EarnedCredits', 'TotalCredits'], axis=1)

# %%
combined_master2016_1.rename(columns = {'Name_x':'Name'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'CGPA_x':'CGPA'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Placement details':'Placed'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Other Details':'OtherDetails'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Co-curricular activities':'CoCurricularActivities'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Languages known':'Languages'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Volunteering':'VolunteeringWork'}, inplace = True)

# %%
master_2017.rename(columns = {'WorkshopAndSeminorAttended':'Workshops'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Events and Competitions participated':'Events participated'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Minor name':'MinorAttended'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Software Tool Skills':'SoftwareTools'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Programming Language Skills':'ProgLanguages'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'External certificates':'ExternalCertificates'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Internship details':'InternshipDetail'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Number of Internships':'NoofInternships'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Publications':'PublicationDetails'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'General skills':'GeneralSkills'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'LinkedIn link':'LinkedInLink'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Github link':'GithubLink'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'10th percentage':'10thPercentage'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'12th percentage':'12thPercentage'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Number of projects':'NoofProjects'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Projects details':'ProjectDetail'}, inplace = True)

# %%
combined_master2016_1.rename(columns = {'Events participated':'EventsParticipated'}, inplace = True)

# %%
combined_master2016_1.columns
# Out:
# Index(['USN', 'Name', 'CGPA', 'Courses', 'Number of Offers', 'CompanyName',
#        'TierLevel', 'EmploymentType', 'CTC', 'Stipend(K)', 'Branch',
#        '10thPercentage', '12thPercentage', 'NoofProjects', 'ProjectDetail',
#        'GithubLink', 'LinkedInLink', 'GeneralSkills', 'PublicationDetails',
#        'NoofInternships', 'InternshipDetail', 'ExternalCertificates',
#        'ProgLanguages', 'SoftwareTools', 'MinorAttended', 'Placed',
#        'Scholarships', 'Awards', 'EventsParticipated', 'Workshops',
#        'VolunteeringWork', 'Languages', 'CoCcurricularActivities',
#        'OtherDetails'],
#       dtype='object')

# %%
master_2017.columns
# Out:
# Index(['USN', 'Courses', 'Name', 'Branch', '10thPercentage', '12thPercentage',
#        'CGPA', 'NoofProjects', 'ProjectDetail', 'GitHubLink', 'LinkedInLink',
#        'GeneralSkills', 'PublicationDetails', 'NoofInternships',
#        'InternshipDetail', 'ExternalCertificates', 'ProgLanguages',
#        'SoftwareTools', 'MinorAttended', 'Placed', 'Scholarships', 'Awards',
#        'EventsParticipated', 'Workshops', 'VolunteeringWork', 'Languages',
#        'CoCurricularActivities', 'OtherDetails', ' CompanyName', ' CTC',
#        ' EmploymentType', ' TierLevel'],
#       dtype='object')

# %%
master_2017.rename(columns = {' CompanyName':'CompanyName'}, inplace = True)

# %%
master_2017.rename(columns = {' CTC':'CTC'}, inplace = True)

# %%
master_2017.rename(columns = {' EmploymentType':'EmploymentType'}, inplace = True)

# %%
master_2017.rename(columns = {' TierLevel':'TierLevel'}, inplace = True)

# %%
master_2017.columns
# Out:
# Index(['USN', 'Courses', 'Name', 'Branch', '10thPercentage', '12thPercentage',
#        'CGPA', 'NoofProjects', 'ProjectDetail', 'GitHubLink', 'LinkedInLink',
#        'GeneralSkills', 'PublicationDetails', 'NoofInternships',
#        'InternshipDetail', 'ExternalCertificates', 'ProgLanguages',
#        'SoftwareTools', 'MinorAttended', 'Placed', 'Scholarships', 'Awards',
#        'EventsParticipated', 'Workshops', 'VolunteeringWork', 'Languages',
#        'CoCurricularActivities', 'OtherDetails', 'CompanyName', 'CTC',
#        'EmploymentType', 'TierLevel'],
#       dtype='object')

# %%
combined_master2016_2=combined_master2016_1.drop(['Number of Offers'], axis=1)

# %%
combined_master2016_2.shape
# Out:
# (46, 33)

# %%
master_2017.shape
# Out:
# (147, 32)

# %%
combined_master2016_2['Branch'].value_counts()
# Out:
# Computer Science and Engineering    46
# Name: Branch, dtype: int64

# %%
combined_master2016_2['Branch'] = combined_master2016_2['Branch'].replace(['Computer Science and Engineering'],'CSE')

# %%
master_2017['EmploymentType'].value_counts()
# Out:
# Full time employment + Internship (Mandatory)    86
# Full time employment only                        34
# Internship only                                  18
#                                                   9
# Name: EmploymentType, dtype: int64

# %%
combined_master2016_2['EmploymentType'].value_counts()
# Out:
# Full time employment only                        17
# Full time employment + Internship (Mandatory)    13
# Summer Internship                                 8
# Internship only                                   7
# Name: EmploymentType, dtype: int64

# %%
master_2017['EmploymentType'] = master_2017['EmploymentType'].replace(['1'],'Full time employment + Internship (Mandatory)')

# %%
master_2017['EmploymentType'] = master_2017['EmploymentType'].replace(['2'],'Full time employment only')

# %%
master_2017['EmploymentType'] = master_2017['EmploymentType'].replace(['3'],'Internship only')

# %%
master_2017['EmploymentType'].value_counts()
# Out:
# Full time employment + Internship (Mandatory)    86
# Full time employment only                        34
# Internship only                                  18
#                                                   9
# Name: EmploymentType, dtype: int64

# %%
combined_master2016_3=combined_master2016_2.drop(['Stipend(K)'], axis=1)

# %%
combined_master2016_3.shape
# Out:
# (46, 32)

# %%
combined_master_1617=pd.concat([combined_master2016_3, master_2017])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined_master_1617
# Out:
#     10thPercentage  12thPercentage  \
# 0               96           90.00
# 1              9.7           97.60
# 2              9.7           97.60
# 3               95           96.00
# 4              NaN           94.00
# 5              9.4           89.36
# 6               95           95.00
# 7               95           95.00
# 8             94.2           89.20
# 9             94.5           94.50
# 10             9.6           87.20
# 11              95           89.40
# 12         d 94.83           95.80
# 13         d 94.83           95.80
# 14              10           90.60
# 15              10           90.60
# 16             8.2           85.60
# 17              10           95.60
# 18            85.6           97.20
# 19            91.3           93.80
# 20              10           90.80
# 21              10           90.80
# 22             NaN           93.00
# 23             NaN           93.00
# 24             NaN             NaN
# 25              90           91.00
# 26              90           91.00
# 27           94.88           96.00
# 28           94.88           96.00
# 29             NaN             NaN
# ..             ...             ...
# 117          94.88           92.70
# 118             10           97.70
# 119          94.16           94.50
# 120          95.33           93.20
# 121          98.08           95.50
# 122             10           96.40
# 123             10           95.20
# 124            8.2           95.80
# 125             89           98.00
# 126          97.28           93.00
# 127          95.66           91.20
# 128             95           97.20
# 129             96           93.30
# 130            9.4           96.00
# 131          98.88           97.50
# 132          98.24           94.50
# 133             10           93.00
# 134          99.52           97.70
# 135             10           97.20
# 136             92           97.50
# 137            9.4           92.20
# 138            9.8           92.00
# 139             99           98.20
# 140          98.24           97.80
# 141            9.6           94.20
# 142          98.54           91.80
# 143            9.6           88.00
# 144          94.56           90.50
# 145           95.5           94.70
# 146             10           90.20
#
#                                                 Awards Branch  CGPA    CTC  \
# 0                                                  NaN    CSE  9.68     18
# 1    Recipient of 6 Distinction Awards in all semes...    CSE  8.83    4.5
# 2    Recipient of 6 Distinction Awards in all semes...    CSE  8.83  12.15
# 3                                                  NaN    CSE  9.27      0
# 4    1st Place at Alcoding Summer Challenge (out of...    CSE  8.95  23.42
# 5                                                  NaN    CSE  8.78   8.36
# 6    Felicitated with Distinction Award for academi...    CSE  9.89      0
# 7    Felicitated with Distinction Award for academi...    CSE  9.89  11.59
# 8    Bagged 13th rank in “Hour Storm #1” organized ...    CSE  9.39     29
# 9    Awarded First Class with Distinction across al...    CSE  9.04  11.59
# 10   Bet to Code - Secured Third Position in the co...    CSE  8.57      0
# 11                                                 NaN    CSE  7.71    4.5
# 12                                                 NaN    CSE  9.90  25.16
# 13                                                 NaN    CSE  9.90    NaN
# 14                                                 NaN    CSE  8.68    NaN
# 15                                                 NaN    CSE  8.68     29
# 16                                                 NaN    CSE  7.30      8
# 17                                                 NaN    CSE  9.22     16
# 18                                                 NaN    CSE  7.71      6
# 19                                                 NaN    CSE  8.64  25.16
# 20                                                 NaN    CSE  9.17  10.35
# 21                                                 NaN    CSE  9.17      0
# 22                                                 NaN    CSE  8.98     16
# 23                                                 NaN    CSE  8.98    NaN
# 24                                                 NaN    CSE  9.52   16.3
# 25                                                 NaN    CSE  8.27      0
# 26                                                 NaN    CSE  8.27  12.75
# 27                                                 NaN    CSE  8.73      8
# 28                                                 NaN    CSE  8.73    6.5
# 29   Institution of Engineering and Technology (IET...    CSE  9.72  12.75
# ..                                                 ...    ...   ...    ...
# 117  3rd price in Mathematics Fest(Mathletics) held...    CSE  8.93   16.8
# 118                                                NaN    CSE  9.10     15
# 119  Distinction awards in all semesters till date....    CSE  9.31   10.3
# 120                                                NaN    CSE  8.94  16.87
# 121                                                NaN    CSE  9.29   9.55
# 122                                                NaN    CSE  9.48     11
# 123                          CNR Rao merit scholarship    ECE  8.54   9.55
# 124                                                NaN    CSE  8.57  25.16
# 125                       Distinction Award for 5 sems    CSE  9.45     27
# 126                                                NaN    ECE  8.69   20.5
# 127  Best Outgoing Student award from BNM Public Sc...    CSE  9.63   18.5
# 128                                                NaN    CSE  9.38     23
# 129                                                NaN    CSE  8.17  22.94
# 130                                                NaN    ECE  6.84
# 131                                                Nil    CSE  9.20      5
# 132                                                NaN    CSE  8.35    7.6
# 133                                                NaN    ECE  8.81      5
# 134                                                NaN    CSE  9.78   16.9
# 135                                  Distinction award    CSE  9.53  13.96
# 136                                                NaN    ECE  9.05   14.3
# 137  Recipient of top 20 percentile scholarship and...    ECE  9.06   9.55
# 138                                                NaN    CSE  8.61     10
# 139                                                NaN    CSE  9.77   11.2
# 140                                                NaN    ECE  8.95     10
# 141                                                NaN    ECE  9.04  14.37
# 142                                                NaN    CSE  8.50   9.55
# 143  - Prof. CNR Rao Merit Scholarship, PES Univers...    ECE  8.26      5
# 144                                                NaN    EEE  8.07
# 145                                                NaN    CSE  9.45     20
# 146                                                NaN    ECE  7.74    7.6
#
#                                CoCcurricularActivities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                               Wildlife#Space#Cricket
# 6    Enthusiastic about travelling, photography, re...
# 7    Enthusiastic about travelling, photography, re...
# 8                                                  NaN
# 9                                                  NaN
# 10   An active member of the Center For Innovation ...
# 11                     Football Player in College Team
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   President of Mathematics Association 2015-16, ...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                                 CoCurricularActivities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 117                                                NaN
# 118                                              Chess
# 119                                                NaN
# 120                                                NaN
# 121                           State Level Chess player
# 122                                                NaN
# 123                                                NaN
# 124                                     Social Service
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                             Video editing, Writing
# 131                                                Nil
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137  Active participant in EWD activities conducted...
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142  Been A active Volunteer at local temple in Vij...
# 143                            Dancing, Poetry Writing
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                                            CompanyName  \
# 0                                         Walmart Labs
# 1                                       TheMathCompany
# 2                                   NXP Semiconductors
# 3              Intuit India Product Development Center
# 4                            Citrix R&D India Pvt Ltd
# 5                       Novarties Healthcare PVt. Ltd.
# 6                                        Cisco Systems
# 7                                                Optum
# 8                                        Cisco Systems
# 9                                                Optum
# 10             Intuit India Product Development Center
# 11                                           Accenture
# 12             Intuit India Product Development Center
# 13                                              Intuit
# 14                                              CISCO
# 15                                       Cisco Systems
# 16   Raramuri Technology Private Limited (website: ...
# 17                             Rupeek Fintech Pvt. Ltd
# 18                                      Enquero Global
# 19             Intuit India Product Development Center
# 20            AirAsia Technology Centre India Pvt. Ltd
# 21                                             LogMeIn
# 22                                             Samsumg
# 23                                         Samsung R&D
# 24                                 Akamai Technologies
# 25                                   IBM INDIA PVT LTD
# 26                                           MathWorks
# 27       APMSE Software Services Pvt. Ltd. (EagleView)
# 28                                           Accenture
# 29                                           MathWorks
# ..                                                 ...
# 117                                Akamai Technologies
# 118                                              Amagi
# 119                         Hewlett Packard Enterprise
# 120                        Akamai Technologies Pvt Ltd
# 121                              Amadeus Software Labs
# 122                 Target Corporation India Pvt. Ltd.
# 123                              Amadeus Software labs
# 124                                             Intuit
# 125                                            Curefit
# 126                                     Analog Devices
# 127                                             Amazon
# 128                                      Goldman Sachs
# 129                                             Citrix
# 130
# 131  Robert Bosch Engineering & Business Solutions ...
# 132                                           Deloitte
# 133                                       ROBERT BOSCH
# 134                                Akamai Technologies
# 135                                Akamai Technologies
# 136                                              CISCO
# 137                             Amadeus Software Labs.
# 138                                            Epsilon
# 139                                       Target India
# 140                                            Epsilon
# 141                                              Cisco
# 142                                       Amadeus Labs
# 143                                      Robert Bosch
# 144
# 145                                              Groww
# 146                                           Deloitte
#
#                                                Courses  ...  Placed  \
# 0    {'Core Courses': [{"{'Code': 'UE15CS101', 'Nam...  ...     NaN
# 1    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 2    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 3    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 4    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 5    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 6    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 7    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 8    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 9    {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 10   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 11   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 12   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 13   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 14   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 15   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 16   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 17   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 18   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 19   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 20   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 21   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 22   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 23   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 24   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...  Placed
# 25   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 26   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 27   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 28   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# 29   {'Core Courses': [{"{'Code': 'UE16CS101', 'Nam...  ...     NaN
# ..                                                 ...  ...     ...
# 117  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 118  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 119  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 120  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 121  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 122  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 123  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 124  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 125  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 126  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 127  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 128  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 129  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 130  {'Core Courses': [{"{'Code': 'UE16EC357AA', 'N...  ...  Placed
# 131  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 132  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 133  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 134  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 135  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 136  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 137  {'Core Courses': [{"{'Code': 'UE16EC357AA', 'N...  ...  Placed
# 138  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 139  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 140  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 141  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 142  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 143  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 144  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 145  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
# 146  {'Core Courses': [{"{'Code': 'UE17CS101', 'Nam...  ...  Placed
#
#                                          ProgLanguages  \
# 0                                     python##c++##c\n
# 1            C##Python ##Java##HTML ##CSS##PHP##MYSQL.
# 2            C##Python ##Java##HTML ##CSS##PHP##MYSQL.
# 3                                                  NaN
# 4          Python##Java##C##JavaScript##HTML##CSS##PHP
# 5    Python# Php# Javascript##CSS## W3.CSS## HTML5#...
# 6         C##Python##Java## HTML##CSS##Javascript##PHP
# 7         C##Python##Java## HTML##CSS##Javascript##PHP
# 8                                               C##C++
# 9    C ##C++##Java ## Python##HTML## CSS##JavaScrip...
# 10                                C##Java##Python##C++
# 11                    C##CSS##Python##Java##JavaScript
# 12   C++##C##Java,##Python##NodeJS## ReactJS##HTML#...
# 13   C++##C##Java,##Python##NodeJS## ReactJS##HTML#...
# 14                                                 NaN
# 15                                                 NaN
# 16                C##C++##Java##HTML##CSS##Java Script
# 17   C++##C##Python##R##NodeJS##PHP##HTML##CSS##Jav...
# 18               C##C++##Python##JavaScript##HTML##CSS
# 19        C##C++##Python##Java##HTML##PHP##JavaScript.
# 20         C##Python##PHP##HTML##CSS##Javascript##Java
# 21         C##Python##PHP##HTML##CSS##Javascript##Java
# 22       C##C++##Python##R##Javascript##Django##OpenCV
# 23       C##C++##Python##R##Javascript##Django##OpenCV
# 24                                                 NaN
# 25                   C##C++(STL)##Python##JAVA,JS,PHP,
# 26                   C##C++(STL)##Python##JAVA,JS,PHP,
# 27                                    C##Python ##JAVA
# 28                                    C##Python ##JAVA
# 29                         Python##C##C++## JavaScript
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                                          ProjectDetail  \
# 0                                                  NaN
# 1    {Selfieless Photo Sharing App:[Cloud Computing...
# 2    {Selfieless Photo Sharing App:[Cloud Computing...
# 3    {Micro-services based website:[ Cloud Computin...
# 4    {Crio Summer Of Doing:[Data Analytics@@Built a...
# 5    {Typing Master:[Web Technology and CloudComput...
# 6    {SelfieLessActs- A cloud based scalable applic...
# 7    {SelfieLessActs- A cloud based scalable applic...
# 8    {Photo-Share:[Cloud Computing@@Built the backe...
# 9    {Compiler Design for C:[Compiler Design@@Devel...
# 10   {Scheduling ML jobs on distributed systems:[Ma...
# 11   {Chat Application:[Web Development@@Developed ...
# 12   {Subgraph Isomorphism:[Data Structures and Alg...
# 13   {Subgraph Isomorphism:[Data Structures and Alg...
# 14                                                 NaN
# 15                                                 NaN
# 16   {SelfieLessActs:[ Cloud Computing@@: A cloud b...
# 17   {:[Cloud Computing@@Set up a container orchest...
# 18   {College Project in Web Technologies:[Web Tech...
# 19   {Selfie-less acts website:[Cloud Computing@@ D...
# 20   {Selfie-less acts website:[Cloud Computing@@ B...
# 21   {Selfie-less acts website:[Cloud Computing@@ B...
# 22   {Recommender System:[ Deep Reinforcement Learn...
# 23   {Recommender System:[ Deep Reinforcement Learn...
# 24                                                 NaN
# 25   {Web Servlet for Banking:[@@ Motivation:Front ...
# 26   {Web Servlet for Banking:[@@ Motivation:Front ...
# 27   {C++ compiler using lex and yacc:[@@ A simple ...
# 28   {C++ compiler using lex and yacc:[@@ A simple ...
# 29   {Youtube Trending Algorithm Analysis:[@@ Studi...
# ..                                                 ...
# 117  {Project_Introduction to Fast Data Structure L...
# 118  {Project_Human Activity Captioning:[Project_Hu...
# 119  {Project_Database as a Service (DBaaS):[Projec...
# 120  {Project_Realtime Event Detection using social...
# 121  {Project_Restaurant automation system :[Projec...
# 122  {Project_MongoDB QoS:[Project_MongoDB QoS_Rese...
# 123  {Project_Diabetic Retinopathy Detection using ...
# 124  {Project_Cloud Based RideShare Application:[Pr...
# 125  {Project_Rideshare API on AWS:[Project_Ridesha...
# 126  {Project_SELF BALANCING MED-BOT BASED ON INVER...
# 127  {Project_Automatic Questionnaire Generation fr...
# 128  {Project_Automated Forensic Artis:[Project_Aut...
# 129  {Project_Image Completion using DCGAN:[Project...
# 130  {Project_Agricultural Automation:[Project_Agri...
# 131  {Project_Classification of Spectrometric Data:...
# 132  {Project_Ml-Tool:[Project_Ml-Tool_Machine lean...
# 133  {Project_Online Voting System using IPv6 addre...
# 134  {Project_Footballer Market Value prediction:[P...
# 135  {Project_ Spam Detection in Hotel review using...
# 136  {Project_Electroencephalogram (EEG) signal bas...
# 137  {Project_Hospital management system:[Project_H...
# 138  {Project_Efficient Seating Allocation:[Project...
# 139  {Project_ Research on Recognition of similar h...
# 140  {Project_FIND INFARCT :[Project_FIND INFARCT _...
# 141  {Project_A deep learning Image classifier for ...
# 142  {Project_Big Integer Library :[Project_Big Int...
# 143  {Project_Smart Shopping Trolley:[Project_Smart...
# 144  {Project_pulse oximeter:[Project_pulse oximete...
# 145  {Project_ride share application:[Project_ride ...
# 146  {Project_Automated Smart Garbage Monitoring Sy...
#
#                                     PublicationDetails  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6    {"Document embedding generation for cyber-aggr...
# 7    {"Document embedding generation for cyber-aggr...
# 8    {"Document embedding generation for cyber-aggr...
# 9                                                  NaN
# 10   {" Cassandra - Quality Of Service ":" Benchmar...
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22   {Recognition of Similar Scripted Language Char...
# 23   {Recognition of Similar Scripted Language Char...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   {Deep Learning on Binary Patterns for Face Rec...
# ..                                                 ...
# 117                                               {:_}
# 118                                               {:_}
# 119  {Software Implementation of an Automatic Movab...
# 120                                               {:_}
# 121                                               {:_}
# 122                                               {:_}
# 123                                               {:_}
# 124                                               {:_}
# 125                                               {:_}
# 126                                               {:_}
# 127  {Automatic questionnaire and interactive sessi...
# 128  {A Paradigmatic Approach to Exploratory Data A...
# 129                                               {:_}
# 130                                               {:_}
# 131                                      {Nil:Nil_Nil}
# 132                                               {:_}
# 133  {”Music Instrument Recognition using Artificia...
# 134                                               {:_}
# 135                                               {:_}
# 136                                               {:_}
# 137                                               {:_}
# 138                                               {:_}
# 139                                               {:_}
# 140                                               {:_}
# 141                                               {:_}
# 142                                               {:_}
# 143                                               {:_}
# 144                                               {:_}
# 145                                               {:_}
# 146                                               {:_}
#
#                                           Scholarships  \
# 0                                                  NaN
# 1    Recipient of CNR Rao Scholarship in the 5th se...
# 2    Recipient of CNR Rao Scholarship in the 5th se...
# 3                                                  NaN
# 4    Prof MRD Scholarship for Academic Excellence, ...
# 5                                                  NaN
# 6    Received the Prof MRD Merit Scholarship for be...
# 7    Received the Prof MRD Merit Scholarship for be...
# 8    Recipient of “CNR RAO Merit Scholarship” ##Bag...
# 9    Recipient of Prof CNR RAO Merit Scholarship(20...
# 10                                                 NaN
# 11                                                 NaN
# 12   University merit-based scholarship holder and ...
# 13   University merit-based scholarship holder and ...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19   Received Prof. C N Rao Merit Scholarship durin...
# 20                  Prof. C.N.R. Rao Merit Scholarship
# 21                  Prof. C.N.R. Rao Merit Scholarship
# 22                  Prof. C.N.R. Rao Merit Scholarship
# 23                  Prof. C.N.R. Rao Merit Scholarship
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   CNR Rao Merit Scholarship winner for academic ...
# ..                                                 ...
# 117                                        CNR Roa (2)
# 118                                                NaN
# 119  PROF. M R DORESWAMY MERIT SCHOLARSHIP AWARD\nH...
# 120                                CNR Rao Scholarship
# 121  Recipient of CNR Rao Scholarship in the 1st, 3...
# 122                                                NaN
# 123                          CNR Rao merit scholarship
# 124                                                NaN
# 125  CNR Rao Merit Scholarship\nMR Doreswamy Merit ...
# 126  CNR and MRD scholarship for 3rd and 5th semest...
# 127  Prof. MRD Merit Scholarship.\nProf CNR Rao Mer...
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131  • Obtained MRD & CNR Rao Merit Scholarship for...
# 132                                                NaN
# 133  CNR Rao Merit Scholarship\nSecured CNR Merit S...
# 134  NTSE - State Scholar\nCNR Rao Merit Scholarshi...
# 135   CNR Scholarship in sem-1,sem-2,sem-3,sem-4,sem-5
# 136  Received Prof. CNR Rao Merit scholarship"s for...
# 137  Recipient of top 20 percentile scholarship and...
# 138  Prof. CNR Rao scholarship award\nDistinction a...
# 139                                CNR Rao scholarship
# 140  CNR Rao Scholarship For being in top 20%  perf...
# 141  Prof. CNR Rao Merit Scholarship: Sem 3\nProf. ...
# 142  Secured Distinction award for top score for al...
# 143                                                NaN
# 144                                                NaN
# 145                                      Huawei , CNR
# 146                                                NaN
#
#                                          SoftwareTools TierLevel  \
# 0                                                  NaN         1
# 1                                                  NaN         2
# 2                                                  NaN         1
# 3                                                  NaN       NaN
# 4                        Flask##Spring##MySQL##MongoDB         1
# 5    Web Scraping ## Ajax##Flask##Photoshop## Light...         1
# 6    MySQL##OpenCV##keras##scikit-learn##matplotlib...       NaN
# 7    MySQL##OpenCV##keras##scikit-learn##matplotlib...         1
# 8                                                  SQL         1
# 9                                        NodeJS##Flask         1
# 10        Cassandra##Spring boot##MongoDB##Mesos##REST       NaN
# 11   Word##Excel##Powerpoint##Angular##Node.js##Exp...         2
# 12                                                 NaN         1
# 13                                                 NaN         1
# 14                                                 NaN         1
# 15                                                 NaN         1
# 16                                                 NaN         1
# 17   Docker##AWS##GCP##SQL##MongoDB##SailJS##Hadoop...         1
# 18   ReactJS, AWS basics, GCP basics, PostGreSQL, M...         2
# 19                                               MySQL         1
# 20                                                 SQL         1
# 21                                                 SQL       NaN
# 22                 AWS##Hadoop##GCP##Zookeeper##Docker         1
# 23                 AWS##Hadoop##GCP##Zookeeper##Docker         1
# 24                                                 NaN         1
# 25                                               Mysql       NaN
# 26                                               Mysql         1
# 27   JavaScript##PHP##MySQL##CSS##BigData##Machine ...         1
# 28   JavaScript##PHP##MySQL##CSS##BigData##Machine ...         2
# 29   Tensorflow##Pytorch##OpenCV##Scikitlearn##Matp...         1
# ..                                                 ...       ...
# 117                                                NaN         1
# 118                                                NaN         1
# 119                                                NaN         1
# 120                                                NaN         1
# 121                                                NaN         1
# 122                                                NaN         1
# 123                                                NaN         1
# 124                                                NaN         1
# 125                                                NaN         1
# 126                                                NaN         1
# 127                                                NaN         1
# 128                                                NaN         1
# 129                                                NaN         1
# 130                                                NaN
# 131                                                NaN         2
# 132                                                NaN         2
# 133                                                NaN         2
# 134                                                NaN         1
# 135                                                NaN         1
# 136                                                NaN         1
# 137                                                NaN         1
# 138                                                NaN         1
# 139                                                NaN         1
# 140                                                NaN         1
# 141                                                NaN         1
# 142                                                NaN         1
# 143                                                NaN         2
# 144                                                NaN
# 145                                                NaN         1
# 146                                                NaN         2
#
#                USN                                   VolunteeringWork  \
# 0     01FB15ECS019                                                NaN
# 1     01FB16ECS002                                                NaN
# 2     01FB16ECS002                                                NaN
# 3     01FB16ECS006                                                NaN
# 4     01FB16ECS012                                                NaN
# 5     01FB16ECS015                                                NaN
# 6     01FB16ECS016                                                NaN
# 7     01FB16ECS016                                                NaN
# 8     01FB16ECS017                                                NaN
# 9     01FB16ECS018                                                NaN
# 10    01FB16ECS023                                                NaN
# 11    01FB16ECS031                                                NaN
# 12    01FB16ECS035                                                NaN
# 13    01FB16ECS035                                                NaN
# 14    01FB16ECS036                                                NaN
# 15    01FB16ECS036                                                NaN
# 16    01FB16ECS037     Organised and volunteered Events of Samarpana.
# 17    01FB16ECS038                                                NaN
# 18    01FB16ECS044                                                NaN
# 19    01FB16ECS050                                                NaN
# 20    01FB16ECS052                                                NaN
# 21    01FB16ECS052                                                NaN
# 22    01FB16ECS056                                                NaN
# 23    01FB16ECS056                                                NaN
# 24    01FB16ECS069                                                NaN
# 25    01FB16ECS072                                                NaN
# 26    01FB16ECS072                                                NaN
# 27    01FB16ECS073                                                NaN
# 28    01FB16ECS073                                                NaN
# 29    01FB16ECS074                                                NaN
# ..             ...                                                ...
# 117  PES1201701525                                                NaN
# 118  PES1201701526                                                NaN
# 119  PES1201701528                                                NaN
# 120  PES1201701532                                                NaN
# 121  PES1201701536  Member of CSR  (Collegiate Social Responsibili...
# 122  PES1201701543                                                NaN
# 123  PES1201701544                                                NaN
# 124  PES1201701545  Core Member for CSR-PESU. Years of Service: 20...
# 125  PES1201701549                                                NaN
# 126  PES1201701556  Volunteered at The Amateur Scientist Competiti...
# 127  PES1201701573                                                NaN
# 128  PES1201701575                                                NaN
# 129  PES1201701576                                                NaN
# 130  PES1201701579                                                NaN
# 131  PES1201701595                                                Nil
# 132  PES1201701597                                        Part of CSR
# 133  PES1201701599                                                NaN
# 134  PES1201701604                                                NaN
# 135  PES1201701615                                                NaN
# 136  PES1201701617                                                NaN
# 137  PES1201701619                                                NaN
# 138  PES1201701621                                                NaN
# 139  PES1201701633                                                NaN
# 140  PES1201701648                                                NaN
# 141  PES1201701651                                                NaN
# 142  PES1201701665                                                NaN
# 143  PES1201701676  Teaching Assistant, 2019 - Control Systems, Dr...
# 144  PES1201701751                                                NaN
# 145  PES1201701809                                                NaN
# 146  PES1201702215                                                NaN
#
#                                              Workshops
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6    Attended workshop on machine learning, image p...
# 7    Attended workshop on machine learning, image p...
# 8                                                  NaN
# 9                                                  NaN
# 10                                              L1 CIE
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119  Presented my work and submitted a research pap...
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126  MyCaptain Workshops, PESU-IO on Rocket Propulsion
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130  An exciting journey of building a $0 - $20 mil...
# 131            1)Citrix Workshop\n2)FACE Prep Workshop
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141  Indian Mobile Congress Lead 2019\nConsensus In...
# 142                                                NaN
# 143  Amazon India Technical Workshop : Writing a Cl...
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
# [193 rows x 34 columns]

# %%
combined_master_1617.to_csv(r'MasterDataset_2016_2017_temp.csv', index = False)
