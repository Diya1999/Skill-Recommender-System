# %%
import pandas as pd 
from itsdangerous import URLSafeSerializer

# %%
data = pd.read_csv(r"C:\Users\diyas\Downloads\MasterDatasetTemp_Preprocessed.csv")

# %%
def encrypt(text,s):
    result = ""
    for i in range(len(text)):
        char = text[i]
        if (char.isupper()):
            result += chr((ord(char) + s-65) % 26 + 65)
        else:
            result += chr((ord(char) + s - 97) % 26 + 97)
    return result
s = 23455

# %%
l1=[]
for i in data['USN']:
    l1.append(encrypt(i,s))
data['USN']=l1

# %%
data
# Out:
#      Unnamed: 0            USN  10thPercentage  10thMarks  12thPercentage  \
# 0             0   ghIEhlHFVghp           96.00  96.000000       90.000000
# 1             1   ghIEhmHFVggi            9.70  92.150000       97.600000
# 2             2   ghIEhmHFVggi            9.70  92.150000       97.600000
# 3             3   ghIEhmHFVggm           95.00  95.000000       96.000000
# 4             4   ghIEhmHFVghi             NaN  93.386967       94.000000
# 5             5   ghIEhmHFVghl            9.40  89.300000       89.360000
# 6             6   ghIEhmHFVghm           95.00  95.000000       95.000000
# 7             7   ghIEhmHFVghm           95.00  95.000000       95.000000
# 8             8   ghIEhmHFVghn           94.20  94.200000       89.200000
# 9             9   ghIEhmHFVgho           94.50  94.500000       94.500000
# 10           10   ghIEhmHFVgij            9.60  91.200000       87.200000
# 11           11   ghIEhmHFVgjh           95.00  95.000000       89.400000
# ...

# %%
data.apply(lambda x: x.astype(str).str.lower())
# Out:
#     Unnamed: 0            USN 10thPercentage          10thMarks  \
# 0            0   ghiehlhfvghp           96.0               96.0
# 1            1   ghiehmhfvggi            9.7              92.15
# 2            2   ghiehmhfvggi            9.7              92.15
# 3            3   ghiehmhfvggm           95.0               95.0
# 4            4   ghiehmhfvghi            nan  93.38696739130435
# 5            5   ghiehmhfvghl            9.4               89.3
# 6            6   ghiehmhfvghm           95.0               95.0
# 7            7   ghiehmhfvghm           95.0               95.0
# 8            8   ghiehmhfvghn           94.2               94.2
# 9            9   ghiehmhfvgho           94.5               94.5
# 10          10   ghiehmhfvgij            9.6               91.2
# 11          11   ghiehmhfvgjh           95.0               95.0
# 12          12   ghiehmhfvgjl          94.83              94.83
# 13          13   ghiehmhfvgjl          94.83              94.83
# ...

# %%
data.to_csv(r'MasterDatasetTemp_Preprocessed_Anonymized_small.csv')
