# %%
#pdf to text
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

# %%
def convertPDFtoText(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    string = retstr.getvalue()
    retstr.close()
    return string

# %%
#printing all filenames
import glob
for filename in glob.iglob(r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory" + '**/*', recursive=True):
     print(filename)
# Out:
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\00-Kaveri.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01fb15ecs001.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS004.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS008.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS010.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS017.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS018.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS021.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS027.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS028_UPDATED.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\01FB15ECS029.pdf
# ...

# %%
#getting a list of the text forms of resumes
import os

path = r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory"
l=[]
#f=open("resumes.txt","a",encoding="utf-8")
# Read every file in directory
for filename in os.listdir(path):
        t=r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\"+filename
        try:
            s = convertPDFtoText(t)
        #print(s)
        #print("----------------------------------------------------------------------------------------------------------")
            l.append(s)
        except:
            print(t)
# Out:
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS095.docx
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS100.docx
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS100_20190116210350.docx
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS161.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS218_(1).zip
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS270_SaudaminiKhare.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS292.docx
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS334.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS338.pdf
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS348.docx
# C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS359.docx
# ...

# %%
p=r"""C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS095.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS100.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS100_20190116210350.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS161.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS218_(1).zip
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS270_SaudaminiKhare.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS292.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS334.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS338.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS348.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS359.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECS909.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15ECV022.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC017.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC023.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC054.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC153.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC169.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01fb15eec180.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC195.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC205.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC217.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC258.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEC275.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE015.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE015_20190114225032.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE015_20190114225529.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE015_20190116214843.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE015_20190117103800.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE018.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EEE411.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EME053.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EME058.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EME058.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB15EME149.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB16ECS708.zip
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01FB16ECS713.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\01fb16eme700.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\1547656442349_SHIVU.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\170769.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\1_NAHUSHA_B_G_BE(ME).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\20488.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\5CD6A92F-DA09-4DDC-92D9-7A6E1AA81B91.jpeg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\70233958_1546847243639.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\76452879-5DA6-4CDD-B558-8A625F5EDE92.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\85028F5F-BC88-4F45-8A6D-45D0CCDF2932.jpeg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\a4-size-paper-sheet-500x500.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Abhishek_CV_15_oct_2018.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Aditya_Ramesh-CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\AISHWARYA_M.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Aiswarya_AM_new.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\AJITH_KUMAR_B_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\akshay_new_resume_(1)_(1)_(1).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Akshay_Udayashankar_CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Aman_Resume_(3).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Aman_Resume_(3)_20190116232830.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ANGEL_GEORGE.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Anirudh_CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\anishsridharan_resume_(1).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\annis.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ANUSHA__R_PAI_CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ANUSHKA_NARENDRAN_RESUME.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\APARNA_BHAT_RESUME_1.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\APARNA_BHAT_RESUME_1_20190109124444.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\APARNA_BHAT_RESUME_1_20190109125509.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\APARNA_BHAT_RESUME_1_20190112114933.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ARCHIT_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Ashika_V_Shetty_CV.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ASHOKA_L_____resume___________________.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ashu.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ashwin_-_ebiodata.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\banu_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Blank.pages
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\B_Vidya(Resume)_final.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\chaitu_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\charan_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CURRICULUM_VITAE_final_mv.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV-Heeba_Anjum.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Cv.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV2_0.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\cvkavya.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CVNeethu.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CVNeethu_20190114153455.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV_20190111223545.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV_20190114104222.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV_20190116175129.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV_FINAL.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\CV_Saarika.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\dechu.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Deepa-resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Deepthi_M_Rao.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\DOC-20190117-WA0007.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\E849228C-B2CE-470A-8A20-A2657182CCD6.jpeg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\FpersonalresumeMINOR.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Gauthiii_DN_(1).doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Gayathri_new_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Guru_Prasad_Patro_P_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\HARIKIRAN_C.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Harikrihsna_rajesh_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Harikrihsna_rajesh_Resume_20190114232457.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Harishankar_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\hema_resume_1.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\image.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\image_20190116171533.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\IMG_20190121_092852.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Karishma_Mehta_resume_2018.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Kartik_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Kartik_Resume_20190109124144.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Kartik_Resume_20190109134553.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Kartik_Resume_20190109135229.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Kartik_Resume_20190109205225.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Karun's_Resume_.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Keerthana_CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\KULASHEKAR_B.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\MALLik12.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\manjubresume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\myresume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\My_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\My_Resume_20190117114701.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\My_Resume_20190117121707.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Nainika_R__Placement.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Nainika_R__Placement_20190116175510.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\narendra_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\NEWSRIVANIRESUME_(1).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\New_Doc_2019-01-18_09_30_20_1.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\New_Text_Document.txt
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Nikhil_latestresume.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\NiveditaLohar_CV.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\PARITALA_MANJU_SUBHASH.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\PARITALA_MANJU_SUBHASH_20190117125358.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\pesuresume.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\pl.txt
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\pooja_resume.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Prajeet_RESUME.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\PreethamDheeraj_InternshalaResume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\PuneetAcharya_Resume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\P_KOMAL_BE(ME).doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RahulDagliya_InternshalaResume_(1).pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ravi_resume[12]_11.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume-_Quick_Hash.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume.txt
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume01FB15EEC015.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME2_pdf.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_(1).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_(5).docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_-_01FB15EEC089.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_-_Arvind_V.DOCX
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_-_Arvind_V_20190112065751.DOCX
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_-_Arvind_V_20190112065816.DOCX
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_20190108191214.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_20190108191218.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190111153032.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190111175446.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190111234524.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190111235941.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190112000246.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190112143426.txt
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190112164809.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190112180602.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190113192357.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190114153751.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190114162448.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190114211918.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190116153625.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116173032.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116194907.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116211125.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116211228.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116213827.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116215510.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_20190116235331.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_20190117134745.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_20190119045526.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_abhishek.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Anusha.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_FINAL.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_final.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_for_8th_semester_project_Nagaraja.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\resume_himanshu.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME_NEW-2018.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Sameer_December_2018.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Tom.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_updated.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_V1.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108214050.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108214100.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108214109.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108215134.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108221855.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108222049.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Resume_Vinolia_20190108222202.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUME__2.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RESUMUPD.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\rN_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\RRR.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\rsz_1screen_shot_2015-01-10_at_64214_pm.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SACHIN_GHANTI[1].docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sahiba_Singh_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sai_Subathra_Anbarasu_Resume_2018.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sandesh_Joshi_ECE.doc
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Screenshot_2019-01-14-17-17-50-950_com_android_browser.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Screenshot_2019-01-17-18-14-30-689_com_microsoft_office_word.png
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Screenshot_20190114-145645.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Screenshot_20190116-171322.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Screenshot_20190117_115735.jpg
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SHALINI_V__resumedocx.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ShashwatAnant_resume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Shivam_RESUME__(2017)_.pages
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SHREEKRISHNA_P_PUTHANE.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ShreyasAinapur-131_InternshalaResume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SHREYAS_MR.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Shreya_Resume_2018(it)docx.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\shridatta_resume_sample.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SHUBHAM_PATIL_resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\SiriRavi_InternshalaResume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sri(RESUME)_S_.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ssssssssssssssssssssssssssss.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\ssssssssssssssssssssssssssss_20190116114801.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sukanta_8_94_No.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Sumedh_Resume.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Taarini-CV.docx
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\TarunBantanahalResume.pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\temp.java
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\UpanshuSingh_InternshalaResume_(1).pdf
C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory\\Vatsal_Mehta.docx""" 

import docx

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        txt = para.text.encode('ascii', 'ignore')
        fullText.append(txt)
    return '\n'.join(fullText)

j=1
path = r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory1"
for i in l:
    f=open(r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory1\text"+str(j)+".txt","w",encoding="utf-16")
    f.write(i)
    j=j+1
    
j=1
doc_complete=[]
for i in l:
    f=open(r"C:\Users\diyas\Desktop\Recommendation_system\ResumeFileDirectory1\text"+str(j)+".txt","r",encoding="utf-16")
    doc_complete.append(f.read())
    j=j+1
print(len(doc_complete))

import docx2txt

for i in p.split():
    if Document(i):
        my_text = gettext(i)
        doc_complete.append(my_text)
# Out:
#   File "<ipython-input-203-75abf8780eb4>", line 259
#     if Document(i)
#                   ^
# SyntaxError: invalid syntax

# %%
import nltk
nltk.download('punkt')



#removing duplicates
doc_complete=set(doc_complete)
print(len(doc_complete))
doc_complete=list(doc_complete)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\diyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 751

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
from nltk.stem.porter import *
stemmer = PorterStemmer()    
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('wordnet')

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

processed_docs = []

for doc in doc_complete:
    processed_docs.append(preprocess(doc))
dictionary = corpora.Dictionary(processed_docs)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\diyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
document_num = 20
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 14 ("bangalor") appears 1 time.
# Word 16 ("base") appears 3 time.
# Word 27 ("cgpa") appears 1 time.
# Word 32 ("commun") appears 1 time.
# Word 37 ("cours") appears 1 time.
# Word 39 ("data") appears 6 time.
# Word 44 ("design") appears 2 time.
# Word 46 ("educ") appears 2 time.
# Word 48 ("email") appears 1 time.
# Word 50 ("engin") appears 3 time.
# Word 54 ("final") appears 1 time.
# Word 57 ("gmail") appears 1 time.
# Word 69 ("intern") appears 2 time.
# Word 76 ("learn") appears 4 time.
# Word 80 ("manag") appears 1 time.
# Word 87 ("model") appears 3 time.
# Word 89 ("music") appears 2 time.
# Word 91 ("nation") appears 2 time.
# Word 93 ("onlin") appears 3 time.
# Word 100 ("perform") appears 1 time.
# Word 103 ("phone") appears 1 time.
# Word 108 ("problem") appears 1 time.
# Word 113 ("profici") appears 2 time.
# Word 115 ("project") appears 8 time.
# Word 117 ("public") appears 2 time.
# Word 118 ("python") appears 2 time.
# Word 130 ("school") appears 2 time.
# ...

# %%
"""lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,
                                   passes = 1,
                                   workers = 2)"""
Lda = gensim.models.ldamodel.LdaModel

ldamodel = Lda(bow_corpus, num_topics=8, id2word = dictionary, passes=50)

# %%
"""for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")"""
print(ldamodel.print_topics(num_topics=8, num_words=1))
# Out:
# [(0, '0.015*"data" + 0.011*"project"'), (1, '0.014*"univers" + 0.012*"design"'), (2, '0.016*"univers" + 0.014*"project"'), (3, '0.013*"analysi" + 0.010*"program"')]

# %%
#LSA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline

# %%
vectorizer = TfidfVectorizer(stop_words='english', 
                             use_idf=True, 
                             smooth_idf=True)

# %%
svd_model = TruncatedSVD(n_components=100,algorithm='randomized',n_iter=10)

# %%
svd_transformer = Pipeline([('tfidf', vectorizer), 
                            ('svd', svd_model)])

# %%
svd_matrix = svd_transformer.fit_transform(doc_complete)

# %%
svd_matrix
# Out:
# array([[ 0.28098863,  0.11957853, -0.12863594, ..., -0.1028072 ,
#          0.00724127, -0.02779979],
#        [ 0.21874176,  0.10491851, -0.01804971, ..., -0.03709825,
#         -0.00374971,  0.04980593],
#        [ 0.14740548,  0.15568945,  0.08385544, ..., -0.0555683 ,
#          0.00213765,  0.01286916],
#        ...,
#        [ 0.23773099,  0.08607523, -0.15457168, ..., -0.08089731,
#         -0.04513187,  0.0509437 ],
#        [ 0.24445876,  0.13017563,  0.09570772, ...,  0.0267332 ,
#          0.04697704,  0.00283109],
#        [ 0.33238015,  0.11881597, -0.05285768, ...,  0.01024839,
#          0.01358863, -0.00894199]])

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)

svd_model.fit(svd_matrix)

len(svd_model.components_)
# Out:
# 20

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
    print("Topic "+str(i)+": ")
    for t in sorted_terms:
        print(t[0])
        print(" ")
# Out:
# Topic 0:
# 00
#
# 000
#
# 0001
#
# 003
#
# 0068stone
#
# 01fb15eme142
#
# 01fb15ecs057
#
# Topic 1:
# 000
#
# 0001
#
# 00027
#
# 0068stone
#
# 01fb15eec299
#
# 01fb15eme142
#
# 003
#
# Topic 2:
# 0001
#
# 000882
#
# 003
#
# 006a22147
#
# 01fb15ecs031
#
# 015
#
# 01fb15ecs217
#
# Topic 3:
# 00027
#
# 0001
#
# 000882
#
# 001
#
# 01fb15eec299
#
# 007k
#
# 01fb15ecs217
#
# Topic 4:
# 000882
#
# 002
#
# 007k
#
# 0050
#
# 000
#
# 003
#
# 01fb16ecs701
#
# Topic 5:
# 001
#
# 003
#
# 000882
#
# 0050
#
# 0068stone
#
# 002
#
# 007k
#
# Topic 6:
# 002
#
# 0050
#
# 006a22147
#
# 000
#
# 00027
#
# 01fb15ecs031
#
# 01fb15eec299
#
# Topic 7:
# 003
#
# 0050
#
# 002
#
# 0068stone
#
# 006a22147
#
# 01fb15ecs259
#
# 01
#
# Topic 8:
# 0050
#
# 007k
#
# 006a22147
#
# 01
#
# 01fb15ecs259
#
# 01fb15ecs190
#
# 015
#
# Topic 9:
# 0068stone
#
# 0050
#
# 015
#
# 002
#
# 01fb15eec154
#
# 01fb15ecs259
#
# 00027
#
# Topic 10:
# 006a22147
#
# 007k
#
# 015
#
# 01fb15ecs031
#
# 01fb15eme127
#
# 01fb15eec171
#
# ...

# %%
#LSA 
import os.path
from gensim import corpora
from gensim.models import LsiModel
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

def preprocess_data(doc_set):
    """
    Input  : docuemnt list
    Purpose: preprocess text (tokenize, removing stopwords, and stemming)
    Output : preprocessed text
    """
    # initialize regex tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # create English stop words list
    en_stop = set(stopwords.words('english'))
    # Create p_stemmer of class PorterStemmer
    p_stemmer = PorterStemmer()
    # list for tokenized documents in loop
    texts = []
    # loop through document list
    for i in doc_set:
        # clean and tokenize document string
        raw = i.lower()
        tokens = tokenizer.tokenize(raw)
        # remove stop words from tokens
        stopped_tokens = [i for i in tokens if not i in en_stop]
        # stem tokens
        stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
        # add tokens to list
        normalized=[i for i in stemmed_tokens if len(i)>3]
        texts.append(stemmed_tokens)
    return texts

# %%
def prepare_corpus(doc_clean):
    # Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
    dictionary = corpora.Dictionary(doc_clean)
    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    # generate LDA model
    return dictionary,doc_term_matrix

# %%
def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
    print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

# %%
def compute_coherence_values(dictionary, doc_term_matrix, doc_clean, stop, start=2, step=3):
    """
    Input   : dictionary : Gensim dictionary
              corpus : Gensim corpus
              texts : List of input texts
              stop : Max num of topics
    purpose : Compute c_v coherence for various number of topics
    Output  : model_list : List of LSA topic models
              coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, stop, step):
        # generate LSA model
        model = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=doc_clean, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# %%
def plot_graph(doc_clean,start, stop, step):
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    model_list, coherence_values = compute_coherence_values(dictionary, doc_term_matrix,doc_clean,
                                                            stop, start, step)
    # Show graph
    x = range(start, stop, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()

# %%
number_of_topics=7
words=10
clean_text=preprocess_data(doc_complete)
model=create_gensim_lsa_model(clean_text,number_of_topics,words)
# Out:
# [(0, '0.578*"e" + 0.393*"n" + 0.332*"r" + 0.262*"c" + 0.188*"l" + 0.174*"p" + 0.156*"g" + 0.155*"u" + 0.147*"h" + 0.122*"use"'), (1, '0.293*"use" + -0.239*"e" + 0.232*"year" + -0.228*"n" + -0.179*"r" + 0.178*"univers" + 0.168*"2017" + 0.163*"design" + 0.152*"pe" + 0.147*"2018"'), (2, '-0.376*"year" + 0.182*"use" + 0.181*"program" + -0.169*"complet" + 0.155*"system" + 0.151*"analysi" + -0.148*"knowledg" + -0.139*"role" + 0.124*"2018" + 0.117*"flow"'), (3, '-0.298*"analysi" + -0.298*"flow" + -0.230*"taint" + -0.219*"constraint" + -0.202*"program" + -0.174*"assign" + -0.165*"untaint" + -0.138*"call" + 0.127*"2018" + -0.125*"variabl"'), (4, '-0.368*"use" + 0.221*"engin" + -0.214*"data" + 0.214*"2018" + 0.155*"2016" + 0.154*"2017" + 0.152*"pe" + -0.152*"implement" + 0.149*"mechan" + 0.148*"design"'), (5, '0.382*"2018" + 0.221*"hackathon" + -0.185*"univers" + -0.178*"engin" + -0.163*"school" + -0.154*"pe" + 0.151*"iot" + 0.150*"2017" + 0.142*"use" + 0.139*"design"'), (6, '-0.196*"school" +
# ...

# %%
start,stop,step=2,12,1
plot_graph(clean_text,start,stop,step)

# %%
import re
from nltk.util import ngrams

doc_complete[45]=doc_complete[45].lower()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', doc_complete[45])
tokens = [token for token in s.split(" ") if token != ""]
output = list(ngrams(tokens, 5))

# %%
output
# Out:
# [('sadhya', 'achanta', '\n\nplot', '40', 'upkar'),
#  ('achanta', '\n\nplot', '40', 'upkar', 'greenfields'),
#  ('\n\nplot', '40', 'upkar', 'greenfields', 'attibele'),
#  ('40', 'upkar', 'greenfields', 'attibele', '\nbangalore'),
#  ('upkar', 'greenfields', 'attibele', '\nbangalore', '562107'),
#  ('greenfields', 'attibele', '\nbangalore', '562107', '\nkarnataka'),
#  ('attibele', '\nbangalore', '562107', '\nkarnataka', '\nindia'),
#  ('\nbangalore', '562107', '\nkarnataka', '\nindia', '\n'),
#  ('562107', '\nkarnataka', '\nindia', '\n', '91'),
#  ('\nkarnataka', '\nindia', '\n', '91', '7760010099'),
#  ('\nindia', '\n', '91', '7760010099', '\nsadhya'),
#  ('\n', '91', '7760010099', '\nsadhya', '97'),
#  ('91', '7760010099', '\nsadhya', '97', 'gmail'),
#  ('7760010099', '\nsadhya', '97', 'gmail', 'com'),
#  ('\nsadhya', '97', 'gmail', 'com', '\n\n'),
#  ('97', 'gmail', 'com', '\n\n', '\n\npersonal'),
#  ('gmail', 'com', '\n\n', '\n\npersonal', 'profile'),
# ...

# %%
#text extraction
import nltk
nltk.download('averaged_perceptron_tagger')
  
def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document) 
    sentences = [nltk.word_tokenize(sent) for sent in sentences] 
    sentences = [nltk.pos_tag(sent) for sent in sentences] 
    return(sentences)

tagged=(ie_preprocess(doc_complete[3]))
tagged=list(tagged)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\diyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
tokens = nltk.word_tokenize(doc_complete[3])
tagged = nltk.pos_tag(tokens)
tagged[0:6]
# Out:
# [('RESUME', 'NNP'),
#  ('Mobile', 'NNP'),
#  (':', ':'),
#  ('+91-8861262027', 'JJ'),
#  ('rajeshwari3036', 'NN'),
#  ('@', 'NNP')]

# %%
import nltk
nltk.download('words')
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\diyas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
# ...

# %%
import nltk
nltk.download('treebank')
from nltk.corpus import treebank
t = treebank.parsed_sents('wsj_0001.mrg')[0]
t.draw()
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\diyas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.

# %%
cp = nltk.RegexpParser(grammar)
result = cp.parse(entities) 
print(result) 
result.draw()
# Out:
# (S
#   (ORGANIZATION RESUME/NNP)
#   Mobile/NNP
#   :/:
#   (NP +91-8861262027/JJ rajeshwari3036/NN)
#   @/NNP
#   (NP gmail.com/NN)
#   (ORGANIZATION RAJESHWARI/NNP)
#   D/o/NNP
#   Rupla/NNP
#   (PERSON Jadhav/NNP)
#   (ORGANIZATION OBJECTIVES/NNP)
#   A/NNP
#   challenging/VBG
#   (NP career/NN)
#   which/WDT
#   provides/VBZ
#   (NP an/DT opportunity/NN)
#   for/IN
#   developing/VBG
#   innovative/JJ
#   applications/NNS
#   using/VBG
#   evolving/VBG
#   technologies/NNS
#   and/CC
#   (NP an/DT exposure/NN)
#   to/TO
#   learn/VB
#   new/JJ
#   exciting/VBG
#   skills/NNS
#   ./.
#   (ORGANIZATION EDUCATIONAL/NNP)
#   PROFILE/NNP
#   QUALIFICATION/NNP
#   INSTITUTION/NNP
#   AFFILIATED/NNP
#   TO/NNP
#   YEAR/NNP
#   PERCENTAGE/NNP
#   B.E/NNP
#   (/(
#   (ORGANIZATION Electronics/NNP)
#   &/CC
#   (NP communication/NN)
#   )/)
#   (ORGANIZATION PES/NNP University/NNP Bengaluru/NNP)
#   (ORGANIZATION PES/NNP University/NNP)
#   (/(
#   (ORGANIZATION Autonomous/NNP)
#   )/)
# ...
