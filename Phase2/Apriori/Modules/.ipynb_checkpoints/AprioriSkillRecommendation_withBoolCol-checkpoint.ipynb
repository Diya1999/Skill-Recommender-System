# %%
import pandas as pd
import time
import numpy as np
import json
from nltk import ngrams
from sklearn.feature_extraction import text
from itsdangerous import URLSafeSerializer
import hashlib
import operator
import itertools
from itertools import combinations, chain
import import_ipynb
import EntropyBasedItemsetGenerationModule as entropy

# %%
class PreprocessApriori:
    def __init__(self, masterData, softwareToolGroupDict, columns,list_var):
        self.masterData = masterData
        self.softwareToolGroupDict = softwareToolGroupDict
        self.columns = columns
        self.list_var=list_var
    
    def getSubsetNotNA(self, df, columnName):
        data = df.copy()
        data = data[data[columnName].notna()]
        return data
        
    def getSubsetForApriori(self, df, columnName, columnvalue):
        df.dropna(subset=[columnName], inplace=True)
        data = df.loc[df[columnName] == columnValue]
        return data
        
    def preprocessSoftwareToolsGroup(self, df, groups):
        data = df.copy()
        var = 'SoftwareTools'
        data[var]=data[var].str.split('##')
        for i,v in data.iterrows():
            #print(data['SoftwareTools'][i])
            l=[]
            if(isinstance(v[var],list)):
                for k in v['SoftwareTools']:
                    if(k!=''):
                        t=k.rstrip("\n")
                        h=t.strip()
                        #print(h)
                        l.append(h.lower())
            data['SoftwareTools'][i]=l
            
        for i,v in data.iterrows():
            l=[]
            for k in v['SoftwareTools']:
                if(k in groups['l1']):
                    l.append("Adobe")
                if(k in groups['l2']):
                    l.append("Cloud Computing and Big Data")
                if(k in groups['l3']):
                    l.append("Python tools")
                if(k in groups['l4']):
                    l.append("Microsoft Tools")
                if(k in groups['l5']):
                    l.append("DBMS Tools")
                if(k in groups['l6']):
                    l.append("Machine Learning Tools")
                if(k in groups['l7']):
                    l.append("Computer Network")
            l_str = '##'.join(l)
            data['SoftwareTools'][i]=l_str
        return data
    
    def preprocessTier(self,data):
        data['TierLevel']=data['TierLevel'].replace(to_replace ="1.0",value ="1")
        data['TierLevel']=data['TierLevel'].replace(to_replace ="2.0",value ="2")
        data['TierLevel']=data['TierLevel'].replace(to_replace ="3.0",value ="3")
        return data
    
    def columnwiseItemPreprocess(self,data,columns):
        df=data.copy()
        for column in columns:
            #print(column)
            if(isinstance(df[column][1],str)):
                df[column]=df[column].str.strip('##').str.split('##')
                for i,v in df.iterrows():
                    l=[]
                    #print(v)
                    #print(type(v[column]))
                    if(isinstance(v[column],list)):
                        for k in v[column]:
                            #print(k)
                            if(k!=''):
                                l.append(column+"_"+k)
                    #print(l)
                    df[column][i]=l
        return df
    
    def columnwiseItemGeneration(self,data,columns):
        df=data.copy()
        df['combinedItems_noCourse']=np.empty((len(df), 0)).tolist()
        for i,v in df.iterrows():
            l=df['combinedItems_noCourse'][i]
            for column in columns:
                #print(v)
                #print(type(v[column]))
                if(isinstance(v[column],list)):
                    l=l+v[column]
            #print(l)
            df['combinedItems_noCourse'][i]=l
        return df
    
    def allColumnsItemGeneration(self, df, columnName, columnValue, gradeColumnName, courseColumnName, addCourses = True):
        data_full = df.copy()
        self.generateValidCoursesItem(data_full, columnName, columnValue, gradeColumnName, courseColumnName)
        data_full1 = self.getSubsetNotNA(df, columnName)
        data_full1 = self.preprocessTier(data_full1)
        data_full2 = data_full1.merge(self.validCoursesData.drop_duplicates(subset=['USN']), how ='left')
        data_main = self.getSubsetForApriori(data_full2, columnName, columnValue)
        dataPreProcess = self.preprocessSoftwareToolsGroup(data_main, self.softwareToolGroupDict)
        dataPreProcess1 = self.columnwiseItemPreprocess(dataPreProcess, self.columns)
        dataPreProcess2 = self.columnwiseItemGeneration(dataPreProcess1, self.columns)
        if(addCourses):
            dataPreProcess2['combinedItemset'] =  dataPreProcess2['ValidCourses'] + dataPreProcess2['combinedItems_noCourse']
        else:
            dataPreProcess2['combinedItemset'] =  dataPreProcess2['combinedItems_noCourse']
        dataPreProcess2=dataPreProcess2.rename({'ExternalCertificatesKey,ExternalCertificatesDomain,WorkshopsOrg,WorkshopsDomain,PublicationNLP': 'OffCampusLearning', 'GeneralSkillsNLP,VolunteeringWork,CoCurricularActivitiesNLP,LanguagesNLP': 'NonAcademicSkills'}, axis=1) 
        return dataPreProcess2
    
    def allColumnsItemGenerationBoolColumn(self, df, columnName, columnValue, gradeColumnName, courseColumnName, addCourses = True):
        data_full = df.copy()
        self.generateValidCoursesItem(data_full, columnName, columnValue, gradeColumnName, courseColumnName)
        data_full1 = self.getSubsetNotNA(df, columnName)
        data_full1 = self.preprocessTier(data_full1)
        data_full2 = data_full1.merge(self.validCoursesData.drop_duplicates(subset=['USN']), how ='left')
        data_main = self.getSubsetForApriori(data_full2, columnName, columnValue)
        dataPreProcessBoolColumn=self.getColumnBoolVal(data_main,self.list_var)
        #dataBool1=self.renameBoolColumns(dataPreProcessBoolColumn)
        boolColumns=self.boolGetListOfColumns(self.columns)
        print(boolColumns)
        print("--------------------------------------")
        #print(dataBool1.columns)
        #dataBool2=self.boolColumnItemPreprocess(dataBool1)
        dataPreProcess = self.preprocessSoftwareToolsGroup(dataPreProcessBoolColumn, self.softwareToolGroupDict)
        dataPreProcess1 = self.columnwiseItemPreprocess(dataPreProcess, boolColumns)
        dataPreProcess2 = self.columnwiseItemGeneration(dataPreProcess1, boolColumns)
        if(addCourses):
            dataPreProcess2['combinedItemset'] =  dataPreProcess2['ValidCourses'] + dataPreProcess2['combinedItems_noCourse']
        else:
            dataPreProcess2['combinedItemset'] =  dataPreProcess2['combinedItems_noCourse']
        dataPreProcess2=dataPreProcess2.rename({'ExternalCertificatesKey,ExternalCertificatesDomain,WorkshopsOrg,WorkshopsDomain,PublicationNLP': 'OffCampusLearning', 'GeneralSkillsNLP,VolunteeringWork,CoCurricularActivitiesNLP,LanguagesNLP': 'NonAcademicSkills'}, axis=1) 
        return dataPreProcess2
        
    def generateValidCoursesItem(self, data, columnName, columnValue, gradeColumnName, courseColumnName):
        obj = entropy.EntropyBasedItemset(data)
        self.validCoursesData = obj.getOptimalGradeForAllCourses(data, columnName, columnValue, gradeColumnName, courseColumnName)
        self.optimal10thMarks = obj.getEntropy10th(data, columnName, columnValue)
        self.optimal12thMarks = obj.getEntropy12th(data, columnName, columnValue)
    
    def getOptimal10thMarks(self):
        return self.optimal10thMarks
    
    def getOptimal10thMarks(self):
        return self.optimal12thMarks
    
    def getValidCoursesItemset(self):
        return self.validCoursesData
    
    def addColumnBool(self,df,var):
        t=""
        t=",".join(var)
        if(len(var)>1):
            listofcols = var
            df[t] = ''  
            for column in listofcols:     
                df[t] = df[t] + ' ' + df[column]
            var=t
        else:
            var=var[0]
        t=t+"_present"
        t=self.renameBoolColumns(t)
        df[var] = df[var].str.replace(" ", '', regex=True)
        df1 = df.replace(np.nan, '', regex=True)
        df1[t]=""
        for index, row in df1.iterrows():
            l=[]
            if(len(row[var])>0):
                l.append(t)
                df1[t][index]=l
            else:
                df1[t][index]=l
        return df1
    
    def getColumnBoolVal(self,data,list_var):
        df=data.copy()
        for var in list_var:
            df=self.addColumnBool(df,var)
        return df
    
    def boolColumnItemPreprocess(self,data):
        df = data.copy()
        for column in self.boolColumns:
            print(column)
            if(isinstance(df[column][1],(int,np.integer))):
                print(column)
                for i,v in df.iterrows():
                    l=[]
                    if(v[column]==1):
                        l.append(column)
                    df[column][i]=l
        return df
   
    def boolGetListOfColumns(self, columns):
        self.boolColumns = columns[:]
        if('SoftwareTools' in self.boolColumns):
            self.boolColumns.remove('SoftwareTools')
            self.boolColumns.append('SoftwareTools_present')
        if('ProgLanguagesNLP' in self.boolColumns):
            self.boolColumns.remove('ProgLanguagesNLP')
            self.boolColumns.append('ProgLanguagesNLP_present')
        if('CoCurricularActivitiesNLP' in self.boolColumns):
            if('NonAcademicSkills_present' not in self.boolColumns):
                self.boolColumns.append('NonAcademicSkills_present')
            self.boolColumns.remove('CoCurricularActivitiesNLP')
        if('GeneralSkillsNLP' in self.boolColumns):
            if('NonAcademicSkills_present' not in self.boolColumns):
                self.boolColumns.append('NonAcademicSkills_present')
            self.boolColumns.remove('GeneralSkillsNLP')
        if('LanguagesNLP' in self.boolColumns):
            if('NonAcademicSkills_present' not in self.boolColumns):
                self.boolColumns.append('NonAcademicSkills_present')
            self.boolColumns.remove('LanguagesNLP')
        if('VolunteeringWork' in self.boolColumns):
            if('NonAcademicSkills_present' not in self.boolColumns):
                self.boolColumns.append('NonAcademicSkills_present')
            self.boolColumns.remove('VolunteeringWork')
        if('ExternalCertificatesKey' in self.boolColumns):
            if('OffCampusLearning_present' not in self.boolColumns):
                self.boolColumns.append('OffCampusLearning_present')
            self.boolColumns.remove('ExternalCertificatesKey')
        if('ExternalCertificatesDomain' in self.boolColumns):
            if('OffCampusLearning_present' not in self.boolColumns):
                self.boolColumns.append('OffCampusLearning_present')
            self.boolColumns.remove('ExternalCertificatesDomain')
        if('WorkshopsDomain' in self.boolColumns):
            if('OffCampusLearning_present' not in self.boolColumns):
                self.boolColumns.append('OffCampusLearning_present')
            self.boolColumns.remove('WorkshopsDomain')
        if('WorkshopsOrg' in self.boolColumns):
            if('OffCampusLearning_present' not in self.boolColumns):
                self.boolColumns.append('OffCampusLearning_present')
            self.boolColumns.remove('WorkshopsOrg')
        if('PublicationNLP' in self.boolColumns):
            if('OffCampusLearning_present' not in self.boolColumns):
                self.boolColumns.append('OffCampusLearning_present')
            self.boolColumns.remove('PublicationNLP')
        return self.boolColumns
   
    def renameBoolColumns(self, colName):
        if(colName=='ExternalCertificatesKey,ExternalCertificatesDomain,WorkshopsOrg,WorkshopsDomain,PublicationNLP_present'):
            return 'OffCampusLearning_present'
        elif(colName=='GeneralSkillsNLP,VolunteeringWork,CoCurricularActivitiesNLP,LanguagesNLP_present'):
            return 'NonAcademicSkills_present'
        else:
            return colName

# %%
#MODULAR VERSION: 
class Apriori:
    def __init__(self, data, alpha, ls):
        self.data = data
        self.alpha = alpha
        self.ls = ls
        
    def findsubsets(self, uniqueItems, listFormattedPreviousRules, n):
        #return list(map(set, itertools.combinations(s, n)))
        #find combination the first time for all unique items 
        if(len(listFormattedPreviousRules)==0):
            return list(itertools.combinations(uniqueItems, n))
        else:
            #print("In combo")
            return self.getValidCombinations(uniqueItems, listFormattedPreviousRules, n)
        
    def getValidCombinations(self, uniqueItems, listFormattedPreviousRules, n):
        #print("\n\n\nin get valid combis\n\n\n")
        validCombinations = []
        for item in uniqueItems:
            for rule in listFormattedPreviousRules:
                if(item not in rule):
                    if(self.isCombinationValid(item, rule, listFormattedPreviousRules)):
                        temp =[]
                        temp.append(item)
                        l = rule + temp
                        l.sort()
                        validCombinations.append(tuple(l))
        return list(set(validCombinations))
          
    def isCombinationValid(self, item, rule, listFormattedPreviousRules):
        flag = True
        temp = []
        for prevRule in listFormattedPreviousRules:
            prevRule.sort()
            temp.append(prevRule)
        for i in rule:
            y = rule[:]  # fastest way to copy
            y.remove(i)
            y.append(item)
            y.sort()
            if(y not in temp):
                flag = False
                break
        return flag
            
        
    def findItemCount(self, columnName, data):
        item_count={}
        for v,k in data[columnName].iteritems():
            for i in k:
                if i in item_count:
                    item_count[i]=item_count[i]+1
                else:
                    item_count[i]=1
        print("itemcount\n", item_count)
        print("unique items:", len(item_count))
        return item_count
    
    def findLambda(self, item_count):
        lamb = 0
        for val in item_count.values(): 
            lamb += val 
        lamb = lamb / len(item_count) 
        return lamb
    
    def mis(self, item_count):
        sd=self.findLambda(item_count)*(1-self.alpha)
        mis=[]
        misdict={}
        mis_val={}
        for k, v in item_count.items():
            m=item_count[k]-sd
            if(m<self.ls):
                mis.append(self.ls)
                misdict[item_count[k]]=self.ls
                mis_val[k]=self.ls
            else:
                mis.append(m)
                misdict[item_count[k]]=m
                mis_val[k]=m
        return mis_val
    
    def getMinMIS(self, mis_val):
        return min(mis_val.values())
    
    def getIndividualItems(self, mis_val, item_count):
        L_2={}
        for k, v in item_count.items():
            if(item_count[k]>=mis_val[k]):
                L_2[k]=mis_val[k]
        uniqueItems = list(L_2.keys())
        temp= sorted(L_2.items(), key=operator.itemgetter(0))
        L_21=sorted(temp, key=operator.itemgetter(1), reverse=True)
        print("individual items size: ", len(L_21))
        #print("items:", L_21)
        print("L21 Keys: ",uniqueItems)
        return uniqueItems, L_21
    
    def getNItemsetRules(self, n, individualUniqueItems, listFormattedPreviousRules, mis_val, columnName, data, courseNameColumn):
        start_time = time.time()
        CN=self.findsubsets(individualUniqueItems, listFormattedPreviousRules, n)
        if(n>2):
            print("combination:", CN)
        print("time taken to get all combinations: ", time.time() - start_time)
        print("combination size", len(CN))
        print("combinations:",CN[:3])
        #count for each candidate itemset
        start_time = time.time()
        count = self.getSupportOfEachCombination(CN, data, columnName)
        print("time taken to get support of each combination : ", time.time() - start_time)
        #checking criteria for count
        start_time = time.time()
        itemSet={}
        indivUniqueItems =[]
        for k, v in count.items():
                m=count[k][0]*100/data.shape[0]
                if(m > self.getMinMIS(mis_val)):
                    itemSet[k]=count[k]
        
        indivUniqueItems, listFormattedRules = self.getUnqiueValidItemsAndListFormatteRules(list(itemSet.keys()))
        temp= sorted(itemSet.items(), key=operator.itemgetter(0))
        sortedRules=sorted(temp, key=operator.itemgetter(1), reverse=True)
        print("time taken to get valid combinations : ", time.time() - start_time)
        
        if(len(sortedRules)>4):
            print("N:", n,"No of rules:", len(sortedRules),"\nRules: ", sortedRules[:3], type(sortedRules[:3][0]))
        file=open(str(n)+'_'+str(self.alpha)+'_'+str(self.ls)+'_'+courseNameColumn+'_RulesElectiveCourse.txt','w+')
        for items in sortedRules:
            file.writelines([str(items)])
            file.write("\n")
        file.close()
        return indivUniqueItems, listFormattedRules, sortedRules
    
    def getUnqiueValidItemsAndListFormatteRules(self, listOfItemSets):
        #keys will be strings separated by ,
        allItems = []
        listFormattedRules = []
        for itemSet in listOfItemSets:
            l = itemSet.split(',')
            allItems+= l
            listFormattedRules.append(l)
        return list(set(allItems)),listFormattedRules
    
    def getSupportOfEachCombination(self, CN, data, columnName):
        count={}
        for i in CN:
            for index, row in data.iterrows():
                if(set(i).issubset( row[columnName])):
                    strSet = ','.join(set(i))
                    if(strSet in count):
                        count[strSet].append(index)
                    else:
                        count[strSet] = [index]
        new_count={}
        for i in count:
            temp=list(count[i])
            new_count[i]=[len(count[i]), temp]
        return new_count
            
    def generateAllRules(self, L1List, mis_val, columnName, data, start, end, courseNameColumn):
        rules = {}
        indivUniqueItems = L1List
        listFormattedRules = []
        for i in range(start,end+1):
            indivUniqueItems, listFormattedRules, rule = self.getNItemsetRules(i, indivUniqueItems, listFormattedRules, mis_val, columnName, data, courseNameColumn)
            print("for ", i, " number of rules:", len(rule))
            print("indivudal unique items left:", indivUniqueItems)
            print("number of unique items:", len(indivUniqueItems)) 
            print("rules in list format: ", listFormattedRules)
            if(len(rule)==0):
                break
            rules[i] = rule
        return rules
    
    def runApriori(self, columnName, df, start, end, courseNameColumn):
        data = df.copy()
        item_count = self.findItemCount(columnName, data)
        mis_val = self.mis(item_count)
        uniqueItems , L1Set = self.getIndividualItems(mis_val, item_count)
        print("L1 set: ", L1Set)
        rules = self.generateAllRules(uniqueItems, mis_val, columnName, data,start, end, courseNameColumn)
        print("total rules:", len(rules))
        return rules

# %%
def readJson(filename):
    data = {}
    with open(filename) as json_file:
        data = json.load(json_file)
    return data

# %%
#Parameter
#1: dataset
#2: Tier, Company name, etc
#3: LS
#4: Alpha
#5: list of column names
start_time = time.time()
softwareToolGroupDict = readJson('softwareToolGroups.json')
columns=['AwardsNLP',
       'ExternalCertificatesDomain', 'ExternalCertificatesKey',
       'GeneralSkillsNLP', 'InternshipCompany',
       'InternshipProjectDomain', 'LanguagesNLP',
       'ProjectDetailDomain',
       'PublicationNLP', 'ResearchDomain',
       'ScholarshipsNLP', 'VolunteeringWork',
       'WorkshopsDomain', 'WorkshopsOrg', 'SoftwareTools', 'ProgLanguagesNLP','CoCurricularActivitiesNLP'
]
columnName = 'TierLevel'
columnValue = '1'
boolAprioriVersion=True
boolCourses=True
list_var=[['SoftwareTools'],['ProgLanguagesNLP'],['GeneralSkillsNLP','VolunteeringWork','CoCurricularActivitiesNLP','LanguagesNLP'],['ExternalCertificatesKey','ExternalCertificatesDomain','WorkshopsOrg','WorkshopsDomain','PublicationNLP']]
data_full= pd.read_csv(r"FinalCombined_April.csv")
obj1 = PreprocessApriori(data_full, softwareToolGroupDict, columns,list_var)
if(boolAprioriVersion):
    a=obj1.allColumnsItemGenerationBoolColumn(data_full, columnName, columnValue,'ElectiveCourseGrade', 'ElectiveCourseName', boolCourses)
else:
    a= obj1.allColumnsItemGeneration(data_full, columnName, columnValue,'ElectiveCourseGrade', 'ElectiveCourseName', boolCourses )
a.reset_index(inplace = True)
a=a.drop(['index','Unnamed: 0','Unnamed: 0.1'], axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['AwardsNLP', 'InternshipCompany', 'InternshipProjectDomain', 'ProjectDetailDomain', 'ResearchDomain', 'ScholarshipsNLP', 'SoftwareTools_present', 'ProgLanguagesNLP_present', 'NonAcademicSkills_present', 'OffCampusLearning_present']
# --------------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
objApriori = Apriori(a, 0.1, 10)
rules = objApriori.runApriori('combinedItemset',a, 2,10, 'ElectiveCourseName')
print("time taken overall ", time.time() - start_time)
# Out:
# itemcount
#  {'ElectiveCourseName_advanced algorithms::A and higher': 86, 'AwardsNLP_iayp': 1, 'AwardsNLP_e-yantra': 1, 'InternshipProjectDomain_Image Processing': 220, 'InternshipProjectDomain_Algorithms': 29, 'ProjectDetailDomain_Cloud computing': 221, 'ProjectDetailDomain_Machine Learning': 119, 'ProjectDetailDomain_Web Development': 108, 'ProjectDetailDomain_Compiler Design': 92, 'ProjectDetailDomain_Big Data': 51, 'ProjectDetailDomain_Image Processing': 187, 'ProjectDetailDomain_Data Structures': 112, 'ProjectDetailDomain_Deep Learning': 81, 'ProjectDetailDomain_Artificial Intelligence': 28, 'ProjectDetailDomain_Micro Processors and Controllers': 16, 'ResearchDomain_Machine Learning': 7, 'ResearchDomain_Image Processing': 15, 'ResearchDomain_Deep Learning': 2, 'ScholarshipsNLP_cnr': 87, 'NonAcademicSkills_present': 209, 'OffCampusLearning_present': 80, 'ElectiveCourseName_big data::A and higher': 165, 'ElectiveCourseName_data analytics::S and higher': 41, 'ElectiveCourseName_topics in deep learning::S and higher': 6, 'ElectiveCourseName_knowledge management::A and higher': 85, 'ProjectDetailDomain_Computer Networks': 45, 'ProjectDetailDomain_Heterogenous parallelism': 12, 'ScholarshipsNLP_mrd': 26, 'AwardsNLP_distinction award': 24, 'InternshipProjectDomain_Data Structures': 18, 'ResearchDomain_Artificial Intelligence': 1, 'InternshipCompany_Morgan Stanley': 8, 'InternshipProjectDomain_Cloud computing': 101, 'InternshipProjectDomain_Operating System': 16, 'ProjectDetailDomain_Database Management System': 156, 'ProjectDetailDomain_Data Sience': 47, 'InternshipProjectDomain_Big Data': 60, 'ProjectDetailDomain_IoT': 45, 'ResearchDomain_Cloud computing': 18, 'ResearchDomain_Data Structures': 2, 'InternshipProjectDomain_Web Development': 42, 'InternshipCompany_IISc': 7, 'InternshipProjectDomain_Machine Learning': 58, 'InternshipProjectDomain_Compiler Design': 2, 'InternshipProjectDomain_Deep Learning': 31, 'ProjectDetailDomain_Algorithms': 111, 'ProjectDetailDomain_Blockchain': 11, 'ElectiveCourseName_artificial intelligence::S and higher': 7, 'ElectiveCourseName_system modeling and simulation::S and higher': 1, 'InternshipCompany_Microsoft': 15, 'InternshipProjectDomain_Database Management System': 38, 'ProjectDetailDomain_Reinforcement Learning': 48, 'ProjectDetailDomain_Game Development': 4, 'ElectiveCourseName_fuzzy logic::S and higher': 10, 'InternshipCompany_insigma': 1, 'InternshipProjectDomain_IoT': 23, 'ProjectDetailDomain_Natural Language Processing': 29, 'ElectiveCourseName_advanced computer networks::A and higher': 58, 'InternshipCompany_Akamai Technologies': 15, 'InternshipProjectDomain_Artificial Intelligence': 36, 'InternshipProjectDomain_Software Development': 44, 'ElectiveCourseName_database technologies::B and higher': 5, 'ProjectDetailDomain_Information Security': 7, 'ProjectDetailDomain_App Development': 22, 'ElectiveCourseName_generic programming::A and higher': 18, 'InternshipCompany_Zscaler Softech': 2, 'InternshipCompany_Tally Solutions': 1, 'InternshipCompany_Wipro': 3, 'InternshipProjectDomain_Computer Networks': 16, 'InternshipCompany_Samsung': 6, 'InternshipCompany_alcoding club': 1, 'InternshipProjectDomain_Heterogenous parallelism': 4, 'ProjectDetailDomain_Software Development': 38, 'ProjectDetailDomain_Digital Design and Computer Organization': 7, 'ElectiveCourseName_natural language processing::S and higher': 4, 'ProjectDetailDomain_Operating System': 105, 'ProjectDetailDomain_Computer Network Security': 4, 'InternshipCompany_Tata': 1, 'ProjectDetailDomain_Computer Vision': 7, 'InternshipCompany_Crio.do': 5, 'InternshipCompany_CDSAML': 5, 'ScholarshipsNLP_distinction': 12, 'InternshipCompany_Goldman Sachs': 4, 'InternshipCompany_IIIT': 2, 'ProjectDetailDomain_Robotics': 6, 'AwardsNLP_intel': 6, 'ResearchDomain_Software Development': 5, 'ResearchDomain_Algorithms': 5, 'InternshipCompany_IBM': 3, 'ElectiveCourseName_digital image processing::S and higher': 32, 'InternshipCompany_Crucible of research and innov ...
# unique items: 155
# individual items size:  70
# L21 Keys:  ['ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Algorithms', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Big Data', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Artificial Intelligence', 'ProjectDetailDomain_Micro Processors and Controllers', 'ResearchDomain_Image Processing', 'ScholarshipsNLP_cnr', 'NonAcademicSkills_present', 'OffCampusLearning_present', 'ElectiveCourseName_big data::A and higher', 'ElectiveCourseName_data analytics::S and higher', 'ElectiveCourseName_knowledge management::A and higher', 'ProjectDetailDomain_Computer Networks', 'ProjectDetailDomain_Heterogenous parallelism', 'ScholarshipsNLP_mrd', 'AwardsNLP_distinction award', 'InternshipProjectDomain_Data Structures', 'InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Operating System', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Data Sience', 'InternshipProjectDomain_Big Data', 'ProjectDetailDomain_IoT', 'ResearchDomain_Cloud computing', 'InternshipProjectDomain_Web Development', 'InternshipProjectDomain_Machine Learning', 'InternshipProjectDomain_Deep Learning', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Blockchain', 'InternshipCompany_Microsoft', 'InternshipProjectDomain_Database Management System', 'ProjectDetailDomain_Reinforcement Learning', 'ElectiveCourseName_fuzzy logic::S and higher', 'InternshipProjectDomain_IoT', 'ProjectDetailDomain_Natural Language Processing', 'ElectiveCourseName_advanced computer networks::A and higher', 'InternshipCompany_Akamai Technologies', 'InternshipProjectDomain_Artificial Intelligence', 'InternshipProjectDomain_Software Development', 'ProjectDetailDomain_App Development', 'ElectiveCourseName_generic programming::A and higher', 'InternshipProjectDomain_Computer Networks', 'ProjectDetailDomain_Software Development', 'ProjectDetailDomain_Operating System', 'ScholarshipsNLP_distinction', 'ElectiveCourseName_digital image processing::S and higher', 'InternshipCompany_Microsoft Innovation Lab', 'InternshipProjectDomain_Reinforcement Learning', 'AwardsNLP_olympiad', 'AwardsNLP_math', 'AwardsNLP_merit', 'InternshipProjectDomain_Natural Language Processing', 'InternshipProjectDomain_App Development', 'AwardsNLP_cnr', 'InternshipProjectDomain_Data Sience', 'ProgLanguagesNLP_present', 'ElectiveCourseName_professional skills for software engineers - i::D and higher', 'SoftwareTools_present', 'AwardsNLP_machine learning', 'ProjectDetailDomain_ c Unix', 'AwardsNLP_hackathon', 'ElectiveCourseName_programming with c++::D and higher']
# L1 set:  [('ProjectDetailDomain_Cloud computing', 196.41548387096773), ('InternshipProjectDomain_Image Processing', 195.41548387096773), ('NonAcademicSkills_present', 184.41548387096773), ('ProjectDetailDomain_Image Processing', 162.41548387096773), ('ProgLanguagesNLP_present', 142.41548387096773), ('ElectiveCourseName_big data::A and higher', 140.41548387096773), ('ProjectDetailDomain_Database Management System', 131.41548387096773), ('ProjectDetailDomain_Machine Learning', 94.41548387096773), ('ProjectDetailDomain_Data Structures', 87.41548387096773), ('ProjectDetailDomain_Algorithms', 86.41548387096773), ('ProjectDetailDomain_Web Development', 83.41548387096773), ('ProjectDetailDomain_Operating System', 80.41548387096773), ('InternshipProjectDomain_Cloud computing', 76.41548387096773), ('ProjectDetailDomain_Compiler Design', 67.41548387096773), ('ScholarshipsNLP_cnr', 62.41548387096774), ('ElectiveCourseName_advanced algorithms::A and higher', 61.41548387096774), ('ElectiveCourseName_knowledge management::A and higher', 60.41548387096774), ('ProjectDetailDomain_Deep Learning', 56.41548387096774), ('OffCampusLearning_present', 55.41548387096774), ('InternshipProjectDomain_Big Data', 35.41548387096774), ('ElectiveCourseName_advanced computer networks::A and higher', 33.41548387096774), ('InternshipProjectDomain_Machine Learning', 33.41548387096774), ('ProjectDetailDomain_Big Data', 26.41548387096774), ('ProjectDetailDomain_Reinforcement Learning', 23.41548387096774), ('ProjectDetailDomain_Data Sience', 22.41548387096774), ('SoftwareTools_present', 22.41548387096774), ('ProjectDetailDomain_Computer Networks', 20.41548387096774), ('ProjectDetailDomain_IoT', 20.41548387096774), ('InternshipProjectDomain_Software Development', 19.41548387096774), ('InternshipProjectDomain_Web Development', 17.41548387096774), ('ElectiveCourseName_data analytics::S and higher', 16.41548387096774), ('InternshipProjectDomain_Database Management System', 13.41548387096774), ('ProjectDetailDomain_Software Development', 13.41548387096774), ('AwardsNLP_hackathon', 12.41548387096774), ('ElectiveCourseName_professional skills for software engineers - i::D and higher', 12.41548387096774), ('AwardsNLP_merit', 11.41548387096774), ('InternshipProjectDomain_Artificial Intelligence', 11.41548387096774), ('AwardsNLP_cnr', 10), ('AwardsNLP_distinction award', 10), ('AwardsNLP_machine learning', 10), ('AwardsNLP_math', 10), ('AwardsNLP_olympiad', 10), ('ElectiveCourseName_digital image processing::S and higher', 10), ('ElectiveCourseName_fuzzy logic::S and higher', 10), ('ElectiveCourseName_generic programming::A and higher', 10), ('ElectiveCourseName_programming with c++::D and higher', 10), ('InternshipCompany_Akamai Technologies', 10), ('InternshipCompany_Microsoft', 10), ('InternshipCompany_Microsoft Innovation Lab', 10), ('InternshipProjectDomain_Algorithms', 10), ('InternshipProjectDomain_App Development', 10), ('InternshipProjectDomain_Computer Networks', 10), ('InternshipProjectDomain_Data Sience', 10), ('InternshipProjectDomain_Data Structures', 10), ('InternshipProjectDomain_Deep Learning', 10), ('InternshipProjectDomain_IoT', 10), ('InternshipProjectDomain_Natural Language Processing', 10), ('InternshipProjectDomain_Operating System', 10), ('InternshipProjectDomain_Reinforcement Learning', 10), ('ProjectDetailDomain_ c Unix', 10), ('ProjectDetailDomain_App Development', 10), ('ProjectDetailDomain_Artificial Intelligence', 10), ('ProjectDetailDomain_Blockchain', 10), ('ProjectDetailDomain_Heterogenous parallelism', 10), ('ProjectDetailDomain_Micro Processors and Controllers', 10), ('ProjectDetailDomain_Natural Language Processing', 10), ('ResearchDomain_Cloud computing', 10), ('ResearchDomain_Image Processing', 10), ('ScholarshipsNLP_distinction', 10), ('ScholarshipsNLP_mrd', 10)]
# time taken to get all combinations:  0.0009915828704833984
# combination size 2415
# combinations: [('ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Image Processing'), ('ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Algorithms'), ('ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Cloud computing')]
# time taken to get support of each combination :  80.68574953079224
# time taken to get valid combinations :  0.01504826545715332
# N: 2 No of rules: 208
# Rules:  [('InternshipProjectDomain_Image Processing,ProjectDetailDomain_Cloud computing', [162, [0, 2, 4, 5, 6, 12, 14, 16, 17, 18, 19, 26, 27, 28, 32, 33, 34, 36, 38, 39, 45, 48, 50, 52, 53, 58, 63, 66, 68, 71, 72, 74, 75, 78, 79, 80, 82, 84, 85, 87, 90, 92, 93, 94, 98, 100, 102, 103, 104, 105, 107, 108, 109, 110, 112, 113, 115, 116, 118, 122, 123, 124, 129, 130, 133, 134, 135, 136, 137, 138, 144, 145, 146, 147, 152, 157, 158, 159, 160, 163, 166, 167, 168, 169, 170, 171, 172, 173, 174, 178, 179, 180, 181, 182, 183, 188, 189, 190, 191, 192, 193, 194, 195, 198, 200, 201, 202, 203, 205, 206, 207, 208, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 226, 231, 232, 233, 234, 236, 237, 239, 240, 244, 245, 246, 247, 250, 251, 252, 255, 259, 260, 261, 262, 266, 281, 282, 283, 284, 285, 286, 287, 290, 291, 293, 294, 296, 297]]), ('NonAcademicSkills_present,ProjectDetailDomain_Cloud computing', [156, [0, 1, 2, 4, 5, 6, 8, 12, 13, 14, 16, 17, 18, 19, 23, 26, 27, 28, 32, 33, 34, 35, 36, 37, 38, 39, 40, 44, 45, 47, 48, 49, 50, 52, 53, 54, 55, 58, 59, 63, 66, 68, 69, 70, 71, 72, 73, 74, 75, 78, 79, 80, 82, 84, 85, 86, 87, 88, 92, 93, 94, 95, 97, 98, 100, 101, 107, 109, 110, 111, 112, 113, 122, 123, 124, 126, 133, 134, 135, 136, 144, 145, 146, 147, 157, 158, 159, 160, 163, 166, 167, 168, 171, 172, 173, 174, 177, 178, 179, 181, 182, 183, 186, 187, 188, 189, 191, 192, 193, 194, 195, 202, 203, 204, 210, 211, 220, 221, 226, 229, 230, 231, 232, 233, 239, 240, 241, 242, 243, 244, 245, 248, 249, 250, 251, 252, 255, 256, 259, 260, 261, 262, 265, 266, 273, 275, 276, 281, 285, 288, 289, 290, 291, 296, 297, 299]]), ('ProjectDetailDomain_Image Processing,ProjectDetailDomain_Cloud computing', [155, [0, 2, 4, 5, 12, 14, 16, 18, 19, 26, 27, 28, 34, 36, 37, 39, 44, 45, 47, 48, 52, 58, 63, 64, 66, 68, 69, 71, 72, 74, 75, 78, 80, 84, 86, 87, 90, 92, 93, 95, 97, 100, 101, 104, 106, 108, 109, 110, 111, 112, 113, 115, 116, 118, 124, 126, 129, 130, 133, 134, 137, 138, 144, 145, 146, 147, 152, 154, 155, 157, 158, 159, 160, 163, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 177, 180, 181, 182, 186, 187, 188, 189, 191, 192, 193, 194, 199, 200, 201, 202, 203, 204, 205, 206, 208, 210, 211, 214, 215, 220, 221, 222, 223, 224, 226, 229, 230, 232, 233, 234, 236, 237, 238, 243, 244, 248, 249, 252, 253, 254, 255, 256, 259, 260, 261, 262, 265, 271, 272, 275, 276, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294]])] <class 'tuple'>
# for  2  number of rules: 208
# indivudal unique items left: ['ElectiveCourseName_advanced computer networks::A and higher', 'NonAcademicSkills_present', 'InternshipProjectDomain_Web Development', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data', 'InternshipProjectDomain_Software Development', 'InternshipProjectDomain_Database Management System', 'ProjectDetailDomain_Data Structures', 'ScholarshipsNLP_cnr', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Cloud computing', 'InternshipProjectDomain_Big Data', 'ProjectDetailDomain_Machine Learning', 'AwardsNLP_hackathon', 'ProjectDetailDomain_Operating System', 'SoftwareTools_present', 'InternshipProjectDomain_Machine Learning', 'ProjectDetailDomain_IoT', 'OffCampusLearning_present', 'ElectiveCourseName_big data::A and higher', 'ElectiveCourseName_data analytics::S and higher', 'ProjectDetailDomain_Data Sience', 'ElectiveCourseName_knowledge management::A and higher', 'ElectiveCourseName_professional skills for software engineers - i::D and higher', 'ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Computer Networks', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Reinforcement Learning', 'ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Artificial Intelligence']
# number of unique items: 35
# rules in list format:  [['InternshipProjectDomain_Image Processing', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Machine Learning', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ProjectDetailDomain_Web Development', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Image Processing'], ['ProjectDetailDomain_Data Structures', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ElectiveCourseName_advanced algorithms::A and higher', 'NonAcademicSkills_present'], ['ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Algorithms', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ProjectDetailDomain_Operating System', 'ElectiveCourseName_advanced algorithms::A and higher'], ['ProgLanguagesNLP_present', 'ElectiveCourseName_advanced algorithms::A and higher'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Machine Learning', 'InternshipProjectDomain_Image Processing'], ['ProjectDetailDomain_Web Development', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing'], ['ProjectDetailDomain_Data Structures', 'InternshipProjectDomain_Image Processing'], ['ProjectDetailDomain_Deep Learning', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'ScholarshipsNLP_cnr'], ['InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present'], ['InternshipProjectDomain_Image Processing', 'OffCampusLearning_present'], ['InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['InternshipProjectDomain_Image Processing', 'ElectiveCourseName_data analytics::S and higher'], ['ElectiveCourseName_knowledge management::A and higher', 'InternshipProjectDomain_Image Processing'], ['ProjectDetailDomain_Computer Networks', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Database Management System'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Data Sience'], ['InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Big Data'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_IoT'], ['InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Web Development'], ['InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Machine Learning'], ['ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Database Management System'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Reinforcement Learning'], ['ElectiveCourseName_advanced computer networks::A and higher', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Artificial Intelligence', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Software Development', 'InternshipProjectDomain_Image Processing'], ['ProjectDetailDomain_Operating System', 'InternshipProjectDomain_Image Processing'], ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'SoftwareTools_present'], ['ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing'], [' ...
# combination: [('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present'), ('ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Web Development'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Web Development'), ('InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Operating System'), ('ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design'), ('ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Operating System'), ('ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Deep Learning'), ('ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_IoT'), ('InternshipProjectDomain_Big Data', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Operating System'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Operating System'), ('ProgLanguagesNLP_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Machine Learning', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Machine Learning', 'NonAcademicSkills_present'), ('ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'), ('ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Web Development'), ('ElectiveCourseName_knowledge management::A and higher', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Web Development'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProjectDetailDomain_Data Structures'), ('OffCampusLearning_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Database Management System'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Machine Learning', 'ProjectDetailDomain_Cloud computing'), ('ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'SoftwareTools_present'), ('ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design'), ('InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Machine Learning', 'ProjectDetailDomain_Algorithms'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Computer Networks'), ('InternshipProjectDomain_Big Data', 'NonAcademicSkills_present', 'ProjectDetailDomain_Image Processing'), ('ProgLanguagesNLP_present', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Database Management System'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Web Development'), ('InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Web Development'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProjectDetailDomain_Operating System'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data', 'ProjectDetailDomain_Image Processing'), ('InternshipP ...
# time taken to get all combinations:  0.37061500549316406
# combination size 778
# combinations: [('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present'), ('ElectiveCourseName_advanced algorithms::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Web Development'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Web Development')]
# time taken to get support of each combination :  26.531408548355103
# time taken to get valid combinations :  0.007940530776977539
# N: 3 No of rules: 406
# Rules:  [('InternshipProjectDomain_Image Processing,ProjectDetailDomain_Image Processing,ProjectDetailDomain_Cloud computing', [118, [0, 2, 4, 5, 12, 14, 16, 18, 19, 26, 27, 28, 34, 36, 39, 45, 48, 52, 58, 63, 66, 68, 71, 72, 74, 75, 78, 80, 84, 87, 90, 92, 93, 100, 104, 108, 109, 110, 112, 113, 115, 116, 118, 124, 129, 130, 133, 134, 137, 138, 144, 145, 146, 147, 152, 157, 158, 159, 160, 163, 166, 167, 168, 169, 170, 171, 172, 173, 174, 180, 181, 182, 188, 189, 191, 192, 193, 194, 200, 201, 202, 203, 205, 206, 208, 210, 211, 214, 215, 220, 221, 222, 223, 224, 226, 232, 233, 234, 236, 237, 244, 252, 255, 259, 260, 261, 262, 281, 282, 283, 284, 285, 286, 287, 290, 291, 293, 294]]), ('ProjectDetailDomain_Cloud computing,InternshipProjectDomain_Image Processing,NonAcademicSkills_present', [114, [0, 2, 4, 5, 6, 12, 14, 16, 17, 18, 19, 26, 27, 28, 32, 33, 34, 36, 38, 39, 45, 48, 50, 52, 53, 58, 63, 66, 68, 71, 72, 74, 75, 78, 79, 80, 82, 84, 85, 87, 92, 93, 94, 98, 100, 107, 109, 110, 112, 113, 122, 123, 124, 133, 134, 135, 136, 144, 145, 146, 147, 157, 158, 159, 160, 163, 166, 167, 168, 171, 172, 173, 174, 178, 179, 181, 182, 183, 188, 189, 191, 192, 193, 194, 195, 202, 203, 210, 211, 220, 221, 226, 231, 232, 233, 239, 240, 244, 245, 250, 251, 252, 255, 259, 260, 261, 262, 266, 281, 285, 290, 291, 296, 297]]), ('ProjectDetailDomain_Cloud computing,ProjectDetailDomain_Image Processing,NonAcademicSkills_present', [109, [0, 2, 4, 5, 12, 14, 16, 18, 19, 26, 27, 28, 34, 36, 37, 39, 44, 45, 47, 48, 52, 58, 63, 66, 68, 69, 71, 72, 74, 75, 78, 80, 84, 86, 87, 92, 93, 95, 97, 100, 101, 109, 110, 111, 112, 113, 124, 126, 133, 134, 144, 145, 146, 147, 157, 158, 159, 160, 163, 166, 167, 168, 171, 172, 173, 174, 177, 181, 182, 186, 187, 188, 189, 191, 192, 193, 194, 202, 203, 204, 210, 211, 220, 221, 226, 229, 230, 232, 233, 243, 244, 248, 249, 252, 255, 256, 259, 260, 261, 262, 265, 275, 276, 281, 285, 288, 289, 290, 291]])] <class 'tuple'>
# for  3  number of rules: 406
# indivudal unique items left: ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data', 'ProjectDetailDomain_Data Structures', 'ScholarshipsNLP_cnr', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Cloud computing', 'InternshipProjectDomain_Big Data', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Operating System', 'SoftwareTools_present', 'InternshipProjectDomain_Machine Learning', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Data Sience', 'OffCampusLearning_present', 'ElectiveCourseName_data analytics::S and higher', 'ElectiveCourseName_knowledge management::A and higher', 'ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Reinforcement Learning', 'ProjectDetailDomain_Algorithms']
# number of unique items: 26
# rules in list format:  [['ProgLanguagesNLP_present', 'NonAcademicSkills_present', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Operating System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing'], ['ProgLanguagesNLP_present', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['InternshipProjectDomain_Image Processing', 'ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'NonAcademicSkills_present', 'ElectiveCourseName_big data::A and higher'], ['ProgLanguagesNLP_present', 'SoftwareTools_present', 'ProjectDetailDomain_Cloud computing'], ['InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Machine Learning'], ['ProgLanguagesNLP_present', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Operating System', 'NonAcademicSkills_present', 'ElectiveCourseName_big data::A and higher'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data', 'ProjectDetailDomain_Image Processing'], ['ElectiveCourseName_knowledge management::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Web Development', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Web Development', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Sience'], ['ProjectDetailDomain_Compiler Design', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Operating System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Cloud computing'], ['ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing'], ['InternshipProjectDomain_Image Processing', 'ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Machine Learning'], ['InternshipProjectDomain_Image Processing', 'OffCampusLearning_present', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_advanced algorithms::A and higher', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing', 'OffCampusLearning_present'], ['ProjectDetailDomain_Operating System', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Image Processing'], ['InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing', 'InternshipProjectDomain_Machine Learning'], ['ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Algorithms', 'ProgLanguagesNLP_present'], ['ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher', 'Pr ...
# combination: [('NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Machine Learning'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Image Processing'), ('NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('ElectiveCourseName_big data::A and higher', 'ElectiveCourseName_knowledge management::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Image Processing'), ('NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Database Management System'), ('NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Machine Learning'), ('InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing'), ('ProgLanguagesNLP_present', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Operating System'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Web Development'), ('ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Image Processing'), ('ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Image Processing'), ('ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures'), ('ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing'), ('ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Deep Learning'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Machine Learning'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing'), ('ElectiveCourseName_big data::A and higher', 'Intern ...
# time taken to get all combinations:  1.014906883239746
# combination size 583
# combinations: [('NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Machine Learning'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Machine Learning'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Image Processing')]
# time taken to get support of each combination :  20.117751836776733
# time taken to get valid combinations :  0.0049860477447509766
# N: 4 No of rules: 330
# Rules:  [('ProjectDetailDomain_Cloud computing,InternshipProjectDomain_Image Processing,ProjectDetailDomain_Image Processing,NonAcademicSkills_present', [84, [0, 2, 4, 5, 12, 14, 16, 18, 19, 26, 27, 28, 34, 36, 39, 45, 48, 52, 58, 63, 66, 68, 71, 72, 74, 75, 78, 80, 84, 87, 92, 93, 100, 109, 110, 112, 113, 124, 133, 134, 144, 145, 146, 147, 157, 158, 159, 160, 163, 166, 167, 168, 171, 172, 173, 174, 181, 182, 188, 189, 191, 192, 193, 194, 202, 203, 210, 211, 220, 221, 226, 232, 233, 244, 252, 255, 259, 260, 261, 262, 281, 285, 290, 291]]), ('ProgLanguagesNLP_present,InternshipProjectDomain_Image Processing,ProjectDetailDomain_Image Processing,ProjectDetailDomain_Cloud computing', [73, [104, 108, 109, 110, 112, 113, 115, 116, 118, 124, 129, 130, 133, 134, 146, 147, 152, 157, 158, 159, 160, 163, 167, 169, 170, 171, 172, 173, 174, 180, 181, 182, 189, 191, 192, 193, 194, 200, 202, 203, 205, 206, 208, 210, 211, 214, 215, 220, 221, 222, 223, 226, 232, 233, 234, 236, 237, 244, 255, 259, 260, 261, 262, 281, 283, 284, 285, 286, 287, 290, 291, 293, 294]]), ('InternshipProjectDomain_Image Processing,ProjectDetailDomain_Image Processing,ProjectDetailDomain_Cloud computing,ProjectDetailDomain_Database Management System', [69, [4, 5, 12, 16, 18, 19, 26, 27, 28, 34, 36, 45, 52, 58, 66, 68, 71, 74, 78, 84, 87, 92, 93, 104, 108, 109, 110, 118, 124, 130, 134, 147, 152, 158, 159, 166, 167, 172, 173, 174, 180, 188, 189, 200, 201, 202, 203, 205, 206, 208, 210, 211, 214, 215, 220, 221, 222, 223, 232, 236, 237, 255, 261, 262, 282, 286, 287, 290, 291]])] <class 'tuple'>
# for  4  number of rules: 330
# indivudal unique items left: ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Big Data', 'ProjectDetailDomain_Data Structures', 'ScholarshipsNLP_cnr', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Cloud computing', 'InternshipProjectDomain_Big Data', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Operating System', 'ElectiveCourseName_big data::A and higher', 'OffCampusLearning_present', 'ElectiveCourseName_knowledge management::A and higher', 'ElectiveCourseName_advanced algorithms::A and higher', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Algorithms']
# number of unique items: 21
# rules in list format:  [['InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_knowledge management::A and higher', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Deep Learning', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Machine Learning', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present'], ['ProgLanguagesNLP_present', 'NonAcademicSkills_present', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Data Structures', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Machine Learning', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing'], ['ProjectDetailDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Operating System', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Web Development', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning', 'ProgLanguagesNLP_present', 'NonAcademicSkills_present'], ['ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Algorithms', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Image Processing'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Operating System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Image Pro ...
# combination: [('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Data Structures'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing'), ('NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System'), ('ElectiveCourseName_big data::A and higher', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing'), ('ElectiveCourseName_big data::A and higher', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Image Processing'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System'), ('ElectiveCourseName_big data::A and higher', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System'), ('InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjec ...
# time taken to get all combinations:  0.6003966331481934
# combination size 154
# combinations: [('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Data Structures'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Cloud computing', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing')]
# time taken to get support of each combination :  5.255981206893921
# time taken to get valid combinations :  0.0009922981262207031
# N: 5 No of rules: 90
# Rules:  [('ProjectDetailDomain_Image Processing,NonAcademicSkills_present,ProjectDetailDomain_Database Management System,InternshipProjectDomain_Image Processing,ProjectDetailDomain_Cloud computing', [49, [4, 5, 12, 16, 18, 19, 26, 27, 28, 34, 36, 45, 52, 58, 66, 68, 71, 74, 78, 84, 87, 92, 93, 109, 110, 124, 134, 147, 158, 159, 166, 167, 172, 173, 174, 188, 189, 202, 203, 210, 211, 220, 221, 232, 255, 261, 262, 290, 291]]), ('ProjectDetailDomain_Image Processing,NonAcademicSkills_present,InternshipProjectDomain_Image Processing,ProjectDetailDomain_Cloud computing,ElectiveCourseName_big data::A and higher', [47, [2, 12, 14, 16, 19, 26, 28, 39, 48, 52, 58, 66, 68, 71, 74, 80, 84, 92, 109, 110, 146, 147, 157, 158, 159, 160, 166, 171, 181, 182, 189, 202, 203, 210, 211, 220, 221, 226, 252, 255, 260, 261, 262, 281, 285, 290, 291]]), ('ProjectDetailDomain_Image Processing,ProgLanguagesNLP_present,InternshipProjectDomain_Image Processing,ProjectDetailDomain_Cloud computing,ElectiveCourseName_big data::A and higher', [45, [109, 110, 115, 116, 118, 130, 146, 147, 157, 158, 159, 160, 171, 181, 182, 189, 200, 202, 203, 205, 206, 210, 211, 214, 215, 220, 221, 222, 223, 226, 234, 236, 237, 255, 260, 261, 262, 281, 283, 284, 285, 286, 287, 290, 291]])] <class 'tuple'>
# for  5  number of rules: 90
# indivudal unique items left: ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ScholarshipsNLP_cnr', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Deep Learning', 'InternshipProjectDomain_Big Data', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'OffCampusLearning_present', 'ProjectDetailDomain_Machine Learning', 'ProjectDetailDomain_Algorithms', 'ProjectDetailDomain_Operating System']
# number of unique items: 18
# rules in list format:  [['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing'], ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Image Processing', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'OffCampusLearning_present'], ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Data Structures', 'ProjectDetai ...
# combination: [('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System')]
# time taken to get all combinations:  0.03494763374328613
# combination size 6
# combinations: [('ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing'), ('InternshipProjectDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Operating System')]
# time taken to get support of each combination :  0.2075331211090088
# time taken to get valid combinations :  0.0
# for  6  number of rules: 4
# indivudal unique items left: ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System']
# number of unique items: 9
# rules in list format:  [['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing'], ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System'], ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']]
# combination: []
# time taken to get all combinations:  0.0
# combination size 0
# combinations: []
# time taken to get support of each combination :  0.0
# time taken to get valid combinations :  0.0
# for  7  number of rules: 0
# indivudal unique items left: []
# number of unique items: 0
# rules in list format:  []
# total rules: 5
# time taken overall  307.8292269706726

# %%
a.columns
# Out:
# Index(['USN', '10thPercentage', '12thPercentage', 'AwardsNLP', 'Branch',
#        'CGPA', 'CTC', 'CoCurricularActivities', 'CompanyNameNLP',
#        'CoreCourseGrade', 'CoreCourseName', 'CourseGrade', 'CourseName',
#        'ElectiveCourseGrade', 'ElectiveCourseName', 'EmploymentType',
#        'ExternalCertificatesDomain', 'ExternalCertificatesKey',
#        'GeneralSkills', 'GitHubLink', 'InternshipCompany',
#        'InternshipProjectDomain', 'LanguagesNLP', 'LinkedInLink',
#        'MinorAttended', 'Name', 'NoofInternships', 'NoofProjects',
#        'NumberOfOffers', 'OtherDetails', 'ProgLanguages',
#        'ProjectDetailDomain', 'PublicationNLP', 'ResearchDomain',
#        'ScholarshipsNLP', 'Stipend(K)', 'TierLevel', 'VolunteeringWork',
#        'WorkshopsDomain', 'WorkshopsOrg', 'SoftwareTools', 'ProgLanguagesNLP',
#        'CoCurricularActivitiesNLP', 'GeneralSkillsNLP', 'ValidCourses',
#        'SoftwareTools_present', 'ProgLanguagesNLP_present',
#        'NonAcademicSkills', 'NonAcademicSkills_present', 'OffCampusLearning',
#        'OffCampusLearning_present', 'combinedItems_noCourse',
#        'combinedItemset'],
#       dtype='object')

# %%
#GROUP RULES

def topRules(threshold, name):
    a_file = open(name)
    file_contents = a_file.read()
    rules = file_contents.splitlines()
    a_file.close()
    for i in range(len(rules)):
        temp=rules[i].split("[")   
        temp[0]=temp[0].strip("(").lstrip("'").rstrip("'").split(",")
        temp[0]=temp[0][0:-1]
        temp[0][-1]=temp[0][-1].rstrip("'")
        temp[1]=temp[1].replace(", ","")
        temp[1]=int(temp[1])
        temp[2]=temp[2].replace("]])","").strip("[")
        temp[2]=list(map(int, temp[2].split(',')))
        rules[i]=temp
    max_sup=rules[0][1]
    min_sup=rules[len(rules)-1][1]
    index_thresh=threshold*len(rules)
    index_thresh=int(index_thresh)
    thresh_sup=rules[index_thresh][1]
    thresh_rules=[]
    for i in rules:
        if(i[1]>=thresh_sup):
            thresh_rules.append(i)
    return thresh_rules

def rulesSep(rulesGroup, groups):
    groupDict={}
    for i in groups:
        for j in rulesGroup:
            if(i in j[0]):
                if(i not in groupDict):
                    groupDict[i]=[j]
                    print(i)
                else:
                    groupDict[i].append(j)
    
    return groupDict
                
rulesGroup=topRules(0.6,"5_0.1_10_ElectiveCourseName_RulesElectiveCourse.txt")  
groups=['OffCampusLearning_present','NonAcademicSkills_present','ProgLanguagesNLP_present','SoftwareTools_present']
groupDict=rulesSep(rulesGroup,groups)
# Out:
# OffCampusLearning_present
# NonAcademicSkills_present
# ProgLanguagesNLP_present

# %%
#for prog lang and software tools
# find the unique values in the Prog lang NLP and software tools 
#in the index of rulesGroup, if a given value of prog lang and software tools present then increase count of value
#find top n % of unique values in the column  

def drillDown(columns, df,groupDict):
    data=df.copy()
    for column in columns:
        col=column.replace("_present","")
        data[col]=data[col].str.strip('##').str.split('##')
        '''unique=[]
        for v,k in data[column].iteritems():
            for i in k:
                if i not in unique:
                    unique.append(i)'''
    items={}
    for group in groupDict:
        rules=groupDict[group]
        group_temp=group.replace("_present","")
        for rule in rules:
            temp_df=data.iloc[rule[2]]
            item_count={}
            for v,k in temp_df[group_temp].iteritems():
                for i in k:
                    if i in item_count:
                        item_count[i]=item_count[i]+1
                    else:
                        item_count[i]=1
            print(items, rule[0])
            s=str(rule[0])
            if str(rule[0]) not in items:
                items[s]={}
                items[s][group]=item_count
            else:
                items[s][group]=item_count

            print(group_temp,item_count)
            print("-----------------------------------------------------------")
    return items
        

p=drillDown(groups, a,groupDict)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#a['ProgLanguagesNLP']
groupDict.keys()
# Out:
# dict_keys(['OffCampusLearning_present', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present'])

# %%
for i in p.keys():
    print(i)
    print("---------------------------------")
# Out:
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'OffCampusLearning_present']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']
# ---------------------------------
# ['NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Machine Learning']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Web Development', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Deep Learning', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ScholarshipsNLP_cnr', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']
# ---------------------------------
# ['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing']
# ---------------------------------
# ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']
# ---------------------------------
# ['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Big Data']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Algorithms']
# ---------------------------------
# ['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']
# ---------------------------------
# ['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Operating System']
# ---------------------------------

# %%
p["['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']"].keys()
# Out:
# dict_keys(['NonAcademicSkills_present', 'ProgLanguagesNLP_present'])

# %%
p
# Out:
# {"['NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'NonAcademicSkills_present': {'': 8,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    'Art': 8,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 7,
#    'Coding': 3,
#    'Communication': 3,
#    'Cooking': 2,
#    'Dance': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'Hardworkinganddiligent': 1,
#    'Inquisitive': 2,
#    'Instruments': 5,
#    'Introductin\r\ntomachinelearning': 1,
#    'Leader': 2,
#    'Leadership': 3,
#    'LinearAlgebra': 1,
#    'Motivated': 3,
#    'Music': 10,
#    'ProblemSolving': 5,
#    'Publicspeaking': 1,
#    'Quiz': 2,
#    'ReinforcementLearning': 1,
#    'SocialService': 4,
#    'Sports': 8,
#    'TeamWork': 5,
#    'Theatre': 13,
#    'Timemanagement': 2,
#    'english': 20,
#    'hindi': 20,
#    'kannada': 10,
#    'malayalam': 2,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 4,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1}},
#  "['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'': 10,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '1.2017-2019Hackathonorganizer.\r\nOrganizedtwo24-hourCShackathoncalledDotSlashand#codeatPESUniversity\r\nconductednyMicrosoftInnovationLabandAatmatrisharespectively.Morethan100team\r\nhadparticipated\r\n': 1,
#    '2017Volunteer.\r\nTeamInformals,Aatmatrisha2017:WasanactivememberwhohelpedinorganizingCS-GO\r\nandgullycricket.': 1,
#    '2018Volunteer.\r\nPrakalpa:HelpedintechnicalworkandbuiltanARappusingUnity.Theappwouldshow\r\ndifferentanimatedobjectswhenthecameraseesdifferntpatternsaroundthecampus\r\n': 1,
#    'Art': 9,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 9,
#    'Coding': 4,
#    'Cooking': 2,
#    'Dance': 2,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'ForeignLanguages': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Instruments': 5,
#    'Introductin\r\ntomachinelearning': 1,
#    'Leader': 1,
#    'LinearAlgebra': 1,
#    'Music': 10,
#    'Partofschoolthrowballteam.Representedschoolasteamcaptainin\r\ninter-schoolcompetitions.\r\nPartofStudentCouncilAsDisciplineCommitteeSecretary.\r\nPartofculturalteaminschool': 1,
#    "PeerTeachingclassesforthesubjectWebTechnologies(Aug'18)forstudents.CoreteammemberintheEpsilonScienceFestofPESUniversity(2017).Headedthe\r\nmarketting,design,registerations,etc\r\nVolunteerinTheAmateurScientistfestofPESUniversity(2016,2017)": 1,
#    'ProblemSolving': 2,
#    'Quiz': 2,
#    'ReinforcementLearning': 1,
#    'SocialService': 6,
#    'Sports': 6,
#    'Theatre': 12,
#    'VolunteeratCollegefestivalforRoboSoccereventduring“The\r\nRESPONSIBILITYAmateurScientist(2016)”\r\nOrganisedGamingeventatNPS,Indiranagarfor“Scientifica2015”Sports': 1,
#    'english': 15,
#    'hindi': 15,
#    'kannada': 7,
#    'malayalam': 2,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 6,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1},
#   'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 7,
#    'c': 34,
#    'c++': 21,
#    'css': 20,
#    'go': 7,
#    'html': 27,
#    'java': 10,
#    'javascript': 27,
#    'php': 21,
#    'python': 34,
#    'r': 7,
#    'rest': 9,
#    'scala': 4,
#    'sql': 16}},
#  "['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'': 11,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '2010HelpageIndiafundraisingcampaign\r\n2018FloodrelieffundraisingcampaignforKerala\r\n2016-2019PartofCSR,PESUniversity': 1,
#    'Art': 11,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'BuiltthejudgesystemforBombTag,AnAllIndiaBotBuildingcompetitionforschoolstudentsatTheAmateurScientist2017.\r\nTheAmateurScientist,OrganiserforCodeWars\r\n': 1,
#    'Clubs': 6,
#    'Coding': 4,
#    'Communication': 1,
#    'Cooking': 2,
#    'Dance': 2,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DeployedtheonlinejudgeserverusingDOMJudgeforCodewars,\r\nwhichisthepremiercompetitivecodingcompetitionatTheAmateur\r\nScientist2016.Wereceivedtheparticipationofover350teams\r\nfromacrossIndia.': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'HandledallthelogisticsforScienceShowdown,anintercollegeScienceExhibitionatEpsilon2017.\r\nTheAmateurScientist,OrganiserforBombTag\r\n': 1,
#    'IEEE,StudentCoordinator\r\n•Workedcloselywithvariousteamsincollegetoorganiseworkshops\r\n,seminars,hackathonsandindustrialvisits.\r\nEpsilon,OrganiserforScienceShowdown\r\n': 1,
#    'Inquisitive': 1,
#    'Instruments': 5,
#    'Introductin\r\ntomachinelearning': 1,
#    'LinearAlgebra': 1,
#    'Music': 10,
#    'ProblemSolving': 3,
#    'Quiz': 4,
#    'ReinforcementLearning': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 6,
#    'Sports': 7,
#    'Theatre': 13,
#    'bengali': 2,
#    'english': 15,
#    'hindi': 15,
#    'kannada': 5,
#    'malayalam': 2,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 6,
#    'telugu': 4,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1},
#   'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 6,
#    'c': 34,
#    'c++': 22,
#    'css': 19,
#    'go': 7,
#    'html': 25,
#    'java': 11,
#    'javascript': 27,
#    'php': 20,
#    'python': 32,
#    'r': 4,
#    'rest': 7,
#    'scala': 4,
#    'sql': 15}},
#  "['NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'NonAcademicSkills_present': {'Art': 6,
#    'Clubs': 8,
#    'Coding': 2,
#    'Cooking': 2,
#    'Dance': 2,
#    'ForeignLanguages': 2,
#    'Instruments': 4,
#    'Music': 10,
#    "PeerTeachingclassesforthesubjectWebTechnologies(Aug'18)forstudents.CoreteammemberintheEpsilonScienceFestofPESUniversity(2017).Headedthe\r\nmarketting,design,registerations,etc\r\nVolunteerinTheAmateurScientistfestofPESUniversity(2016,2017)": 1,
#    'ProblemSolving': 3,
#    'Quiz': 4,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 4,
#    'Sports': 5,
#    'Theatre': 7,
#    'Volunteer(2016)TheAmateurScientist,aneventheldatPESUniversity\r\n(Bangalore),thatprovidedanicheplatformforyoungminds\r\ntoshowcasetheirforteinvariousbranchesofscienceata\r\nprofessionallevel\r\nScienceand\r\nTechnology\r\nVolunteer(2017)Prakalpa,aneventheldatPESUniversity(Bangalore),\r\nwhereprojectsfromdifferentengineeringstreamsare\r\npresented\r\nScienceand\r\nTechnology': 3,
#    'bengali': 2,
#    'english': 15,
#    'hindi': 15,
#    'kannada': 7,
#    'malayalam': 2,
#    'sanskrit': 2,
#    'spanish': 2,
#    'tamil': 6,
#    'telugu': 4,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Memberoftheorganisingcommittee(AlgorithmicCodingEvent)of“Aatmatrisha”,theannualtechno\r\nculturalfestofPESUniversity,2018\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Epsilon”,theannualsciencefestofPES\r\nUniversity,2017\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Disha”,theannualfestofCMRNationalPublic\r\nSchool,2015\r\n●VolunteerfortheorganisingcommitteeofCodewarseventin"TheAmateurScientist"(anationallevel\r\nsciencefest,organizedbyPESUniversity),2016\r\n●MemberofthePenandInkClub(FAPS),2013andtheModelUnitedNationsClub(CMRNPS),2015,\r\n2016': 1,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1},
#   'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 7,
#    'c': 32,
#    'c++': 23,
#    'css': 19,
#    'go': 8,
#    'html': 23,
#    'java': 10,
#    'javascript': 24,
#    'php': 18,
#    'python': 33,
#    'r': 6,
#    'rest': 7,
#    'scala': 4,
#    'sql': 11}},
#  "['NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'NonAcademicSkills_present': {'Art': 8,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 9,
#    'Coding': 2,
#    'Communication': 9,
#    'Cooking': 2,
#    'CoreteammemberforEPSILON2017(AnnualTechnical\r\nFestofPESUniversity),Wasresponsibleforthetwo\r\nmajorevents-inQUIZitive(Quizevent)andRadioShack\r\n(ElectronicTreasureHunt).\r\nCampusAmbassadorforCitrixIndiaatPESUniversity\r\nAnactivememberofthePeerteachinginitiativeatPES\r\nUNIVERSITY.CurrentlycontributingasaPeerteacherfor\r\ntheDataStructurescourse.\r\nCoreteammemberororganizingteam,responsiblefor\r\nconductingtheethicalhackingworkshopatPrakalpa\r\n2017incoordinationwithSpyryTechnologies,\r\nBangalore.\r\nOrganizerandheadofmediaandpublicityforTAS(The\r\nAmateurScientist)2017.Inaddition,Eventheadfor\r\nBridgeIT.\r\nStudentExecutiveforcorporaterelationsforIET,\r\nStudentchapter,PESU,Bangalore(2016-2017)\r\nPromotedto:HeadandchairmanofIET,Student\r\nchapter,PESU,Bangalore,2017-18\r\nCoreteammemberofEWD(extendedweekday\r\nactivities)': 1,
#    'Dance': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'ForeignLanguages': 2,
#    'Hardworkinganddiligent': 3,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Inquisitive': 5,
#    'Instruments': 2,
#    'Leadership': 6,
#    'MemberofCSR(CollegiateSocialResponsibility)Sports': 1,
#    'Motivated': 5,
#    'Music': 7,
#    'Organiserofcollegefest-Aatmatrisha,ClasscoordinatorinPrakalpaSciencefestTheatre': 1,
#    'ProblemSolving': 12,
#    'Publicspeaking': 2,
#    'Quiz': 2,
#    'RotaractClubMemberkannada': 1,
#    'SalesandFinanceHeadofAatmatrisha,CoreteammemberofTAS,OrganizedSamarpana,PartofPESUI/OSports': 1,
#    'SamarapanLogisticsHeadhindi': 1,
#    'Samarpana,AatmatrishaSports': 1,
#    'SocialService': 7,
#    'Sports': 3,
#    'TeachingAssistantforDataAnalyticskannada': 1,
#    'TeamWork': 12,
#    'Theatre': 7,
#    'Timemanagement': 8,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'bengali': 1,
#    'english': 31,
#    'german': 1,
#    'hindi': 28,
#    'kannada': 14,
#    'malayalam': 2,
#    'marathi': 1,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 6,
#    'telugu': 4,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2}},
#  "['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'InternshipProjectDomain_Big Data']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 4,
#    'c': 31,
#    'c++': 24,
#    'css': 18,
#    'go': 4,
#    'html': 20,
#    'java': 12,
#    'javascript': 20,
#    'php': 13,
#    'python': 31,
#    'r': 2,
#    'rest': 7,
#    'scala': 2,
#    'sql': 13}},
#  "['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 6,
#    'c': 38,
#    'c++': 23,
#    'css': 20,
#    'go': 11,
#    'html': 26,
#    'java': 13,
#    'javascript': 27,
#    'php': 20,
#    'python': 38,
#    'r': 7,
#    'rest': 10,
#    'scala': 4,
#    'sql': 18}},
#  "['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 10,
#    'c': 34,
#    'c++': 24,
#    'css': 23,
#    'go': 9,
#    'html': 26,
#    'java': 12,
#    'javascript': 28,
#    'php': 22,
#    'python': 34,
#    'r': 7,
#    'rest': 12,
#    'scala': 4,
#    'sql': 15}},
#  "['ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 9,
#    'c': 32,
#    'c++': 21,
#    'css': 19,
#    'go': 9,
#    'html': 24,
#    'java': 17,
#    'javascript': 25,
#    'php': 19,
#    'python': 32,
#    'r': 8,
#    'rest': 13,
#    'scala': 2,
#    'sql': 16}},
#  "['ProjectDetailDomain_Data Structures', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'Art': 7,
#    'Clubs': 9,
#    'Coding': 4,
#    'Communication': 5,
#    'ContentCreator-ParikramaFoundation(2019)|PrimarySchoolEnglishTeacher(Assistant)-BGMSShishukunjVidyalaya(2018)MUN': 1,
#    'Cooking': 2,
#    'Dance': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'ForeignLanguages': 2,
#    'Gitcoin\r\nhttps://github.com/gitcoinco/web\r\n-Developedthebackendfornotificationandfavorite\r\nsystem.\r\n-Fixedwebpagedesignissues.\r\n-TechnologiesUsed:Django,Javascript,CSS\r\nTheClassicalLanguageToolkit\r\nhttps://github.com/cltk/cltk\r\n-AddedKannadaLanguagesupporttotheCLTKlibrary': 1,
#    'Hardworkinganddiligent': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Inquisitive': 1,
#    'Instruments': 2,
#    'Leadership': 3,
#    'Motivated': 2,
#    'Music': 9,
#    "Organiser:Beenapartofthe\r\n‘OrganizingCommittee'of\r\nAatmatrisha-2018,Ihave\r\norganisedaneventunder\r\n‘Informals'domain\r\n•\r\nVolunteerforAatmatrisha2017–\r\nAnnualTechno-CulturalFestof\r\nPESUniversity\r\n•\r\nVolunteer:AsapartofGlobal\r\nVolunteeringMonth,cleanedand\r\nbeautifiedSoulKerelake\r\nsurroundingsInstruments": 2,
#    'Poetry': 2,
#    'ProblemSolving': 6,
#    'Publicspeaking': 2,
#    'Quiz': 2,
#    'SOCIETYMEMBERSHIPS\r\nIEEEStudentMember\r\nMemberNumber:96238500Instruments': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 5,
#    'Sports': 3,
#    'Teachingassistant-Designandanalysisofalgorithmslabhindi': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 7,
#    'Theatre': 5,
#    'Timemanagement': 2,
#    'Volunteer,GoogleMLStudyJam\r\n+Helpedinorganizing3dayhandsonsessionworkshoponmachinelearningstudyjamconductedbyGoogle\r\nDevelopers’GroupBengaluru.\r\nOrganizer,Samarpana\r\n+Collegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonandmanyprogramstoraise\r\nfundsandlookafterthewelfareofthemartyr’sfamilies\r\nOrganizer,AtmaTrisha\r\n+SuccessfullyorganizedFactionMasters,atechnicaleventatthecollegeannualfest.Art': 1,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'english': 17,
#    'hindi': 15,
#    'kannada': 7,
#    'malayalam': 2,
#    'sanskrit': 3,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 2,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2}},
#  "['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 6,
#    'c': 39,
#    'c++': 26,
#    'css': 25,
#    'go': 11,
#    'html': 27,
#    'java': 16,
#    'javascript': 27,
#    'php': 24,
#    'python': 39,
#    'r': 8,
#    'rest': 18,
#    'scala': 4,
#    'sql': 16}},
#  "['ProjectDetailDomain_Data Structures', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 7,
#    'c': 34,
#    'c++': 23,
#    'css': 22,
#    'go': 11,
#    'html': 24,
#    'java': 12,
#    'javascript': 26,
#    'php': 23,
#    'python': 34,
#    'r': 5,
#    'rest': 14,
#    'scala': 4,
#    'sql': 12}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 6,
#    'c': 39,
#    'c++': 26,
#    'css': 22,
#    'go': 13,
#    'html': 25,
#    'java': 16,
#    'javascript': 29,
#    'php': 26,
#    'python': 38,
#    'r': 8,
#    'rest': 18,
#    'scala': 4,
#    'sql': 15}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 6,
#    'c': 38,
#    'c++': 21,
#    'css': 26,
#    'go': 13,
#    'html': 30,
#    'java': 18,
#    'javascript': 29,
#    'php': 26,
#    'python': 37,
#    'r': 7,
#    'rest': 16,
#    'scala': 4,
#    'sql': 16}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 6,
#    'c': 33,
#    'c++': 20,
#    'css': 21,
#    'go': 10,
#    'html': 24,
#    'java': 13,
#    'javascript': 24,
#    'php': 21,
#    'python': 32,
#    'r': 5,
#    'rest': 14,
#    'scala': 4,
#    'sql': 13}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'Art': 7,
#    'Clubs': 10,
#    'Coding': 4,
#    'Communication': 5,
#    'ContentCreator-ParikramaFoundation(2019)|PrimarySchoolEnglishTeacher(Assistant)-BGMSShishukunjVidyalaya(2018)MUN': 1,
#    'Cooking': 2,
#    'Dance': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'ForeignLanguages': 2,
#    'Hardworkinganddiligent': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Helpedinorganizing#Code2020ForeignLanguages': 1,
#    'Inquisitive': 2,
#    'Instruments': 2,
#    'Leader': 1,
#    'Leadership': 3,
#    'Motivated': 2,
#    'Music': 9,
#    'ProblemSolving': 6,
#    'Publicspeaking': 1,
#    'Quiz': 3,
#    'SOCIETYMEMBERSHIPS\r\nIEEEStudentMember\r\nMemberNumber:96238500Instruments': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 5,
#    'Sports': 4,
#    'Teachingassistant-Designandanalysisofalgorithmslabhindi': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 6,
#    'Theatre': 6,
#    'Timemanagement': 2,
#    'Volunteer,GoogleMLStudyJam\r\n+Helpedinorganizing3dayhandsonsessionworkshoponmachinelearningstudyjamconductedbyGoogle\r\nDevelopers’GroupBengaluru.\r\nOrganizer,Samarpana\r\n+Collegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonandmanyprogramstoraise\r\nfundsandlookafterthewelfareofthemartyr’sfamilies\r\nOrganizer,AtmaTrisha\r\n+SuccessfullyorganizedFactionMasters,atechnicaleventatthecollegeannualfest.Art': 1,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'VolunteeratCollegefestivalforRoboSoccereventduring“The\r\nRESPONSIBILITYAmateurScientist(2016)”\r\nOrganisedGamingeventatNPS,Indiranagarfor“Scientifica2015”Sports': 1,
#    'bengali': 1,
#    'english': 20,
#    'german': 1,
#    'hindi': 17,
#    'kannada': 10,
#    'malayalam': 2,
#    'sanskrit': 3,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 2,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Memberoftheorganisingcommittee(AlgorithmicCodingEvent)of“Aatmatrisha”,theannualtechno\r\nculturalfestofPESUniversity,2018\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Epsilon”,theannualsciencefestofPES\r\nUniversity,2017\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Disha”,theannualfestofCMRNationalPublic\r\nSchool,2015\r\n●VolunteerfortheorganisingcommitteeofCodewarseventin"TheAmateurScientist"(anationallevel\r\nsciencefest,organizedbyPESUniversity),2016\r\n●MemberofthePenandInkClub(FAPS),2013andtheModelUnitedNationsClub(CMRNPS),2015,\r\n2016': 1}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'Art': 9,
#    'Clubs': 8,
#    'Coding': 5,
#    'Cooking': 2,
#    'Dance': 4,
#    'ForeignLanguages': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Instruments': 2,
#    'Leader': 1,
#    'MUN': 2,
#    'Music': 11,
#    'Prakalpa(ScienceFest):Organizerteam\r\nAatmatrisha(techno-culturalFest):Volunteer\r\nRotractClubofPesUniversity:VolunteerDance': 1,
#    'ProblemSolving': 3,
#    'Quiz': 3,
#    'SOCIETYMEMBERSHIPS\r\nIEEEStudentMember\r\nMemberNumber:96238500Instruments': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 6,
#    'Sports': 6,
#    'Theatre': 6,
#    'Tookpartinnumerousdanceanddramacompetitionsduringschooldays.\r\n●MemberoftheSchoolandPre-universitycollegeSoccerteams.\r\n●Activelyparticipatingincollegefootballeventsandfests.': 1,
#    'VolunteeratCollegefestivalforRoboSoccereventduring“The\r\nRESPONSIBILITYAmateurScientist(2016)”\r\nOrganisedGamingeventatNPS,Indiranagarfor“Scientifica2015”Sports': 1,
#    'bengali': 1,
#    'english': 13,
#    'hindi': 13,
#    'kannada': 6,
#    'malayalam': 2,
#    'sanskrit': 2,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 3,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Memberoftheorganisingcommittee(AlgorithmicCodingEvent)of“Aatmatrisha”,theannualtechno\r\nculturalfestofPESUniversity,2018\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Epsilon”,theannualsciencefestofPES\r\nUniversity,2017\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Disha”,theannualfestofCMRNationalPublic\r\nSchool,2015\r\n●VolunteerfortheorganisingcommitteeofCodewarseventin"TheAmateurScientist"(anationallevel\r\nsciencefest,organizedbyPESUniversity),2016\r\n●MemberofthePenandInkClub(FAPS),2013andtheModelUnitedNationsClub(CMRNPS),2015,\r\n2016': 1},
#   'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 5,
#    'c': 31,
#    'c++': 19,
#    'css': 19,
#    'go': 9,
#    'html': 23,
#    'java': 11,
#    'javascript': 24,
#    'php': 21,
#    'python': 31,
#    'r': 6,
#    'rest': 7,
#    'scala': 4,
#    'sql': 9}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 6,
#    'c': 32,
#    'c++': 19,
#    'css': 23,
#    'go': 8,
#    'html': 25,
#    'java': 13,
#    'javascript': 26,
#    'php': 24,
#    'python': 32,
#    'r': 6,
#    'rest': 15,
#    'scala': 4,
#    'sql': 13}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 7,
#    'c': 44,
#    'c++': 30,
#    'csharp': 1,
#    'css': 29,
#    'go': 10,
#    'html': 32,
#    'java': 18,
#    'javascript': 35,
#    'php': 32,
#    'python': 44,
#    'r': 7,
#    'rest': 17,
#    'scala': 4,
#    'sql': 18}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 8,
#    'c': 43,
#    'c++': 23,
#    'css': 29,
#    'go': 10,
#    'html': 35,
#    'java': 20,
#    'javascript': 36,
#    'php': 30,
#    'python': 42,
#    'r': 8,
#    'rest': 16,
#    'scala': 4,
#    'sql': 17}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 7,
#    'c': 33,
#    'c++': 21,
#    'css': 21,
#    'go': 10,
#    'html': 26,
#    'java': 14,
#    'javascript': 28,
#    'php': 25,
#    'python': 33,
#    'r': 5,
#    'rest': 13,
#    'scala': 4,
#    'sql': 12}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 6,
#    'c': 33,
#    'c++': 21,
#    'css': 22,
#    'go': 10,
#    'html': 25,
#    'java': 13,
#    'javascript': 29,
#    'php': 26,
#    'python': 32,
#    'r': 6,
#    'rest': 14,
#    'scala': 4,
#    'sql': 13}},
#  "['ProjectDetailDomain_Data Structures', 'ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 6,
#    'c': 38,
#    'c++': 23,
#    'css': 26,
#    'go': 11,
#    'html': 31,
#    'java': 15,
#    'javascript': 34,
#    'php': 30,
#    'python': 36,
#    'r': 6,
#    'rest': 15,
#    'scala': 4,
#    'sql': 14}},
#  "['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 4,
#    'c': 32,
#    'c++': 18,
#    'css': 14,
#    'go': 12,
#    'html': 18,
#    'java': 10,
#    'javascript': 21,
#    'php': 17,
#    'python': 32,
#    'r': 5,
#    'rest': 10,
#    'scala': 4,
#    'sql': 11}},
#  "['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 8,
#    'c': 39,
#    'c++': 23,
#    'css': 24,
#    'go': 14,
#    'html': 28,
#    'java': 13,
#    'javascript': 30,
#    'php': 28,
#    'python': 39,
#    'r': 7,
#    'rest': 15,
#    'scala': 4,
#    'sql': 19}},
#  "['ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 8,
#    'c': 35,
#    'c++': 23,
#    'css': 22,
#    'go': 10,
#    'html': 24,
#    'java': 11,
#    'javascript': 27,
#    'php': 25,
#    'python': 33,
#    'r': 5,
#    'rest': 14,
#    'scala': 4,
#    'sql': 15}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'': 11,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '2010HelpageIndiafundraisingcampaign\r\n2018FloodrelieffundraisingcampaignforKerala\r\n2016-2019PartofCSR,PESUniversity': 1,
#    'Art': 6,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'BuiltthejudgesystemforBombTag,AnAllIndiaBotBuildingcompetitionforschoolstudentsatTheAmateurScientist2017.\r\nTheAmateurScientist,OrganiserforCodeWars\r\n': 1,
#    'Clubs': 7,
#    'Coding': 1,
#    'Communication': 6,
#    'Cooking': 2,
#    'CoreMemberforCSR-PESU.YearsofService:2017-2019SocialService': 1,
#    'Dance': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DeployedtheonlinejudgeserverusingDOMJudgeforCodewars,\r\nwhichisthepremiercompetitivecodingcompetitionatTheAmateur\r\nScientist2016.Wereceivedtheparticipationofover350teams\r\nfromacrossIndia.': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'HandledallthelogisticsforScienceShowdown,anintercollegeScienceExhibitionatEpsilon2017.\r\nTheAmateurScientist,OrganiserforBombTag\r\n': 1,
#    'Hardworkinganddiligent': 1,
#    'IEEE,StudentCoordinator\r\n•Workedcloselywithvariousteamsincollegetoorganiseworkshops\r\n,seminars,hackathonsandindustrialvisits.\r\nEpsilon,OrganiserforScienceShowdown\r\n': 1,
#    'Inquisitive': 5,
#    'Instruments': 4,
#    'Introductin\r\ntomachinelearning': 1,
#    'Leadership': 4,
#    'LinearAlgebra': 1,
#    'Motivated': 3,
#    'Music': 11,
#    'ProblemSolving': 7,
#    'Quiz': 3,
#    'ReinforcementLearning': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 2,
#    'Sports': 5,
#    'TeachingAssistant(AdvancedAlgorithms-UE18CS311)Coding': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 5,
#    'Theatre': 8,
#    'Timemanagement': 2,
#    'bengali': 1,
#    'english': 20,
#    'hindi': 20,
#    'kannada': 8,
#    'malayalam': 3,
#    'sanskrit': 6,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 3,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'NonAcademicSkills_present': {'': 10,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '1.2017-2019Hackathonorganizer.\r\nOrganizedtwo24-hourCShackathoncalledDotSlashand#codeatPESUniversity\r\nconductednyMicrosoftInnovationLabandAatmatrisharespectively.Morethan100team\r\nhadparticipated\r\n': 1,
#    '2017Volunteer.\r\nTeamInformals,Aatmatrisha2017:WasanactivememberwhohelpedinorganizingCS-GO\r\nandgullycricket.': 1,
#    '2018Volunteer.\r\nPrakalpa:HelpedintechnicalworkandbuiltanARappusingUnity.Theappwouldshow\r\ndifferentanimatedobjectswhenthecameraseesdifferntpatternsaroundthecampus\r\n': 1,
#    'ActivememberofCSRclubofPESUniversity,ScribeforvisuallychallengedstudentsofSamarthanamTrustfordisabled,•\tElectedasHouseCaptainfor3years(7th,9thand10thstandards)andSchoolPrefectintheacademicyear2016-17whilein12thstandardMusic': 1,
#    'Art': 8,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 11,
#    'Coding': 2,
#    'Communication': 9,
#    'Cooking': 2,
#    'CoreteammemberforEPSILON2017(AnnualTechnical\r\nFestofPESUniversity),Wasresponsibleforthetwo\r\nmajorevents-inQUIZitive(Quizevent)andRadioShack\r\n(ElectronicTreasureHunt).\r\nCampusAmbassadorforCitrixIndiaatPESUniversity\r\nAnactivememberofthePeerteachinginitiativeatPES\r\nUNIVERSITY.CurrentlycontributingasaPeerteacherfor\r\ntheDataStructurescourse.\r\nCoreteammemberororganizingteam,responsiblefor\r\nconductingtheethicalhackingworkshopatPrakalpa\r\n2017incoordinationwithSpyryTechnologies,\r\nBangalore.\r\nOrganizerandheadofmediaandpublicityforTAS(The\r\nAmateurScientist)2017.Inaddition,Eventheadfor\r\nBridgeIT.\r\nStudentExecutiveforcorporaterelationsforIET,\r\nStudentchapter,PESU,Bangalore(2016-2017)\r\nPromotedto:HeadandchairmanofIET,Student\r\nchapter,PESU,Bangalore,2017-18\r\nCoreteammemberofEWD(extendedweekday\r\nactivities)': 1,
#    'Dance': 3,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'ForeignLanguages': 2,
#    'Hardworkinganddiligent': 3,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Inquisitive': 9,
#    'Instruments': 5,
#    'Introductin\r\ntomachinelearning': 1,
#    'Leader': 1,
#    'Leadership': 6,
#    'LinearAlgebra': 1,
#    'MemberofCSR(CollegiateSocialResponsibility)Sports': 1,
#    'MentorforCAPS-PSRLLabatPESUniversitySports': 1,
#    'Motivated': 5,
#    'Music': 11,
#    'Organiserofcollegefest-Aatmatrisha,ClasscoordinatorinPrakalpaSciencefestTheatre': 1,
#    'ProblemSolving': 11,
#    'Publicspeaking': 1,
#    'Quiz': 2,
#    'ReinforcementLearning': 1,
#    'SamarapanLogisticsHeadhindi': 1,
#    'Samarpana,AatmatrishaSports': 1,
#    'SocialService': 5,
#    'Sports': 4,
#    'TeamWork': 8,
#    'Theatre': 10,
#    'Timemanagement': 8,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'VolunteeratCollegefestivalforRoboSoccereventduring“The\r\nRESPONSIBILITYAmateurScientist(2016)”\r\nOrganisedGamingeventatNPS,Indiranagarfor“Scientifica2015”Sports': 1,
#    'bengali': 1,
#    'english': 29,
#    'german': 1,
#    'hindi': 26,
#    'kannada': 18,
#    'malayalam': 2,
#    'marathi': 1,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 4,
#    'telugu': 5,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'OffCampusLearning_present']": {'NonAcademicSkills_present': {'': 8,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '(1)VolunteeredforAIKYAfoundationandAkshayaPathratoservemiddaymealstoschoolchildren.(2)VolunteeredforWorld’sLargestLesson(WLL)organisedbyAISEC.Music': 1,
#    'ActivememberofCSRclubofPESUniversity,ScribeforvisuallychallengedstudentsofSamarthanamTrustfordisabled,•\tElectedasHouseCaptainfor3years(7th,9thand10thstandards)andSchoolPrefectintheacademicyear2016-17whilein12thstandardMusic': 1,
#    'Art': 3,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 3,
#    'Coding': 3,
#    'Communication': 7,
#    'CoreMemberforCSR-PESU.YearsofService:2017-2019SocialService': 1,
#    'CoreteammemberforEPSILON2017(AnnualTechnical\r\nFestofPESUniversity),Wasresponsibleforthetwo\r\nmajorevents-inQUIZitive(Quizevent)andRadioShack\r\n(ElectronicTreasureHunt).\r\nCampusAmbassadorforCitrixIndiaatPESUniversity\r\nAnactivememberofthePeerteachinginitiativeatPES\r\nUNIVERSITY.CurrentlycontributingasaPeerteacherfor\r\ntheDataStructurescourse.\r\nCoreteammemberororganizingteam,responsiblefor\r\nconductingtheethicalhackingworkshopatPrakalpa\r\n2017incoordinationwithSpyryTechnologies,\r\nBangalore.\r\nOrganizerandheadofmediaandpublicityforTAS(The\r\nAmateurScientist)2017.Inaddition,Eventheadfor\r\nBridgeIT.\r\nStudentExecutiveforcorporaterelationsforIET,\r\nStudentchapter,PESU,Bangalore(2016-2017)\r\nPromotedto:HeadandchairmanofIET,Student\r\nchapter,PESU,Bangalore,2017-18\r\nCoreteammemberofEWD(extendedweekday\r\nactivities)': 1,
#    'Dance': 3,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'DataStructures': 1,
#    'DeepLearning': 1,
#    'DesignandAnalysisofAlgorithmsSports': 1,
#    'Hardworkinganddiligent': 2,
#    'Helpedinorganizing#Code2020ForeignLanguages': 1,
#    "HospitalitycoordinatoratAatmatrisha'19,Memberatrotaractclubkannada": 1,
#    'Inquisitive': 7,
#    'Instruments': 3,
#    'Introductin\r\ntomachinelearning': 1,
#    'Leader': 1,
#    'Leadership': 4,
#    'LinearAlgebra': 1,
#    'MentorforCAPS-PSRLLabatPESUniversitySports': 1,
#    'Motivated': 2,
#    'Music': 6,
#    'ProblemSolving': 8,
#    'ReinforcementLearning': 1,
#    'SocialService': 1,
#    'Sports': 3,
#    'TeachingAssistant(AdvancedAlgorithms-UE18CS311)Coding': 1,
#    'Teachingassistant-Designandanalysisofalgorithmslabhindi': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 6,
#    'Theatre': 3,
#    'Timemanagement': 2,
#    'Volunteer(2016)TheAmateurScientist,aneventheldatPESUniversity\r\n(Bangalore),thatprovidedanicheplatformforyoungminds\r\ntoshowcasetheirforteinvariousbranchesofscienceata\r\nprofessionallevel\r\nScienceand\r\nTechnology\r\nVolunteer(2017)Prakalpa,aneventheldatPESUniversity(Bangalore),\r\nwhereprojectsfromdifferentengineeringstreamsare\r\npresented\r\nScienceand\r\nTechnology': 3,
#    'Volunteer,GoogleMLStudyJam\r\n+Helpedinorganizing3dayhandsonsessionworkshoponmachinelearningstudyjamconductedbyGoogle\r\nDevelopers’GroupBengaluru.\r\nOrganizer,Samarpana\r\n+Collegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonandmanyprogramstoraise\r\nfundsandlookafterthewelfareofthemartyr’sfamilies\r\nOrganizer,AtmaTrisha\r\n+SuccessfullyorganizedFactionMasters,atechnicaleventatthecollegeannualfest.Art': 1,
#    'VolunteeratCollegefestivalforRoboSoccereventduring“The\r\nRESPONSIBILITYAmateurScientist(2016)”\r\nOrganisedGamingeventatNPS,Indiranagarfor“Scientifica2015”Sports': 1,
#    'english': 19,
#    'german': 2,
#    'hindi': 17,
#    'kannada': 6,
#    'malayalam': 3,
#    'sanskrit': 6,
#    'tamil': 6,
#    'telugu': 5,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2,
#    '●Memberoftheorganisingcommittee(AlgorithmicCodingEvent)of“Aatmatrisha”,theannualtechno\r\nculturalfestofPESUniversity,2018\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Epsilon”,theannualsciencefestofPES\r\nUniversity,2017\r\n●Memberofthecoreteamoftheorganisingcommitteeof“Disha”,theannualfestofCMRNationalPublic\r\nSchool,2015\r\n●VolunteerfortheorganisingcommitteeofCodewarseventin"TheAmateurScientist"(anationallevel\r\nsciencefest,organizedbyPESUniversity),2016\r\n●MemberofthePenandInkClub(FAPS),2013andtheModelUnitedNationsClub(CMRNPS),2015,\r\n2016': 1,
#    '●Participatedin3blooddonationcampsfor1000peopleorganizedbyCSR(CollegiateSocial\r\nResponsibility)clubheldatPESUniversity,Mar2019Art': 1},
#   'OffCampusLearning_present': {'Algorithms': 5,
#    'AppDevelopment': 3,
#    'ArtificialIntelligence': 1,
#    'Blockchain': 1,
#    'Cloudcomputing': 7,
#    'ComputerNetworks': 1,
#    'DataSience': 2,
#    'DataStructures': 2,
#    'DatabaseManagementSystem': 1,
#    'DeepLearning': 1,
#    'GameDevelopment': 1,
#    'Heterogenousparallelism': 1,
#    'ImageProcessing': 7,
#    'IoT': 3,
#    'MachineLearning': 2,
#    'OperatingSystem': 2,
#    'ReinforcementLearning': 1,
#    'Robotics': 1,
#    'WebDevelopment': 2,
#    'cie': 7,
#    'cloud': 1,
#    'coursera': 6,
#    'datascience': 4,
#    'deeplearning': 4,
#    'german': 1,
#    'google': 2,
#    'harvard': 1,
#    'ibm': 1,
#    'ieee': 8,
#    'iisc': 4,
#    'linkedin': 1,
#    'machinelearning': 4,
#    'mooc': 1,
#    'neuralnetworks': 1,
#    'nitk': 2,
#    'nptel': 3,
#    'patternrecognition': 1,
#    'pes': 7,
#    'robotics': 1,
#    'stanford': 4,
#    'tedx': 1}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']": {'NonAcademicSkills_present': {'': 10,
#    '\r\nEngineeringMathematicsII': 1,
#    '#\r\nEngineeringMathematicsI': 1,
#    '#\r\nIntroductiontoDataScience': 1,
#    '1.2017-2019Hackathonorganizer.\r\nOrganizedtwo24-hourCShackathoncalledDotSlashand#codeatPESUniversity\r\nconductednyMicrosoftInnovationLabandAatmatrisharespectively.Morethan100team\r\nhadparticipated\r\n': 1,
#    '2017Volunteer.\r\nTeamInformals,Aatmatrisha2017:WasanactivememberwhohelpedinorganizingCS-GO\r\nandgullycricket.': 1,
# ...
#    'Dance': 4,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'ForeignLanguages': 2,
#    'Hardworkinganddiligent': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Inquisitive': 8,
#    'Instruments': 2,
#    'Leadership': 5,
#    'MUN': 2,
#    'MemberofCSR(CollegiateSocialResponsibility)Sports': 1,
#    'Motivated': 5,
#    'Music': 9,
#    'Organiserofcollegefest-Aatmatrisha,ClasscoordinatorinPrakalpaSciencefestTheatre': 1,
#    'Prakalpa(ScienceFest):Organizerteam\r\nAatmatrisha(techno-culturalFest):Volunteer\r\nRotractClubofPesUniversity:VolunteerDance': 1,
#    'ProblemSolving': 9,
#    'Publicspeaking': 1,
#    'Quiz': 2,
#    'RegistrationsVolunteeratEpsilonCollegeFest,CampaigningOrganizerforTheAmateurScientist.kannada': 1,
#    'SamarapanLogisticsHeadhindi': 1,
#    'Samarpana,AatmatrishaSports': 1,
#    'SocialService': 5,
#    'Sports': 4,
#    'TeamWork': 9,
#    'Theatre': 6,
#    'Timemanagement': 7,
#    'Tookpartinnumerousdanceanddramacompetitionsduringschooldays.\r\n●MemberoftheSchoolandPre-universitycollegeSoccerteams.\r\n●Activelyparticipatingincollegefootballeventsandfests.': 1,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'bengali': 1,
#    'english': 30,
#    'hindi': 29,
#    'kannada': 17,
#    'malayalam': 2,
#    'marathi': 2,
#    'sanskrit': 4,
#    'spanish': 2,
#    'tamil': 6,
#    'telugu': 6,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']": {'NonAcademicSkills_present': {'Art': 4,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 2,
#    'Coding': 3,
#    'Communication': 5,
#    'ContentCreator-ParikramaFoundation(2019)|PrimarySchoolEnglishTeacher(Assistant)-BGMSShishukunjVidyalaya(2018)MUN': 1,
#    'CoreMemberforCSR-PESU.YearsofService:2017-2019SocialService': 1,
#    'CoreteammemberforEPSILON2017(AnnualTechnical\r\nFestofPESUniversity),Wasresponsibleforthetwo\r\nmajorevents-inQUIZitive(Quizevent)andRadioShack\r\n(ElectronicTreasureHunt).\r\nCampusAmbassadorforCitrixIndiaatPESUniversity\r\nAnactivememberofthePeerteachinginitiativeatPES\r\nUNIVERSITY.CurrentlycontributingasaPeerteacherfor\r\ntheDataStructurescourse.\r\nCoreteammemberororganizingteam,responsiblefor\r\nconductingtheethicalhackingworkshopatPrakalpa\r\n2017incoordinationwithSpyryTechnologies,\r\nBangalore.\r\nOrganizerandheadofmediaandpublicityforTAS(The\r\nAmateurScientist)2017.Inaddition,Eventheadfor\r\nBridgeIT.\r\nStudentExecutiveforcorporaterelationsforIET,\r\nStudentchapter,PESU,Bangalore(2016-2017)\r\nPromotedto:HeadandchairmanofIET,Student\r\nchapter,PESU,Bangalore,2017-18\r\nCoreteammemberofEWD(extendedweekday\r\nactivities)': 1,
#    'Dance': 4,
#    'Hardworkinganddiligent': 1,
#    'Inquisitive': 4,
#    'Instruments': 2,
#    'Leadership': 3,
#    'MUN': 2,
#    'Motivated': 2,
#    'Music': 8,
#    'ProblemSolving': 6,
#    'Publicspeaking': 1,
#    'SamarapanLogisticsHeadhindi': 1,
#    "SamarpanaCollegeclubtospreadsocialawarenessaboutarmedforces.Conductedamarathonand\r\nmanyprogramstolookafterthewelfareofmartyrs'families.\r\nGooglesCloudMachineLearningStudyJam3-daymeetuporganisedbyGoogleDeveloper\r\nGroupBengalurutogivetutorialsonMLtoattendees,andahandsonexperienceonTensorFlow\r\nlibrary.": 3,
#    'SocialService': 1,
#    'Sports': 5,
#    'TeachingAssistant(AdvancedAlgorithms-UE18CS311)Coding': 1,
#    'Teachingassistant-Designandanalysisofalgorithmslabhindi': 1,
#    'TeamWork': 6,
#    'Theatre': 3,
#    'Timemanagement': 4,
#    'Tookpartinnumerousdanceanddramacompetitionsduringschooldays.\r\n●MemberoftheSchoolandPre-universitycollegeSoccerteams.\r\n●Activelyparticipatingincollegefootballeventsandfests.': 1,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'english': 20,
#    'hindi': 17,
#    'kannada': 11,
#    'malayalam': 3,
#    'sanskrit': 5,
#    'tamil': 10,
#    'telugu': 7,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2}},
#  "['ProjectDetailDomain_Image Processing', 'NonAcademicSkills_present', 'ProjectDetailDomain_Database Management System', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Machine Learning']": {'NonAcademicSkills_present': {'AatmatrishaFest2018LITandQuizVolunteerkannada': 1,
#    'Art': 6,
#    'BlooddonationtoBangaloreMedicalServicesTrustandPESMedicalCollege.\r\nVolunteeredforinter-collegeScienceFest.\r\nAnactivememberofRashtrotthanaOldStudentsOrganizationforTransformingSociety.\r\nParticipatedinCyclerallytospreadawarenessregardingEnvironmentprotectiononWorld\r\nEnvironmentDay.kannada': 2,
#    'Clubs': 2,
#    'Coding': 2,
#    'Communication': 5,
#    'Dance': 4,
#    'Inquisitive': 6,
#    'Instruments': 2,
#    'Leadership': 3,
#    'MUN': 2,
#    'Motivated': 2,
#    'Music': 9,
#    'Prakalpa(ScienceFest):Organizerteam\r\nAatmatrisha(techno-culturalFest):Volunteer\r\nRotractClubofPesUniversity:VolunteerDance': 1,
#    'ProblemSolving': 8,
#    'Publicspeaking': 1,
#    'RegistrationsVolunteeratEpsilonCollegeFest,CampaigningOrganizerforTheAmateurScientist.kannada': 1,
#    'SamarapanLogisticsHeadhindi': 1,
#    'Samarpana,AatmatrishaSports': 1,
#    'Sports': 5,
#    'TeachingAssistant(AdvancedAlgorithms-UE18CS311)Coding': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 8,
#    'Theatre': 2,
#    'Timemanagement': 4,
#    'Tookpartinnumerousdanceanddramacompetitionsduringschooldays.\r\n●MemberoftheSchoolandPre-universitycollegeSoccerteams.\r\n●Activelyparticipatingincollegefootballeventsandfests.': 1,
#    'english': 25,
#    'hindi': 23,
#    'kannada': 13,
#    'malayalam': 3,
#    'marathi': 2,
#    'sanskrit': 6,
#    'tamil': 10,
#    'telugu': 5,
#    '•Anactiveandacorememberofthe\r\nCollegiateSocialResponsibility(CSR)Team\r\n•Anactivevolunteerinvariouscollegefests\r\nandapartoftheorganizingteamofTEDxin\r\ncollege.\r\n•Selectedforprojectdisplayintheannual\r\nSciencefest-Prakalpa.\r\n•Educatingunderprivilegedchildren,\r\norganizingBlooddonationcampsand\r\nenvironmentfriendlyactivities\r\n•OrganizedNaturalcalamitydrivesSports': 2}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 6,
#    'c': 32,
#    'c++': 16,
#    'css': 20,
#    'go': 8,
#    'html': 27,
#    'java': 10,
#    'javascript': 29,
#    'php': 23,
#    'python': 32,
#    'r': 5,
#    'rest': 7,
#    'scala': 4,
#    'sql': 16}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'InternshipProjectDomain_Cloud computing', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 8,
#    'c': 40,
#    'c++': 24,
#    'css': 21,
#    'go': 13,
#    'html': 27,
#    'java': 13,
#    'javascript': 33,
#    'matlab': 2,
#    'php': 26,
#    'python': 40,
#    'r': 7,
#    'rest': 12,
#    'scala': 4,
#    'sql': 19}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 10,
#    'c': 45,
#    'c++': 29,
#    'css': 30,
#    'go': 9,
#    'html': 34,
#    'java': 14,
#    'javascript': 36,
#    'php': 31,
#    'python': 45,
#    'r': 8,
#    'rest': 16,
#    'scala': 4,
#    'sql': 22}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Algorithms']": {'ProgLanguagesNLP_present': {'ajax': 3,
#    'arduino': 9,
#    'c': 35,
#    'c++': 22,
#    'css': 21,
#    'go': 10,
#    'html': 25,
#    'java': 11,
#    'javascript': 28,
#    'matlab': 2,
#    'php': 26,
#    'python': 35,
#    'r': 6,
#    'rest': 15,
#    'scala': 4,
#    'sql': 20}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 6,
#    'arduino': 13,
#    'c': 44,
#    'c++': 32,
#    'css': 27,
#    'go': 12,
#    'html': 31,
#    'java': 13,
#    'javascript': 34,
#    'php': 30,
#    'python': 43,
#    'r': 7,
#    'rest': 13,
#    'scala': 4,
#    'sql': 19}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Compiler Design', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 11,
#    'c': 31,
#    'c++': 24,
#    'css': 21,
#    'go': 10,
#    'html': 25,
#    'java': 16,
#    'javascript': 27,
#    'php': 22,
#    'python': 31,
#    'r': 7,
#    'rest': 13,
#    'scala': 2,
#    'sql': 14}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Algorithms']": {'ProgLanguagesNLP_present': {'ajax': 2,
#    'arduino': 8,
#    'c': 32,
#    'c++': 15,
#    'css': 21,
#    'go': 5,
#    'html': 26,
#    'java': 12,
#    'javascript': 26,
#    'php': 22,
#    'python': 32,
#    'r': 5,
#    'rest': 12,
#    'scala': 4,
#    'sql': 18}},
#  "['ProjectDetailDomain_Image Processing', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 10,
#    'c': 35,
#    'c++': 22,
#    'css': 23,
#    'go': 9,
#    'html': 29,
#    'java': 12,
#    'javascript': 31,
#    'php': 27,
#    'python': 35,
#    'r': 8,
#    'rest': 11,
#    'scala': 4,
#    'sql': 16}},
#  "['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 8,
#    'c': 42,
#    'c++': 28,
#    'css': 27,
#    'go': 11,
#    'html': 32,
#    'java': 13,
#    'javascript': 37,
#    'php': 33,
#    'python': 40,
#    'r': 7,
#    'rest': 15,
#    'scala': 4,
#    'sql': 20}},
#  "['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 8,
#    'c': 32,
#    'c++': 20,
#    'css': 22,
#    'go': 9,
#    'html': 24,
#    'java': 11,
#    'javascript': 27,
#    'php': 25,
#    'python': 30,
#    'r': 5,
#    'rest': 13,
#    'scala': 4,
#    'sql': 15}},
#  "['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ElectiveCourseName_big data::A and higher']": {'ProgLanguagesNLP_present': {'ajax': 4,
#    'arduino': 8,
#    'c': 40,
#    'c++': 21,
#    'css': 28,
#    'go': 11,
#    'html': 35,
#    'java': 14,
#    'javascript': 37,
#    'php': 33,
#    'python': 39,
#    'r': 5,
#    'rest': 13,
#    'scala': 4,
#    'sql': 20}},
#  "['ProjectDetailDomain_Image Processing', 'ProjectDetailDomain_Database Management System', 'ProgLanguagesNLP_present', 'ProjectDetailDomain_Cloud computing', 'ProjectDetailDomain_Operating System']": {'ProgLanguagesNLP_present': {'ajax': 5,
#    'arduino': 8,
#    'c': 36,
#    'c++': 22,
#    'css': 22,
#    'go': 10,
#    'html': 27,
#    'java': 12,
#    'javascript': 31,
#    'php': 27,
#    'python': 34,
#    'r': 5,
#    'rest': 14,
#    'scala': 4,
#    'sql': 18}},
#  "['ProjectDetailDomain_Image Processing', 'ScholarshipsNLP_cnr', 'NonAcademicSkills_present', 'InternshipProjectDomain_Image Processing', 'ProjectDetailDomain_Cloud computing']": {'NonAcademicSkills_present': {'': 3,
#    '(1)VolunteeredforAIKYAfoundationandAkshayaPathratoservemiddaymealstoschoolchildren.(2)VolunteeredforWorld’sLargestLesson(WLL)organisedbyAISEC.Music': 1,
#    'AatmatrishaFest2018LITandQuizVolunteerkannada': 1,
#    'Art': 4,
#    'BuiltthejudgesystemforBombTag,AnAllIndiaBotBuildingcompetitionforschoolstudentsatTheAmateurScientist2017.\r\nTheAmateurScientist,OrganiserforCodeWars\r\n': 1,
#    'Clubs': 5,
#    'Coding': 1,
#    'Communication': 9,
#    'Cooking': 2,
#    'DataAnalyticsTeachingAssistantunderProf.GowriSrinivas.Theatre': 1,
#    'DeployedtheonlinejudgeserverusingDOMJudgeforCodewars,\r\nwhichisthepremiercompetitivecodingcompetitionatTheAmateur\r\nScientist2016.Wereceivedtheparticipationofover350teams\r\nfromacrossIndia.': 1,
#    'HandledallthelogisticsforScienceShowdown,anintercollegeScienceExhibitionatEpsilon2017.\r\nTheAmateurScientist,OrganiserforBombTag\r\n': 1,
#    'Hardworkinganddiligent': 2,
#    'HeadofSocialMediaand\r\nDigitalInitiatives,\r\nSamarpana2019.\r\nSamarpanaisaunique\r\nstudentinitiativeatPES\r\nUniversitywhichhasbeen\r\nsupportingand\r\nencouragingmartyr\r\nfamiliesfrom2009.\r\nBookdrive,organisedby\r\ntheRotaractClubofPES\r\nUniversity.': 1,
#    'Helpedinorganizing#Code2020ForeignLanguages': 1,
#    'IEEE,StudentCoordinator\r\n•Workedcloselywithvariousteamsincollegetoorganiseworkshops\r\n,seminars,hackathonsandindustrialvisits.\r\nEpsilon,OrganiserforScienceShowdown\r\n': 1,
#    'Inquisitive': 10,
#    'Instruments': 1,
#    'Leadership': 5,
#    'MemberofCSR(CollegiateSocialResponsibility)Sports': 1,
#    'MentorforCAPS-PSRLLabatPESUniversitySports': 1,
#    'Motivated': 5,
#    'Music': 4,
#    'Organiserofcollegefest-Aatmatrisha,ClasscoordinatorinPrakalpaSciencefestTheatre': 1,
#    'ProblemSolving': 8,
#    'Quiz': 2,
#    'SOCIETYMEMBERSHIPS\r\nIEEEStudentMember\r\nMemberNumber:96238500Instruments': 1,
#    'Samarpana,AatmatrishaSports': 1,
#    'SocialService': 3,
#    'TeachingAssistant(AdvancedAlgorithms-UE18CS311)Coding': 1,
#    'Teachingassistant-Designandanalysisofalgorithmslabhindi': 1,
#    'TeachingassistantforthecourseDataAnalytics,2020.Organizer-Aatmatrisha.MemberofCSRClub,PESU.Music': 1,
#    'TeamWork': 13,
#    'Theatre': 4,
#    'Timemanagement': 5,
#    'Volunteer@RotaractClubofPESUniversityandwasthechairpersonforKiteFightevent.Sports': 1,
#    'bengali': 1,
#    'english': 25,
#    'german': 1,
#    'hindi': 22,
#    'kannada': 16,
#    'malayalam': 1,
#    'sanskrit': 2,
#    'spanish': 2,
#    'tamil': 2,
#    'telugu': 1,
#    '•\tVolunteeredinRotaractClubofPESinabookdriveanddistributingittoorphanageandcelebratingIndependenceDaywiththem': 1}}}
