# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import matplotlib.pyplot as plt; plt.rcdefaults() 
import pandas.plotting as scatter_matrix

# %%
df = pd.read_csv('C:\\Users\\diyas\\Desktop\\Recommendation_system\\vppyh-mao32.csv',skipinitialspace=True) 
df.head()
# Out:
#             SRN                       Name        Mobile  \
# 0  01FB14EBT900                MADHURIMA.M  8.095684e+09
# 1  01FB14ECS036              ANUJAY SHARMA           NaN
# 2  01FB14ECV045     MANJU SUBHASH PARITALA  8.088431e+09
# 3  01FB14EEC188                SHREYAS M R  9.845743e+09
# 4  01FB14EME056  GAGGERA VENKATA SRIHARSHA  9.985781e+09
#
#                            Email Program Branch  CGPA Placement Status  \
# 0         rima.madgula@gmail.com  B.Tech     BT  0.00       Not Placed
# 1             anujay96@gmail.com  B.Tech    CSE  6.58    Not Intersted
# 2     manju.subhash.ms@gmail.com  B.Tech     CV  6.42    Not Intersted
# 3        shreyas.22796@gmail.com  B.Tech    ECE  5.94    Not Intersted
# 4  gaggerasriharsha215@gmail.com  B.Tech     ME  5.17    Not Intersted
#
#   CompanyName  CTC  TierLevel                       Reason
# 0         NaN  NaN        NaN                          NaN
# 1         NaN  NaN        NaN  Planning For Higher Studies
# ...

# %%
#making a dataframe with only CSE
b1=df["Branch"].str.count("CSE").sum()
df1=df[df["Branch"] == 'CSE']#only CS
for i in ['Mobile','Email','Program','Branch','Branch','Placement Status','CompanyName','CTC','TierLevel','Reason']: 
    df1[i] = df1[i].replace(np.nan,"Data Unavailable") 
    df1[i] = df1[i].replace(" ","Data Unavailable") 
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#anolmolies for cgpa
#boxplot
path2 = pd.DataFrame(df1.CGPA) 
ax = path2.plot.box() 
plt.show() 
mean=np.mean(df["CGPA"])
mean
# Out:
# 8.044705882352947

# %%
#piechart to show propotion of placed,not placed
n1=df1["Placement Status"].str.count("Not Placed").sum()
n2=df1["Placement Status"].str.count("Placed").sum()
n3=df1["Placement Status"].str.count("Not Intersted").sum()
path3= pd.DataFrame({'Placement Status': [n2,n3,n1]},index=['Placed','Not Intersted','Not Placed']) 
plot = path3.plot.pie(y='Placement Status', figsize=(7,7)) 
plt.show()

# %%
#piechart for tier 
#df1["TierLevel"] = df1["TierLevel"].replace(np.nan,"0") 
df1["TierLevel"] = df1["TierLevel"].astype(str)
p1=df1["TierLevel"].str.count("1").sum() 
p2=df1["TierLevel"].str.count("2").sum() 
p3=df1["TierLevel"].str.count("3").sum() 
path3= pd.DataFrame({'TierLevel': [p1,p2,p3]},index=['Tier 1','Tier 2','Tier 3']) 
plot = path3.plot.pie(y='TierLevel', figsize=(7,7)) 
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#making seperate dataframes based on range of cgpa
dfage1=df1[df1['CGPA']>=9.5] 
dfage2=df1[(df1['CGPA']>=8.5) & (df1['CGPA']<9.5)]  
dfage3=df1[(df1['CGPA']>=7.5) & (df1['CGPA']<8.5)] 
dfage4=df1[(df1['CGPA']<7.5)]

# %%
#count of CS student per CGPA level
c1 = dfage1.shape[0]
c2 = dfage2.shape[0]
c3 = dfage3.shape[0]
c4 = dfage4.shape[0]

# %%
#count of not placed per cgpa level
q1=dfage1["Placement Status"].str.count("Not Placed").sum()
q2=dfage1["Placement Status"].str.count("Placed").sum()
q3=dfage1["Placement Status"].str.count("Not Intersted").sum()

q4=dfage2["Placement Status"].str.count("Not Placed").sum()
q5=dfage2["Placement Status"].str.count("Placed").sum()
q6=dfage2["Placement Status"].str.count("Not Intersted").sum()

q7=dfage3["Placement Status"].str.count("Not Placed").sum()
q8=dfage3["Placement Status"].str.count("Placed").sum()
q9=dfage3["Placement Status"].str.count("Not Intersted").sum()

q10=dfage4["Placement Status"].str.count("Not Placed").sum()
q11=dfage4["Placement Status"].str.count("Placed").sum()
q12=dfage4["Placement Status"].str.count("Not Intersted").sum()

# %%
#histogram for CGPA
df1.hist(column='CGPA')
plt.show()

# %%
#barplot for CGPA and placed
objects = ('below 7.5','7.5 to 8.5','8.5-9','above 9.5') 
y_pos = np.arange(len(objects)) 
performance = [q11,q8,q5,q2] 
plt.barh(y_pos, performance, align='center', alpha=0.5) 
plt.yticks(y_pos, objects) 
plt.xlabel('Number placed') 
plt.ylabel('CGPA level') 
plt.title('Number of student placed per CGPA level')
# Out:
# Text(0.5, 1.0, 'Number of student placed per CGPA level')

# %%
#barplot for CGPA and not placed
objects = ('below 7.5','7.5 to 8.5','8.5-9','above 9.5') 
y_pos = np.arange(len(objects)) 
performance = [q10,q7,q4,q1] 
plt.barh(y_pos, performance, align='center', alpha=0.5) 
plt.yticks(y_pos, objects) 
plt.xlabel('Number not placed') 
plt.ylabel('CGPA level') 
plt.title('Number of student not placed per CGPA level')
# Out:
# Text(0.5, 1.0, 'Number of student not placed per CGPA level')

# %%
#histogram for CTC
df1["CTC"] = df1["CTC"].replace("Data Unavailable",np.nan) 
df1["CTC"] = df1["CTC"].fillna(0).astype(int)
df1.hist(column=["CTC"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019C4048ABE0>]],
#       dtype=object)

# %%
#wordcloud 
for i in ['CompanyName']: 
    df1[i] = df1[i].replace(np.nan," ") 
    df1[i]= df1[i].replace("nan"," ")
    df1[i]= df1[i].replace("NaN"," ")

from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# Reads 'Youtube04-Eminem.csv' file  
df= pd.read_csv('C:\\Users\\diyas\\Desktop\\Recommendation_system\\vppyh-mao32.csv',skipinitialspace=True, encoding ="latin-1") 
df1=df[df["Branch"] == 'CSE']#only CS
for i in ['CompanyName']: 
    df1[i] = df1[i].replace(np.nan," ") 
    df1[i]= df1[i].replace("nan"," ")
    df1[i]= df1[i].replace("NaN"," ")
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df1.CompanyName: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1['CompanyName'].value_counts()
# Out:
#                                         131
# Deloitte                                 13
# Microsoft                                11
# Cerner                                   10
# Citrix                                    7
# Goldman Sachs                             7
# Cisco                                     7
# HPE                                       6
# Oracle                                    6
# Walmart Labs                              5
# LogMeIn                                   5
# Nasdaq                                    4
# Accenture                                 4
# Philips                                   4
# Atos                                      4
# Autoninja                                 4
# Instamojo                                 3
# Societe Generale                          3
# Epsilon                                   3
# Collins Aerospace                         3
# Mahindra Comviva                          3
# ...

# %%
df1["TierLevel"] = df1["TierLevel"].astype(int)
df1.plot(kind='scatter',x='TierLevel', y='CGPA',color='red')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#only for placed
df6=df1[df1["Placement Status"]=="Placed"] 
df6["CTC"] = df6["CTC"].astype(int)
df6.plot(kind='scatter',x='CTC', y='CGPA',color='red')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1.groupby('TierLevel')['CTC'].nunique().plot(kind='bar')
plt.show()

# %%
df1.groupby('TierLevel')['CGPA'].nunique().plot(kind='bar')
plt.show()

# %%
df1.groupby('TierLevel')['CompanyName'].nunique().plot(kind='bar')
plt.show()

# %%
dfage1.groupby(['TierLevel','CGPA'])['TierLevel'].size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
df1
# Out:
#               SRN                           Name            Mobile  \
# 1    01FB14ECS036                  ANUJAY SHARMA  Data Unavailable
# 53   01FB15ECS001                       A LOKESH       7.02231e+09
# 54   01FB15ECS001                       A LOKESH       7.02231e+09
# 55   01FB15ECS002                    A N SANJITH       8.13065e+09
# 56   01FB15ECS003                   ABDUL REHMAN        9.9005e+09
# 57   01FB15ECS004                 ABDULLAH ANWAR       9.03107e+09
# 58   01FB15ECS005                  ABHIJAY GUPTA       9.97812e+09
# 59   01FB15ECS006             ABHILASH R KASHYAP       9.98604e+09
# 60   01FB15ECS008               ABHISHEK DWIVEDI       9.93593e+09
# 61   01FB15ECS009            ABHISHEK SRIVASTAVA       8.00493e+09
# 62   01FB15ECS010            ABHISHEK V DESHETTY       9.90295e+09
# 63   01FB15ECS012                        ADARSHA       8.86146e+09
# 64   01FB15ECS014               ADITHYA P MALLAR       9.68652e+09
# ...
