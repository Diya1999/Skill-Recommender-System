# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import matplotlib.pyplot as plt; plt.rcdefaults() 
import pandas.plotting as scatter_matrix 
import ast

# %%
df = pd.read_csv('C:\\Users\\diyas\\Documents\\Recommendation_system\\PLACED_Academics+Placement_1516_SeperateCourseNameGrade.csv',skipinitialspace=True) 
df.head()
# Out:
#    Unnamed: 0  StudentId           USN                Name        Mobile  \
# 0           2       4253  01FB15ECS001            A LOKESH  7.022305e+09
# 1           4       4255  01FB15ECS003        ABDUL REHMAN  9.900503e+09
# 2           5       4256  01FB15ECS004      ABDULLAH ANWAR  9.031074e+09
# 3           7       4258  01FB15ECS006  ABHILASH R KASHYAP  9.986044e+09
# 4           8       4260  01FB15ECS008    ABHISHEK DWIVEDI  9.935926e+09
#
#                           Email  CGPA  \
# 0       alokeshnaidu7@gmail.com  7.85
# 1   meet.abdul.online@gmail.com  7.34
# 2  abdullahanwar@rocketmail.com  7.78
# 3            abhi1097@gmail.com  8.85
# 4      abhishekdwi.05@gmail.com  7.78
#
#                                              Courses  EarnedCredits  \
# 0  {'Core Courses': [{"{'Code': 'UE15CS101', 'Nam...          176.0
# 1  {'Core Courses': [{"{'Code': 'UE15CS101', 'Nam...          176.0
# 2  {'Core Courses': [{"{'Code': 'UE15CS101', 'Nam...          176.0
# ...

# %%
df.CourseName=df.CourseName.apply(lambda s: list(ast.literal_eval(s)))
df.CourseGrade=df.CourseGrade.apply(lambda s: list(ast.literal_eval(s)))

# %%
#list of electives
electives=['special tpoic: basic of unix programming',
 'fuzzy logic',
 'special topic : programming with python',
 'special topic : c++ programming - i',
 'advanced algorithms',
 'processor & soc architecture',
 'computer graphics and visualization',
 'data analytics',
 'natural language processing',
 'advanced computer networks',
 'semantic web technologies',
 'digital image processing',
 'research methodology',
 'enterprise resource planning',
 'design patterns',
 'information security',
 'optical networks',
 'android application development',
 'introduction to business',
 'advanced machine learning',
 'project work',
 'advanced database management systems',
 'big data',
 'multimedia computing',
 'artificial intelligence',
 'computer network security',
 'storage area networks',
 'high performance computing architecture ',
 'drone computing',
 'knowledge management',
 'system modeling and simulation',
 'programming with java',
 'algorithms for information retrieval',
 'content management',
 'wireless network communications',
 'social network analytics',
 'design pattern',
 'autonomous mobile robotics',
 'human computer interaction',
 'open source networking',
 'internet of things',
 'design of bitcoin and blockchain systems',
 'research credits',
 'introduction to software testing',
 'internship',
 'advanced data base management systems',
 'generic programming',
 'knowledge management',
 'reconfigurable computing',
 'linux kernal internals',
 'programming with c++',
 'applied cryptography',
 'professional skills for software engineers - i',
 'mini project',
 'topics in deep learning',
 'blockchain architecture design and use cases ',
 'reinforcement learning',
 'computer forensics',
 'performance engineering',
 'project work  minor',
 'cie - level ii',
 'research project',
 'introduction to entrepreneurship - level 1',
 'cie - level i',
 'swachh bharat abhiyaan',
 'serious python',
 'professional skills for sofware engineers',
 'classical cryptoanalysis',
 'network and mobile security',
 'big data analytics using spark']

# %%
for i in range(0,len(df)): 
    for j in range(0,len(df['CourseName'][i])):
        df['CourseName'][i][j]=df['CourseName'][i][j].lower()

# %%
df["ElectiveList"] = ""
df["ElectiveGrade"] = ""

# %%
for i in range(0,len(df)): 
    el=[]
    grade=[]
    for j in range(0,len(df['CourseName'][i])):
        if(df['CourseName'][i][j] in electives):
            el.append(df['CourseName'][i][j])
            grade.append(df['CourseGrade'][i][j])
    df['ElectiveList'][i]=el
    df['ElectiveGrade'][i]=grade
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.to_csv('C:\\Users\\diyas\\Documents\\Recommendation_system\\PLACED_Academics+Placement_1516_SeperateElectiveList.csv')

# %%
print(len(df['ElectiveGrade'][2]))
print(len(df['ElectiveList'][3]))
# Out:
# 9
# 8

# %%
plt.plot(df.iloc[90]['ElectiveGrade'],df.iloc[90]['ElectiveList'])

# %%
dfL1 = pd.DataFrame(df.ElectiveList.values.tolist(), index=df.index).stack()
dfL2 = pd.DataFrame(df.ElectiveGrade.values.tolist(), index=df.index).stack()

# %%
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))

# %%
#top 15 electives chosen (overall)
df1.ElectiveList1.value_counts()[0:15].plot(kind='bar')

# %%
#cumalative elective grades
df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie')

# %%
#electives based on tier Ranges
#splitting data frame into 3 
dft1=df[df['TierLevel'] == 1]
dft2=df[df['TierLevel'] ==2]
dft3=df[df['TierLevel'] ==3]

# %%
#tier 1
dfL1 = pd.DataFrame(dft1.ElectiveList.values.tolist(), index=dft1.index).stack()
dfL2 = pd.DataFrame(dft1.ElectiveGrade.values.tolist(), index=dft1.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for tier 2 jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# elective grades in tier 1
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#tier 2
dfL1 = pd.DataFrame(dft2.ElectiveList.values.tolist(), index=dft2.index).stack()
dfL2 = pd.DataFrame(dft2.ElectiveGrade.values.tolist(), index=dft2.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for tier 2 jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# elective grades in tier 1
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#tier 3
dfL1 = pd.DataFrame(dft3.ElectiveList.values.tolist(), index=dft3.index).stack()
dfL2 = pd.DataFrame(dft3.ElectiveGrade.values.tolist(), index=dft3.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for tier 3 jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# elective grades in tier 3
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#High CTC >35 Companies : what electives?
dfdream=df[df['CTC'] > 35]
dfL1 = pd.DataFrame(dfdream.ElectiveList.values.tolist(), index=dfdream.index).stack()
dfL2 = pd.DataFrame(dfdream.ElectiveGrade.values.tolist(), index=dfdream.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for high paying jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
#highest S: good academic performance
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Electives based on company 
df.CompanyName.value_counts()[0:5]
# Out:
# Accenture              62
# Cisco Systems          34
# Akamai Technologies    30
# Walmart Labs           26
# IBM INDIA PVT LTD      22
# Name: CompanyName, dtype: int64

# %%
#Accenture : what electives?
dfaccenture=df[df['CompanyName'] == 'Accenture']
dfL1 = pd.DataFrame(dfaccenture.ElectiveList.values.tolist(), index=dfaccenture.index).stack()
dfL2 = pd.DataFrame(dfaccenture.ElectiveGrade.values.tolist(), index=dfaccenture.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for high paying jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48b501f0ab21> in <module>()
#       1 #Accenture : what electives?
# ----> 2 dfaccenture=df[df['CompanyName'] == 'Accenture']
#       3 dfL1 = pd.DataFrame(dfaccenture.ElectiveList.values.tolist(), index=dfaccenture.index).stack()
#       4 dfL2 = pd.DataFrame(dfaccenture.ElectiveGrade.values.tolist(), index=dfaccenture.index).stack()
#       5 df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#
# NameError: name 'df' is not defined

# %%
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
#Cisco Systems : what electives?
dfcisco=df[df['CompanyName'] == 'Cisco Systems']
dfL1 = pd.DataFrame(dfcisco.ElectiveList.values.tolist(), index=dfcisco.index).stack()
dfL2 = pd.DataFrame(dfcisco.ElectiveGrade.values.tolist(), index=dfcisco.index).stack()
df1= pd.concat([dfL1, dfL2], axis=1, keys=('ElectiveList1','ElectiveGrade1'))
#top 10 electives chosen for high paying jobs
print(df1.ElectiveList1.value_counts()[0:10].plot(kind='bar', title="Top Electives chosen for Accenture", y="Count"))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(df1.ElectiveGrade1.value_counts()[0:5].plot(kind='pie'))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)
